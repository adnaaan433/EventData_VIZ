# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
import matplotlib.patches as patches
import matplotlib as mpl
from mplsoccer import Pitch, VerticalPitch, FontManager, Sbopen, add_image
from matplotlib.font_manager import FontProperties
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patheffects as path_effects
from highlight_text import ax_text, fig_text
from PIL import Image
from mplsoccer import add_image
from urllib.request import urlopen
import os
from statistics import mode


# Print the modified DataFrame
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

green = '#69f900'
red = '#ff4b44'
blue = '#00a0de'
violet = '#a369ff'
bg_color= '#f5f5f5'
line_color= '#000000'
col1 = '#ff4b44'
col2 = '#00a0de'

# %%
import warnings
warnings.filterwarnings('ignore', category=FutureWarning)
warnings.filterwarnings('ignore', category=pd.errors.SettingWithCopyWarning)

# %%
font_path = "C:\Fonts\Google_Sans_Code\static\GoogleSansCode-Bold.ttf"
custom_font = FontProperties(fname=font_path)
font_path_thin = "C:\Fonts\Google_Sans_Code\static\GoogleSansCode-Regular.ttf"
custom_font_thin = FontProperties(fname=font_path_thin)

# %%
font_path = "C:\Fonts\Montserrat_Alternates\MontserratAlternates-Bold.ttf"
custom_font = FontProperties(fname=font_path)
font_path_thin = "C:\Fonts\Montserrat_Alternates\MontserratAlternates-Regular.ttf"
custom_font_thin = FontProperties(fname=font_path_thin)

# %%
df = pd.read_csv(r"D:\FData\All_Top_5_League\2024_25\event_data\La_Liga_2024_25_event_data.csv")
# Out:
# C:\Users\h\AppData\Local\Temp\ipykernel_9124\3067447424.py:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(r"D:\FData\All_Top_5_League\2024_25\event_data\La_Liga_2024_25_event_data.csv")

# %% [markdown]
# # Offside Trap

# %%
# Function to calculate avg_x for a given team
def calculate_avg_x(team_name):
    dfteam = df[df['teamName'] == team_name]
    cb_df = dfteam[(dfteam['type'] == 'OffsideProvoked')]
    return cb_df['x'].median()

def calculate_of_count(team_name):
    dfteam = df[df['teamName'] == team_name]
    cb_df = dfteam[(dfteam['type'] == 'OffsideProvoked')]
    return len(cb_df)

# Function to plot the defensive line for a team
def plot_def_line(ax, team_name):
    dfteam = df[df['teamName'] == team_name]
    cb_df = dfteam[(dfteam['type'] == 'OffsideProvoked')]
    offpro = len(cb_df)
    avg_x = cb_df['x'].median()
    pitch = VerticalPitch(pitch_type='uefa', pitch_color=bg_color, line_color=line_color, linewidth=1.5, corner_arcs=True)
    pitch.draw(ax=ax)
    
    ax.hlines(avg_x, xmin=0, xmax=68, color=col1, linewidth=3, linestyle='--')
    # ax.hlines(cb_df.x, xmin=0, xmax=68, color=col2, linewidth=1, linestyle='--')
    ax.text(34, avg_x, f'{avg_x:.1f}m', color=bg_color, fontsize=20, fontweight='bold', ha='center', va='center',
            bbox=dict(facecolor=col1, edgecolor=col1, boxstyle='round,pad=0.3'), 
            # fontproperties=custom_font
           )
    
    # ax.hlines(off_x, xmin=0, xmax=68, color=col1, linestyle='--', label='Offensive Actions')
    ax.text(34, 70, f'Offside Provoked\n{offpro}', color=col1, fontsize=15, fontweight='bold', ha='center', va='bottom',
            # bbox=dict(facecolor=col1, edgecolor=col1, boxstyle='round,pad=0.3')
           )
    
    # ax.hlines(def_x, xmin=0, xmax=68, color=col2, linestyle='--', label='Defensive Actions')
    ax.text(34, avg_x + 8, f'Avg. Height of\nOffside Trap', color=bg_color, fontsize=13, fontweight='bold', ha='center', va='bottom',
            bbox=dict(facecolor=col1, edgecolor=col1, boxstyle='round,pad=0.3'))

    fill_x = [0,68,68,0]
    fill_y = [0,0,avg_x,avg_x]
    ax.fill(fill_x, fill_y, color=col1, alpha=0.5)
    
    ax.text(54, 112, team_name, fontsize=18, fontweight='bold', 
            # fontproperties=custom_font
           )
    IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
    image = Image.open(urlopen(IMAGE_URL))
    ax_image = pitch.inset_image(114, 64, image, height=12, ax=ax)

    # ax.legend(loc='upper right')

fig,ax=plt.subplots(figsize=(10,10))
plot_def_line(ax, 'Barcelona')

# %%
sorted(df.playerName.fillna('').unique())
# Out:
# ['',
#  'Abde Ezzalzouli',
#  'Abde Rebbach',
#  'Abdel Abqar',
#  'Abdoulaye Keita',
#  'Abdul Mumin',
#  'Abdón Prats',
#  'Abel Bretones',
#  'Abel Ruiz',
#  'Aboubacar Bassinga',
#  'Adam Aznou',
#  'Adama Boiro',
#  'Adnan Januzaj',
#  'Adri Embarba',
#  'Adrià Alti',
#  'Adrià Pedrosa',
#  'Adrián',
#  'Adrián Arnu',
#  'Adrián Niño',
#  'Adrián Pica',
#  'Adrián Rodríguez',
#  'Adu Ares',
#  'Aihen Muñoz',
#  'Aimar Oroz',
#  'Aingeru Olabarrieta',
#  'Aitor Fernández',
#  'Aitor Paredes',
#  'Aitor Ruibal',
#  'Akor Adams',
#  'Albert Sambi Lokonga',
#  'Alberto Marí',
#  'Alberto Moleiro',
#  'Alberto Risco',
#  'Alejandro Balde',
#  'Alejandro Catena',
#  'Alejandro Francés',
#  'Alejo Véliz',
#  'Aleksandar Sedlar',
#  'Alex Berenguer',
#  'Alex Král',
#  'Alexander Sørloth',
#  'Alfon González',
#  'Alfonso Espino',
#  'Alfonso Pedraza',
#  'Allan Nyom',
#  'Amath Ndiaye',
#  'Ander Barrenetxea',
#  'Ander Guevara',
#  'Ander Herrera',
#  'Andoni Gorosabel',
#  'Andreas Christensen',
#  'Andrei Ratiu',
#  'Andrii Lunin',
#  'André Almeida',
#  'André Ferreira',
#  'Andy Pelmard',
#  'Ansu Fati',
#  'Ante Budimir',
#  'Antoine Griezmann',
#  'Antonio Blanco',
#  'Antonio Candela',
#  'Antonio Raíllo',
#  'Antonio Rüdiger',
#  'Antonio Sivera',
#  'Antonio Sánchez',
#  'Antoniu Roca',
#  'Antony',
#  'Anuar Tuhami',
#  'Arda Güler',
#  'Aridane Hernández',
#  'Aritz Arambarri',
#  'Aritz Elustondo',
#  'Arkaitz Mariezkurrena',
#  'Arnau Martínez',
#  'Arnau Rafús',
#  'Arnau Solà',
#  'Arnaut Danjuma',
#  'Arsen Zakharyan',
#  'Arthur',
#  'Arturo Rodríguez',
#  'Asier Villalibre',
#  'Assane Diao',
#  'Augusto Batalla',
#  'Aurélien Tchouaméni',
#  'Axel Witsel',
#  'Ayoze Pérez',
#  'Benito Ramírez',
#  'Bertug Yildirim',
#  'Beñat Prados',
#  'Beñat Turrientes',
#  'Bojan Miovski',
#  'Borja Iglesias',
#  'Borja Mayoral',
#  'Borna Barisic',
#  'Brahim Díaz',
#  'Brais Méndez',
#  'Brian Oliván',
#  'Bryan Gil',
#  'Bryan Zaragoza',
#  'Carl Starfelt',
#  'Carles Aleñá',
#  'Carles Pérez',
#  'Carlos Benavídez',
#  'Carlos Domínguez',
#  'Carlos Guirao',
#  'Carlos Martín',
#  'Carlos Romero',
#  'Carlos Vicente',
#  'Cenk Özkacar',
#  'Chema Andres',
#  'Chidera Ejuke',
#  'Chimy Ávila',
#  'Chiquinho',
#  'Christantus Uche',
#  'Chuki',
#  'Clément Lenglet',
#  'Coba da Costa',
#  'Conor Gallagher',
#  'Copete',
#  'Cristhian Mosquera',
#  'Cristhian Stuani',
#  'Cucho Hernández',
#  'Cyle Larin',
#  'Cédric Bakambu',
#  'César Azpilicueta',
#  'César Tárrega',
#  'Daley Blind',
#  'Daley Sinkgraven',
#  'Damián Rodríguez',
#  'Dani Carvajal',
#  'Dani Ceballos',
#  'Dani Cárdenas',
#  'Dani Gómez',
#  'Dani Olmo',
#  'Dani Parejo',
#  'Dani Raba',
#  'Dani Requena',
#  'Dani Rodríguez',
#  'Dani Vivian',
#  'Daniel Díaz',
#  'Daniel Luna',
#  'Daniel Yáñez',
#  'Darko Brasanac',
#  'Darwin Machís',
#  'Darío Benavides',
#  'David Alaba',
#  'David Argüelles',
#  'David López',
#  'David Otorbi',
#  'David Soria',
#  'David Torres',
#  'Denis Suárez',
#  'Diego Conde',
#  'Diego García',
#  'Diego Hormigo',
#  'Diego Llorente',
#  'Diego López',
#  'Diego Martín',
#  'Diego Rico',
#  'Dimitri Foulquier',
#  'Dinko Horkas',
#  'Djené Dakonam',
#  'Djibril Sow',
#  'Dodi Lukébakio',
#  'Domingos Duarte',
#  'Dominik Greif',
#  'Donny van de Beek',
#  'Duk',
#  'Dário Essugo',
#  'Edu Expósito',
#  'Eduardo Camavinga',
#  'Endika Bujan',
#  'Endrick',
#  'Enric Franquesa',
#  'Enzo Barrenechea',
#  'Enzo Boyomo',
#  'Enzo Loiodice',
#  'Eray Cömert',
#  'Eric Bailly',
#  'Eric García',
#  "Etienne Eto'o Pineda",
#  'Etta Eyong',
#  'Fabio González',
#  'Facundo Garcés',
#  'Federico Valverde',
#  'Ferland Mendy',
#  'Fermín López',
#  'Fernando Calero',
#  'Fernando López',
#  'Ferran Torres',
#  'Ferrán Ruiz',
#  'Florian Grillitsch',
#  'Florian Lejeune',
#  'Fran Beltrán',
#  'Fran García',
#  'Fran González',
#  'Fran Pérez',
#  'Fran Vieites',
#  'Franco Cervi',
#  'Frenkie de Jong',
#  'Fábio Silva',
#  'Gabriel Misehouy',
#  'García Pascual',
#  'Gavi',
#  'Gerard Gumbau',
#  'Gerard Martín',
#  'Gerard Moreno',
#  'Germán Valera',
#  'Giorgi Mamardashvili',
#  'Giovani Lo Celso',
#  'Giuliano Simeone',
#  'Gonzalo García',
#  'Gonzalo Montiel',
#  'Gorka Guruzeta',
#  'Gorka Rivera',
#  'Hamari Traoré',
#  'Henrique',
#  'Hugo Duro',
#  'Hugo Guillamón',
#  'Hugo Novoa',
#  'Hugo Sotelo',
#  'Hugo Álvarez',
#  'Héctor Bellerín',
#  'Héctor Fort',
#  'Iago Aspas',
#  'Iago Parente',
#  'Ibrahim Alani',
#  'Igor Zubeldia',
#  'Iker Almena',
#  'Iker Benito',
#  'Iker Córdoba',
#  'Iker Losada',
#  'Iker Muñoz',
#  'Ilaix Moriba',
#  'Ilias Akhomach',
#  'Irvin Cardona',
#  'Isaac Romero',
#  'Isco',
#  'Isi Palazón',
#  'Ismael Bekhoucha',
#  'Israel Domínguez',
#  'Iván Balliu',
#  'Iván Jaime',
#  'Iván Martín',
#  'Iván Sánchez',
#  'Iván Villar',
#  'Iñaki Peña',
#  'Iñaki Williams',
#  'Iñigo Martínez',
#  'Jacobo Ramón',
#  'Jailson',
#  'Jaime Mata',
#  'James Rodríguez',
#  'Jan Oblak',
#  'Jan Salas',
#  'Jasper Cillessen',
#  'Javi Galán',
#  'Javi Guerra',
#  'Javi Hernández',
#  'Javi Llabrés',
#  'Javi López',
#  'Javi Martínez',
#  'Javi Muñoz',
#  'Javi Puado',
#  'Javi Rodríguez',
#  'Javi Sánchez',
#  'Javier Manquillo',
#  'Javier Martón',
#  'Jesús Areso',
#  'Jesús Navas',
#  'Jesús Owono',
#  'Jesús Rodriguez',
#  'Jesús Vallejo',
#  'Jesús Vázquez',
#  'Jhon Solís',
#  'Joan García',
#  'Joan Jordán',
#  'Jofre Carreras',
#  'Johan Mojica',
#  'John Patrick',
#  'Johnny Cardoso',
#  'Jon Aramburu',
#  'Jon Guridi',
#  'Jon Magunazelaia',
#  'Jon Martín',
#  'Jon Moncayola',
#  'Jon Olasagasti',
#  'Jon Pacheco',
#  'Jonathan Bamba',
#  'Jorge Herrando',
#  'Jorge Sáenz',
#  'Jorge de Frutos',
#  'Joseph Aidoo',
#  'José Arnáiz',
#  'José Campaña',
#  'José Carlos González',
#  'José Gayà',
#  'José Gragera',
#  'José María Giménez',
#  'José Ángel Carmona',
#  'Juan Bernat',
#  'Juan Berrocal',
#  'Juan Carlos',
#  'Juan Cruz',
#  'Juan Foyth',
#  'Juan Herzog',
#  'Juan Iglesias',
#  'Juan Musso',
#  'Juan Soriano',
#  'Juanlu Sánchez',
#  'Juanmi',
#  'Juanmi Latasa',
#  'Juanpe',
#  'Jude Bellingham',
#  'Julen Agirrezabala',
#  'Jules Koundé',
#  'Julián Alvarez',
#  'Julián Chicco',
#  'Juma Bah',
#  'Justin Smith',
#  'Karl Hein',
#  'Kelechi Iheanacho',
#  'Kenedy',
#  'Kike Barja',
#  'Kike García',
#  'Kike Pérez',
#  'Kike Salas',
#  'Kiko Femenía',
#  'Kim Min-Su',
#  'Kirian Rodríguez',
#  'Koke',
#  'Kylian Mbappé',
#  'Ladislav Krejcí',
#  'Lamine Yamal',
#  'Leandro Antonetti',
#  'Leandro Cabrera',
#  'Leo Román',
#  'Logan Costa',
#  'Lorenzo Aguado',
#  'Loïc Badé',
#  'Luca de la Torre',
#  'Lucas Ocampos',
#  'Lucas Rosa',
#  'Lucas Torró',
#  'Lucas Vázquez',
#  'Lucien Agoumé',
#  'Luis Milla',
#  'Luis Pérez',
#  'Luis Rioja',
#  'Luiz Júnior',
#  'Luka Modric',
#  'Luka Romero',
#  'Luka Sucic',
#  'Luken Beitia',
#  'Mamadou Sylla',
#  'Manu Bueno',
#  'Manu Fuster',
#  'Manu Morlanes',
#  'Manu Sánchez',
#  'Marash Kumbulla',
#  'Marc Bartra',
#  'Marc Bernal',
#  'Marc Cardona',
#  'Marc Casadó',
#  'Marc Domenech',
#  'Marc Roca',
#  'Marc-André ter Stegen',
#  'Marcos Alonso',
#  'Marcos André',
#  'Marcos Llorente',
#  'Marcão',
#  'Mario Maroto',
#  'Mario Martín',
#  'Marko Dmitrovic',
#  'Maroan Sannadi',
#  'Martin Valjent',
#  'Martín Tejón',
#  'Martín Zubimendi',
#  'Marvin Park',
#  'Mateo Flores',
#  'Mateo Mejía',
#  'Mateu Morey',
#  'Matija Nastasic',
#  'Mauro Arambarri',
#  'Max Aarons',
#  'Maximiliano Caufriez',
#  'Miguel Gutiérrez',
#  'Miguel de la Fuente',
#  'Mihailo Ristic',
#  'Mika Mármol',
#  'Mikel Jauregizar',
#  'Mikel Oyarzabal',
#  'Mikel Vesga',
#  'Moi Gómez',
#  'Mouctar Diakhaby',
#  'Moussa Diarra',
#  'Munir El Haddadi',
#  'Nabil Aberdin',
#  'Nabil Fekir',
#  'Nacho Vidal',
#  'Naci Ünüvar',
#  'Nahuel Molina',
#  'Nahuel Tenaglia',
#  'Natan',
#  'Nayef Aguerd',
#  'Nemanja Gudelj',
#  'Nico Serrano',
#  'Nico Williams',
#  'Nicolas Pépé',
#  'Nobel Mendy',
#  'Oihan Sancet',
#  'Oliver McBurnie',
#  'Omar Alderete',
#  'Omar El Hilali',
#  'Omar Mascarell',
#  'Oriol Romeu',
#  'Orri Óskarsson',
#  'Pablo Barrios',
#  'Pablo Durán',
#  'Pablo Fornals',
#  'Pablo García',
#  'Pablo Ibáñez',
#  'Pablo Maffeo',
#  'Pablo Marín',
#  'Pablo Torre',
#  'Papa Dame Ba',
#  'Pape Gueye',
#  'Pathé Ciss',
#  'Pau Cabanes',
#  'Pau Cubarsí',
#  'Pau López',
#  'Pau Navarro',
#  'Pau Víctor',
#  'Paulo Gazzaniga',
#  'Pedri',
#  'Pedro Díaz',
#  'Peio Canales',
#  'Pejiño',
#  'Pelayo Fernández',
#  'Pep Chavarría',
#  'Pepelu',
#  'Peque Fernández',
#  'Pere Milla',
#  'Peter Federico',
#  'Pol Lozano',
#  'Portu',
#  'Rafa Mir',
#  'Rafael Bauza',
#  'Ramon Terrats',
#  'Ramón Martínez',
#  'Randy Nteka',
#  'Raphinha',
#  'Raúl Albiol',
#  'Raúl Asencio',
#  'Raúl Chasco',
#  'Raúl García',
#  'Raúl Moro',
#  'Raúl de Tomás',
#  'Reinildo',
#  'Renato Tapia',
#  'Ricardo Rodríguez',
#  'Robert Lewandowski',
#  'Robert Navarro',
#  'Roberto Fernández',
#  'Roberto López',
#  'Robin Le Normand',
#  'Rodri',
#  'Rodrigo Abajas',
#  'Rodrigo De Paul',
#  'Rodrigo Riquelme',
#  'Rodrygo',
#  'Roger Hinojo',
#  'Romain Perraud',
#  'Ronald Araújo',
#  'Rubén García',
#  'Rubén Peña',
#  'Rubén Vargas',
#  'Rui Silva',
#  'Samuel Lino',
#  'Samú Costa',
#  'Sandro Ramírez',
#  'Santi Comesaña',
#  'Santiago Mouriño',
#  'Saúl Ñíguez',
#  'Scott McKenna',
#  'Selim Amallah',
#  'Selvi Clua',
#  'Sergi Altimira',
#  'Sergi Canós',
#  'Sergi Cardona',
#  'Sergi Darder',
#  'Sergi Domínguez',
#  'Sergi Guardiola',
#  'Sergi Gómez',
#  'Sergio Arribas',
#  'Sergio Camello',
#  'Sergio Carreira',
#  'Sergio González',
#  'Sergio Gómez',
#  'Sergio Herrera',
#  'Sergio Viera',
#  'Seydouba Cissé',
#  'Sheraldo Becker',
#  'Siebe Van der Heyden',
#  'Stanis Idumbo',
#  'Stanko Juric',
#  'Stefan Bajcetic',
#  'Stoichkov',
#  'Stole Dimitrievski',
#  'Suso',
#  'Sébastien Haller',
#  'Tadeo Allende',
#  'Tajon Buchanan',
#  'Takefusa Kubo',
#  'Takuma Asano',
#  'Tamás Nikitscher',
#  'Tanguy Nianzou',
#  'Tasos Douvikas',
#  'Thiago Ojeda',
#  'Thibaut Courtois',
#  'Thierno Barry',
#  'Thierry Correia',
#  'Thomas Lemar',
#  'Tomás Conechny',
#  'Toni Lato',
#  'Toni Martínez',
#  'Umar Sadiq',
#  'Unai García',
#  'Unai Gómez',
#  'Unai López',
#  'Unai Marrero',
#  'Unai Núñez',
#  'Unai Simón',
#  'Urko González',
#  'Valentin Rosier',
#  'Valentín Barco',
#  'Valentín Pezzolesi',
#  'Valery Fernández',
#  'Vedat Muriqi',
#  'Vicente Guaita',
#  'Viktor Tsygankov',
#  'Vinícius Júnior',
#  'Viti Rozada',
#  'Vitor Roque',
#  'Vladyslav Krapyvtsov',
#  'Víctor Meseguer',
#  'Víctor Muñoz',
#  'Walid Cheddira',
#  'William Carvalho',
#  'Williot Swedberg',
#  'Willy Kambwala',
#  'Wojciech Szczesny',
#  'Xavi Moreno',
#  'Yan Diomande',
#  'Yangel Herrera',
#  'Yarek Gasiorowski',
#  'Yellu Santiago',
#  'Yeray Álvarez',
#  'Yeremy Pino',
#  'Yoel Lago',
#  'Youssouf Sabaly',
#  'Yuri Berchiche',
#  'Yvan Neyou',
#  'Yáser Asprilla',
#  'Álex Baena',
#  'Álex Muñoz',
#  'Álex Padilla',
#  'Álex Remiro',
#  'Álex Sola',
#  'Álex Suárez',
#  'Álvaro Aguado',
#  'Álvaro Djaló',
#  'Álvaro Fernández',
#  'Álvaro García',
#  'Álvaro Odriozola',
#  'Álvaro Rodríguez',
#  'Álvaro Tejero',
#  'Ángel Correa',
#  'Ángel Ortiz',
#  'Éder Militão',
#  'Íñigo Lekue',
#  'Íñigo Ruíz de Galarreta',
#  'Óscar De Marcos',
#  'Óscar Mingueza',
#  'Óscar Rodríguez',
#  'Óscar Trejo',
#  'Óscar Valentín',
#  'Ørjan Nyland']

# %%
# Function to plot the defensive line for a team
def plot_def_line(ax, team_name):
    dfteam = df[df['teamName'] == team_name]
    cb_df = dfteam[(dfteam['type'] == 'OffsideProvoked')]
    pitch = VerticalPitch(pitch_type='uefa', pitch_color=bg_color, line_color=line_color, linewidth=1.5, corner_arcs=True)
    pitch.draw(ax=ax)

    pdf1 = cb_df[cb_df['playerName']== 'Iñigo Martínez']
    pdf2 = cb_df[cb_df['playerName']== 'Pau Cubarsí']

    mean_off = cb_df.x.mean()
    ax.hlines(mean_off, xmin=-2, xmax=70, ls='dashed', lw=2, color='gray', alpha=0.5)
    ax.text(-2, mean_off+2, f'avg: {mean_off:.2f} m', color='gray', alpha=0.75, rotation=90)

    ax.scatter(cb_df.y, cb_df.x, color='k', marker='x', alpha=0.25)

    ax.scatter(pdf1.y, pdf1.x, s=100, color=col2)
    ax.scatter(pdf2.y, pdf2.x, s=100, color=violet)

    ax.text(54, 115, f'Total Offsides Provoked: {len(cb_df)}', fontsize=13, ha='left')
    ax_text(54, 112, f'<Pau Cubarsí: {len(pdf2)}>  |  <Iñigo Martínez: {len(pdf1)}>', fontsize=13, ha='left', highlight_textprops=[{'color': violet}, {'color': col2}], ax=ax)

    ax.text(34, 102, '@adnaaan433', ha='center')


    
    ax.text(54, 120, team_name, fontsize=20, fontweight='bold')
    IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
    image = Image.open(urlopen(IMAGE_URL))
    pitch.inset_image(118, 64, image, height=15, ax=ax)

fig,ax=plt.subplots(figsize=(10,10), facecolor=bg_color)
plot_def_line(ax, 'Barcelona')

# %%
# def plot_def_line(ax, team_name):
#     dfteam = df[df['teamName'] == team_name]
#     cb_df = dfteam[(dfteam['type'] == 'OffsideProvoked')]
#     offpro = len(cb_df)
#     avg_x = cb_df['x'].median()
#     pitch = VerticalPitch(pitch_type='uefa', pitch_color=bg_color, linewidth=1.5, corner_arcs=True)
#     pitch.draw(ax=ax)
#     ax.set_xlim(68.5, -0.5)
#     ax.set_ylim(-0.5, 105.5)
    
#     ax.hlines(avg_x, xmin=0, xmax=68, color=col1, linewidth=3, linestyle='--')
#     # ax.hlines(cb_df.x, xmin=0, xmax=68, color=col2, linewidth=1, linestyle='--')
#     ax.text(34, avg_x, f'{avg_x:.1f}m', color=bg_color, fontsize=20, fontweight='bold', ha='center', va='center',
#             bbox=dict(facecolor=col1, edgecolor=col1, boxstyle='round,pad=0.3'), fontproperties=custom_font)
    
#     # # ax.hlines(off_x, xmin=0, xmax=68, color=col1, linestyle='--', label='Offensive Actions')
#     # ax.text(34, 70, f'Offside Provoked\n{offpro}', color=col1, fontsize=15, fontweight='bold', ha='center', va='bottom',
#     #         # bbox=dict(facecolor=col1, edgecolor=col1, boxstyle='round,pad=0.3')
#     #        )
    
#     # # ax.hlines(def_x, xmin=0, xmax=68, color=col2, linestyle='--', label='Defensive Actions')
#     # ax.text(34, avg_x + 7, f'Avg. Height of\nOffside Trap', color=bg_color, fontsize=15, fontweight='bold', ha='center', va='bottom',
#     #         bbox=dict(facecolor=col1, edgecolor=col1, boxstyle='round,pad=0.3'))

#     # fill_x = [0,68,68,0]
#     # fill_y = [0,0,avg_x,avg_x]
#     # ax.fill(fill_x, fill_y, color=col1, alpha=0.5)
#     pitch.scatter(cb_df.x, cb_df.y, s=100, color='None', lw=1.5, ec=col1, ax=ax)
    
#     ax.text(50, 112, team_name, fontsize=18, fontweight='bold', fontproperties=custom_font)
#     ax.text(50, 108, f'Total Offsides Provoked: {offpro}', fontsize=12, ha='left', va='center', fontproperties=custom_font_thin)
#     IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
#     image = Image.open(urlopen(IMAGE_URL))
#     ax_image = pitch.inset_image(114, 60, image, height=12, ax=ax)

#     # ax.legend(loc='upper right')

# fig,ax=plt.subplots(figsize=(10,10))
# plot_def_line(ax, 'Tottenham')

# %%
col1 = '#400f66'

# %%
# List of team names
team_names = df.teamName.unique()

# Create a DataFrame with team names and their avg_x values
team_avg_x = pd.DataFrame({'teamName': team_names})
team_avg_x['avg_x'] = team_avg_x['teamName'].apply(calculate_of_count)

# Sort the teams by avg_x value
team_avg_x_sorted = team_avg_x.sort_values(by='avg_x', ascending=False).dropna().reset_index(drop=True)

# Create the figure and axes for a 4x5 grid
fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(24, 26), facecolor=bg_color)

# Flatten the axes array to easily loop through it
axes = axes.ravel()

# Loop through the sorted team names and corresponding axes
for i, row in enumerate(team_avg_x_sorted.itertuples()):
    team_name = row.teamName
    avg_x = row.avg_x
    plot_def_line(axes[i], team_name)
# plot_blank(axes[18])
# plot_blank(axes[19])

fig.text(0.21, 0.98, 'La Liga Teams Offside Trap Height Analysis', fontsize=38, fontweight='bold', ha='left', va='top')
# fig.text(0.21, 0.955, "Teams are sorted by Avg. Height of the Offside Trap",
#          fontsize=20, ha='left', va='top')
fig.text(0.21, 0.955, "Teams are sorted by the total number of Offsides Provoked",
         fontsize=20, ha='left', va='top')
# fig_text(0.21, 0.94, "<Avg. Offensive Action Height of CenterBacks> | Overall Avg. Position of CneterBacks | <Avg. Defensive Action Height of CenterBacks>",
#          fontsize=17, ha='left', va='top', ax=fig, highlight_textprops=[{'color':col1}, {'color':col2}]_thin)
fig.text(0.21, 0.94, "Data from: Opta | till GW34 of La Liga 2024-25 | made by: @adnaaan433",
         fontsize=20, ha='left', va='top')

image_url = "file:///D:/FData/Leagues_logos/LaLiga%20.html"
image = urlopen(image_url)
image = Image.open(image)
ax_image = add_image(image, fig, left=0.14, bottom=0.93, width=0.05, height=0.05)

# %% [markdown]
# # Fullbacks

# %%
# def calculate_avg_h(team_name):
#     rbdf = df[(df['teamName']==team_name) & (df['position']=='DR') & (~df['qualifiers'].str.contains('FreeKick|Corner|ThrowIn'))]
#     lbdf = df[(df['teamName']==team_name) & (df['position']=='DL') & (~df['qualifiers'].str.contains('FreeKick|Corner|ThrowIn'))]
#     rwbdf = df[(df['teamName']==team_name) & (df['position']=='DMR') & (~df['qualifiers'].str.contains('FreeKick|Corner|ThrowIn'))]
#     lwbdf = df[(df['teamName']==team_name) & (df['position']=='DML') & (~df['qualifiers'].str.contains('FreeKick|Corner|ThrowIn'))]
#     right = pd.concat([rbdf, rwbdf])
#     left = pd.concat([lbdf, lwbdf])
#     avg_hr = right['x'].median()
#     avg_hl = left['x'].median()
#     avg_h = (avg_hr+avg_hl)/2
#     return avg_h

# def plot_fullback(ax, team_name):
#     rbdf = df[(df['teamName']==team_name) & (df['position']=='DR') & (~df['qualifiers'].str.contains('FreeKick|Corner|ThrowIn'))]
#     lbdf = df[(df['teamName']==team_name) & (df['position']=='DL') & (~df['qualifiers'].str.contains('FreeKick|Corner|ThrowIn'))]
#     rwbdf = df[(df['teamName']==team_name) & (df['position']=='DMR') & (~df['qualifiers'].str.contains('FreeKick|Corner|ThrowIn'))]
#     lwbdf = df[(df['teamName']==team_name) & (df['position']=='DML') & (~df['qualifiers'].str.contains('FreeKick|Corner|ThrowIn'))]
#     right = pd.concat([rbdf, rwbdf])
#     left = pd.concat([lbdf, lwbdf])
#     avg_hr = right['x'].median()
#     avg_hl = left['x'].median()
#     avg_h = (avg_hr+avg_hl)/2
#     avg_wr = right['y'].median()
#     avg_wl = left['y'].median()
#     dist = avg_wl - avg_wr
#     pitch = VerticalPitch(pitch_type='uefa', pitch_color=bg_color, line_color='gray', linewidth=2, corner_arcs=True)
#     pitch.draw(ax=ax)
#     pitch.lines(avg_hr, avg_wr, avg_hl, avg_wl, color=col1, lw=7, ax=ax)
#     pitch.scatter(avg_hr, avg_wr, s=1000, color=col1, edgecolor=bg_color, lw=3, zorder=3, ax=ax)
#     pitch.scatter(avg_hl, avg_wl, s=1000, color=col1, edgecolor=bg_color, lw=3, zorder=3, ax=ax)
#     ax.text(avg_wr, avg_hr-7, 'RB', fontsize=20, ha='center', va='top', fontproperties=custom_font)
#     ax.text(avg_wl, avg_hl-7, 'LB', fontsize=20, ha='center', va='top', fontproperties=custom_font)
#     ax.text(avg_wr, avg_hr+7, f'{avg_hr:.1f}', fontsize=20, ha='center', va='bottom', fontproperties=custom_font)
#     ax.text(avg_wl, avg_hl+7, f'{avg_hl:.1f}', fontsize=20, ha='center', va='bottom', fontproperties=custom_font)
#     ax.text(34, 115, f'Avg. Height: {avg_h:.1f}m', fontsize=15, ha='center', va='bottom', fontproperties=custom_font_thin)
#     ax.text(34, 110, f'Avg. Width: {dist:.1f}m', fontsize=15, ha='center', va='bottom', fontproperties=custom_font_thin)
#     ax.text(34, 120, team_name, fontsize=25, fontweight='bold', fontproperties=custom_font, ha='center', va='bottom')
#     IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
#     image = Image.open(urlopen(IMAGE_URL))
#     ax_image = pitch.inset_image(52.5, 34, image, height=25, alpha=0.5, zorder=1, ax=ax)
    

# # List of team names
# team_names = df.teamName.unique()

# # Create a DataFrame with team names and their avg_h values
# team_avg_h = pd.DataFrame({'teamName': team_names})
# team_avg_h['avg_h'] = team_avg_h['teamName'].apply(calculate_avg_h)
# team_avg_h_sorted = team_avg_h.sort_values(by='avg_h', ascending=False).reset_index(drop=True)
# team_avg_h_sorted

# # Create the figure and axes for a 4x5 grid
# fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(24, 26), facecolor=bg_color)

# # Flatten the axes array to easily loop through it
# axes = axes.ravel()

# # Loop through the sorted team names and corresponding axes
# for i, row in enumerate(team_avg_h_sorted.itertuples()):
#     team_name = row.teamName
#     avg_h = row.avg_h
#     plot_fullback(axes[i], team_name)

# %%
def calculate_avg_h(df, team_name):
    team_df = df[(df['teamName']==team_name) & (~df['qualifiers'].str.contains('FreeKick|Corner|ThrowIn'))]
    right = team_df[team_df['position'].isin(['DR', 'DMR'])]
    left = team_df[team_df['position'].isin(['DL', 'DML'])]
    
    avg_hr = right['x'].median()
    avg_hl = left['x'].median()
    avg_h = (avg_hr + avg_hl) / 2
    return avg_h

def plot_fullback(ax, df, team_name, image, avg_h):
    team_df = df[(df['teamName']==team_name) & (~df['qualifiers'].str.contains('FreeKick|Corner|ThrowIn'))]
    right = team_df[team_df['position'].isin(['DR', 'DMR'])]
    left = team_df[team_df['position'].isin(['DL', 'DML'])]
    
    avg_hr = right['x'].median()
    avg_hl = left['x'].median()
    avg_wr = right['y'].median()
    avg_wl = left['y'].median()
    dist = avg_wl - avg_wr

    pitch = VerticalPitch(pitch_type='uefa', pitch_color=bg_color, line_color='gray', linewidth=2, corner_arcs=True)
    pitch.draw(ax=ax)
    
    # Plot lines and scatter points for positions
    pitch.lines(avg_hr, avg_wr, avg_hl, avg_wl, color=col1, lw=7, ax=ax)
    pitch.scatter(avg_hr, avg_wr, s=1000, color=col1, edgecolor=bg_color, lw=3, zorder=3, ax=ax)
    pitch.scatter(avg_hl, avg_wl, s=1000, color=col1, edgecolor=bg_color, lw=3, zorder=3, ax=ax)

    # Annotate the plot
    ax.text(avg_wr, avg_hr-7, 'RB', fontsize=20, ha='center', va='top', fontproperties=custom_font)
    ax.text(avg_wl, avg_hl-7, 'LB', fontsize=20, ha='center', va='top', fontproperties=custom_font)
    ax.text(avg_wr, avg_hr+7, f'{avg_hr:.1f}', fontsize=20, ha='center', va='bottom', fontproperties=custom_font)
    ax.text(avg_wl, avg_hl+7, f'{avg_hl:.1f}', fontsize=20, ha='center', va='bottom', fontproperties=custom_font)
    ax.text(34, 114, f'Avg. Height: {avg_h:.1f}m', fontsize=13, ha='center', va='bottom', fontproperties=custom_font_thin)
    ax.text(34, 107, f'Avg. Width: {dist:.1f}m', fontsize=13, ha='center', va='bottom', fontproperties=custom_font_thin)
    ax.text(34, 120, team_name, fontsize=23, fontweight='bold', fontproperties=custom_font, ha='center', va='bottom')

    # Insert preloaded image
    pitch.inset_image(52.5, 34, image, height=25, alpha=0.5, zorder=1, ax=ax)

team_names = df.teamName.unique()

# Preload team logos
team_images = {}
for team_name in team_names:
    IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
    team_images[team_name] = Image.open(urlopen(IMAGE_URL))

# Create a DataFrame with team names and their avg_h values
team_avg_h = pd.DataFrame({'teamName': team_names})
team_avg_h['avg_h'] = team_avg_h['teamName'].apply(lambda x: calculate_avg_h(df, x))
team_avg_h_sorted = team_avg_h.sort_values(by='avg_h', ascending=False).reset_index(drop=True)

# Create the figure and axes for a 4x5 grid
fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(24, 26), facecolor=bg_color)

# Flatten the axes array to easily loop through it
axes = axes.ravel()

# Loop through the sorted team names and corresponding axes
for i, row in enumerate(team_avg_h_sorted.itertuples()):
    team_name = row.teamName
    avg_h = row.avg_h
    plot_fullback(axes[i], df, team_name, team_images[team_name], avg_h)

font_path = "C:\Fonts\LaLiga2023Bold.otf"
custom_font = FontProperties(fname=font_path)
fig.text(0.21, 0.98, 'LaLiga Teams FullBack Analysis', fontsize=38, fontweight='bold', ha='left', va='top', fontproperties=custom_font)
font_path_thin = "C:\Fonts\LaLiga2023Thin.otf"
custom_font_thin = FontProperties(fname=font_path_thin)
fig.text(0.21, 0.955, "Teams are sorted by Avg. Height of the FullBacks",
         fontsize=20, ha='left', va='top', fontproperties=custom_font_thin)
# fig_text(0.21, 0.94, "<Avg. Offensive Action Height of CenterBacks> | Overall Avg. Position of CneterBacks | <Avg. Defensive Action Height of CenterBacks>",
#          fontsize=17, ha='left', va='top', ax=fig, highlight_textprops=[{'color':col1}, {'color':col2}], fontproperties=custom_font_thin)
fig.text(0.21, 0.94, "Data till GW38 of LaLiga 2023-24 | made by: @adnaaan433 | inspired from: @Opta",
         fontsize=17, ha='left', va='top', fontproperties=custom_font_thin)

image_url = 'file:///D:/FData/Leagues_logos/LaLiga%20.html'
image = urlopen(image_url)
image = Image.open(image)
ax_image = add_image(image, fig, left=0.14, bottom=0.93, width=0.05, height=0.05)

# %% [markdown]
# # CB Def Line

# %%
team_df = df[df['teamName'] == 'Celta Vigo']
match_count = team_df['match_id'].unique()

cb_counts_per_match = {}

for match in match_count:
    no_cb = team_df[(team_df['match_id'] == match) & (team_df['position'] == 'DC')]
    no_cb = no_cb['name'].unique()
    cb_counts_per_match[match] = len(no_cb)

# List of CB counts across matches
cb_counts = list(cb_counts_per_match.values())

# Find the mode (most common count of CBs used)
most_common_cb_count = mode(cb_counts)
most_common_cb_count
# Out:
# 3

# %%
def calculate_avg_x(team_name):
    dfteam = df[df['teamName'] == team_name]
    cb_df = dfteam[(dfteam['position']=='DC') & (dfteam['type'].str.contains('Pass|TakeOn|BallTouch|BallRecovery|Interception|Error|Clearance|Aerial|Challenge|Foul|BlockedPass|Tackle|OffsideProvoked|Save'))]
    avg_x = cb_df['x'].median()
    return avg_x

def backline(ax, team_name):
    team_df = df[df['teamName'] == team_name]
    match_count = team_df['match_id'].unique()

    cb_counts_per_match = {}

    for match in match_count:
        no_cb = team_df[(team_df['match_id'] == match) & (team_df['position'] == 'DC')]
        no_cb = no_cb['name'].unique()
        cb_counts_per_match[match] = len(no_cb)

    # List of CB counts across matches
    cb_counts = list(cb_counts_per_match.values())
    most_common_cb_count = mode(cb_counts)

    if most_common_cb_count == 2:
        dfteam = df[df['teamName'] == team_name]
        cb_df = dfteam[(dfteam['position']=='DC') & (dfteam['type'].str.contains('Pass|TakeOn|BallTouch|BallRecovery|Interception|Error|Clearance|Aerial|Challenge|Foul|BlockedPass|Tackle|OffsideProvoked|Save'))]

        cb_avg = cb_df.groupby('name', as_index=False)[['x', 'y']].median()
        lcb = cb_avg[cb_avg['y']>34]
        rcb = cb_avg[cb_avg['y']<34]
        lcb_avg_y = lcb['y'].median()
        rcb_avg_y = rcb['y'].median()
        lcb_avg_x = lcb['x'].median()
        rcb_avg_x = rcb['x'].median()
        avg_x = cb_df['x'].median()
        avg_width = lcb_avg_y - rcb_avg_y
        pitch = VerticalPitch(pitch_type='uefa', pitch_color=bg_color, line_color='gray', linewidth=1.5, corner_arcs=True)
        pitch.draw(ax=ax)
        
        ax.hlines(avg_x, xmin=0, xmax=68, color='gray', linestyle='--', linewidth=1.5, label='Avg. Position')
        # ax.text(34, avg_x, f'{avg_x:.1f}m', color=bg_color, fontsize=15, fontweight='bold', ha='center', va='center',
        #         bbox=dict(facecolor='k', edgecolor='k', boxstyle='round,pad=0.3'), fontproperties=custom_font)
        ax.scatter(lcb_avg_y, lcb_avg_x, color=col1, edgecolor=col2, zorder=3, linewidth=4, s=500)
        ax.scatter(rcb_avg_y, rcb_avg_x, color=col1, edgecolor=col2, zorder=3, linewidth=4, s=500)
        pitch.lines(lcb_avg_x, lcb_avg_y, rcb_avg_x, rcb_avg_y, color=col2, zorder=2, lw=7, ax=ax)
        ax.text(lcb_avg_y, lcb_avg_x-10, 'LCB', color=col1, fontsize=16, ha='center', va='center', fontproperties=custom_font)
        ax.text(rcb_avg_y, rcb_avg_x-10, 'RCB', color=col1, fontsize=16, ha='center', va='center', fontproperties=custom_font)
        # ax.text(lcb_avg_y, lcb_avg_x+7, f'{lcb_avg_x:.1f}m', rotation=90, color=bg_color, fontsize=16, ha='center', va='bottom',
        #         bbox=dict(facecolor=col1, edgecolor='None', boxstyle='round,pad=0.15'), fontproperties=custom_font)
        # ax.text(rcb_avg_y, rcb_avg_x+7, f'{rcb_avg_x:.1f}m', rotation=90, color=bg_color, fontsize=16, ha='center', va='bottom',
        #         bbox=dict(facecolor=col1, edgecolor='None', boxstyle='round,pad=0.15'), fontproperties=custom_font)
        
        ax.text(34, 114, f'Avg. Height: {avg_x:.1f}m', fontsize=13, ha='center', va='bottom', fontproperties=custom_font_thin)
        ax.text(34, 107, f'Avg. Width: {avg_width:.1f}m', fontsize=13, ha='center', va='bottom', fontproperties=custom_font_thin)
        ax.text(34, 120, team_name, fontsize=23, fontweight='bold', fontproperties=custom_font, ha='center', va='bottom')
        IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
        image = Image.open(urlopen(IMAGE_URL))
        ax_image = pitch.inset_image(52.5, 34, image, height=18, alpha=0.5, ax=ax)

    else:
        dfteam = df[df['teamName'] == team_name]
        cb_df = dfteam[(dfteam['position']=='DC') & (dfteam['type'].str.contains('Pass|TakeOn|BallTouch|BallRecovery|Interception|Error|Clearance|Aerial|Challenge|Foul|BlockedPass|Tackle|OffsideProvoked|Save'))]

        cb_avg = cb_df.groupby('name', as_index=False)[['x', 'y']].median()
        lcb = cb_avg[cb_avg['y']>43]
        mcb = cb_avg[(cb_avg['y']<43) & (cb_avg['y']>25)]
        rcb = cb_avg[cb_avg['y']<25]
        lcb_avg_y = lcb['y'].median()
        rcb_avg_y = rcb['y'].median()
        mcb_avg_y = mcb['y'].median()
        lcb_avg_x = lcb['x'].median()
        rcb_avg_x = rcb['x'].median()
        mcb_avg_x = mcb['x'].median()
        avg_x = cb_df['x'].median()
        avg_width = lcb_avg_y - rcb_avg_y
        pitch = VerticalPitch(pitch_type='uefa', pitch_color=bg_color, line_color='gray', linewidth=1.5, corner_arcs=True)
        pitch.draw(ax=ax)
        
        ax.hlines(avg_x, xmin=0, xmax=68, color='gray', linestyle='--', linewidth=1.5, label='Avg. Position')
        # ax.text(34, avg_x, f'{avg_x:.1f}m', color=bg_color, fontsize=15, fontweight='bold', ha='center', va='center',
        #         bbox=dict(facecolor='k', edgecolor='k', boxstyle='round,pad=0.3'), fontproperties=custom_font)
        ax.scatter(lcb_avg_y, lcb_avg_x, color=col1, edgecolor=col2, zorder=3, linewidth=4, s=500)
        ax.scatter(rcb_avg_y, rcb_avg_x, color=col1, edgecolor=col2, zorder=3, linewidth=4, s=500)
        ax.scatter(mcb_avg_y, mcb_avg_x, color=col1, edgecolor=col2, zorder=3, linewidth=4, s=500)
        pitch.lines(lcb_avg_x, lcb_avg_y, mcb_avg_x, mcb_avg_y, color=col2, zorder=2, lw=7, ax=ax)
        pitch.lines(rcb_avg_x, rcb_avg_y, mcb_avg_x, mcb_avg_y, color=col2, zorder=2, lw=7, ax=ax)
        ax.text(lcb_avg_y, lcb_avg_x-10, 'LCB', color=col1, fontsize=16, ha='center', va='center', fontproperties=custom_font)
        ax.text(rcb_avg_y, rcb_avg_x-10, 'RCB', color=col1, fontsize=16, ha='center', va='center', fontproperties=custom_font)
        ax.text(mcb_avg_y, mcb_avg_x-10, 'CB', color=col1, fontsize=16, ha='center', va='center', fontproperties=custom_font)
        # ax.text(lcb_avg_y, lcb_avg_x+7, f'{lcb_avg_x:.1f}m', rotation=90, color=bg_color, fontsize=16, ha='center', va='bottom',
        #         bbox=dict(facecolor=col1, edgecolor='None', boxstyle='round,pad=0.15'), fontproperties=custom_font)
        # ax.text(rcb_avg_y, rcb_avg_x+7, f'{rcb_avg_x:.1f}m', rotation=90, color=bg_color, fontsize=16, ha='center', va='bottom',
        #         bbox=dict(facecolor=col1, edgecolor='None', boxstyle='round,pad=0.15'), fontproperties=custom_font)
        # ax.text(mcb_avg_y, mcb_avg_x+7, f'{mcb_avg_x:.1f}m', rotation=90, color=bg_color, fontsize=16, ha='center', va='bottom',
        #         bbox=dict(facecolor=col1, edgecolor='None', boxstyle='round,pad=0.15'), fontproperties=custom_font)
        
        ax.text(34, 114, f'Avg. Height: {avg_x:.1f}m', fontsize=13, ha='center', va='bottom', fontproperties=custom_font_thin)
        ax.text(34, 107, f'Avg. Width: {avg_width:.1f}m', fontsize=13, ha='center', va='bottom', fontproperties=custom_font_thin)
        ax.text(34, 120, team_name, fontsize=23, fontweight='bold', fontproperties=custom_font, ha='center', va='bottom')
        IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
        image = Image.open(urlopen(IMAGE_URL))
        ax_image = pitch.inset_image(52.5, 34, image, height=18, alpha=0.5, ax=ax)

fig,ax=plt.subplots(figsize=(10,10), facecolor=bg_color)
backline(ax, 'Barcelona')

# %%
# List of team names
team_names = df.teamName.unique()

# Create a DataFrame with team names and their avg_x values
team_avg_x = pd.DataFrame({'teamName': team_names})
team_avg_x['avg_x'] = team_avg_x['teamName'].apply(calculate_avg_x)

# Sort the teams by avg_x value
team_avg_x_sorted = team_avg_x.sort_values(by='avg_x', ascending=False)

# Create the figure and axes for a 4x5 grid
fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(24, 26), facecolor=bg_color)

# Flatten the axes array to easily loop through it
axes = axes.ravel()

# Loop through the sorted team names and corresponding axes
for i, row in enumerate(team_avg_x_sorted.itertuples()):
    team_name = row.teamName
    avg_x = row.avg_x
    backline(axes[i], team_name)

font_path = "C:\Fonts\LaLiga2023Bold.otf"
custom_font = FontProperties(fname=font_path)
fig.text(0.21, 0.98, 'LaLiga Teams Avg. Defense Line Height Analysis', fontsize=38, fontweight='bold', ha='left', va='top', fontproperties=custom_font)
font_path_thin = "C:\Fonts\LaLiga2023Thin.otf"
custom_font_thin = FontProperties(fname=font_path_thin)
fig.text(0.21, 0.955, "Teams are sorted by Avg. Position of the CenterBacks of the team",
         fontsize=20, ha='left', va='top', fontproperties=custom_font_thin)
fig.text(0.21, 0.94, "Data till GW9 of LaLiga 2024-25| made by: @adnaaan433",
         fontsize=17, ha='left', va='top', fontproperties=custom_font_thin)

image_url = 'file:///D:/FData/Leagues_logos/LaLiga%20.html'
image = urlopen(image_url)
image = Image.open(image)
ax_image = add_image(image, fig, left=0.14, bottom=0.93, width=0.05, height=0.05)

# %%
# List of team names
team_names = df.teamName.unique()

# Create a DataFrame with team names and their avg_x values
team_avg_x = pd.DataFrame({'teamName': team_names})
team_avg_x['avg_x'] = team_avg_x['teamName'].apply(calculate_avg_x)

# Sort the teams by avg_x value
team_avg_x_sorted = team_avg_x.sort_values(by='avg_x', ascending=False)

# Create the figure and axes for a 4x5 grid
fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(24, 26), facecolor=bg_color)

# Flatten the axes array to easily loop through it
axes = axes.ravel()

# Loop through the sorted team names and corresponding axes
for i, row in enumerate(team_avg_x_sorted.itertuples()):
    team_name = row.teamName
    avg_x = row.avg_x
    backline(axes[i], team_name)

font_path = "C:\Fonts\LaLiga2023Bold.otf"
custom_font = FontProperties(fname=font_path)
fig.text(0.21, 0.98, 'LaLiga Teams Avg. Defense Line Height Analysis', fontsize=38, fontweight='bold', ha='left', va='top', fontproperties=custom_font)
font_path_thin = "C:\Fonts\LaLiga2023Thin.otf"
custom_font_thin = FontProperties(fname=font_path_thin)
fig.text(0.21, 0.955, "Teams are sorted by Avg. Position of the CenterBacks of the team",
         fontsize=20, ha='left', va='top', fontproperties=custom_font_thin)
fig.text(0.21, 0.94, "Data till GW38 of LaLiga 2023-24| made by: @adnaaan433",
         fontsize=17, ha='left', va='top', fontproperties=custom_font_thin)

image_url = 'file:///D:/FData/Leagues_logos/LaLiga%20.html'
image = urlopen(image_url)
image = Image.open(image)
ax_image = add_image(image, fig, left=0.14, bottom=0.93, width=0.05, height=0.05)

# %% [markdown]
# # Full Defense Line

# %%
df.teamName.unique()
# Out:
# array(['Sheff Utd', 'Preston', 'Derby', 'Blackburn', 'Oxford', 'Norwich',
#        'Cardiff', 'Sunderland', 'Stoke', 'Coventry', 'Portsmouth',
#        'Leeds', 'Millwall', 'Watford', 'Bristol City', 'Hull', 'QPR',
#        'WBA', 'Swansea', 'Middlesbrough', 'Sheff Wed', 'Plymouth',
#        'Luton', 'Burnley'], dtype=object)

# %%
def plot_blank(ax):
    pitch = VerticalPitch(pitch_type='uefa', pitch_color=bg_color, 
                          # line_color=bg_color, 
                          linewidth=2, corner_arcs=True)
    pitch.draw(ax=ax)

# %%
def calculate_diffe(team_name):
    team_df = df[(df['teamName']==team_name) & (~df['qualifiers'].str.contains('FreeKick|Corner|ThrowIn'))]
    right = team_df[team_df['position'].isin(['DR', 'DMR'])]
    left = team_df[team_df['position'].isin(['DL', 'DML'])]
    
    avg_hr = right['x'].median()
    avg_hl = left['x'].median()
    avg_fb_h = (avg_hr+avg_hl)/2

    dfteam = df[df['teamName'] == team_name]
    cb_df = dfteam[(dfteam['position']=='DC') & (dfteam['type'].str.contains('Pass|TakeOn|BallTouch|BallRecovery|Interception|Error|Clearance|Aerial|Challenge|Foul|BlockedPass|Tackle|OffsideProvoked|Save'))]
    avg_x = cb_df['x'].median()

    diffe = avg_fb_h-avg_x
    return avg_x

def backline(ax, team_name):
    team_df = df[(df['teamName']==team_name) & (~df['qualifiers'].str.contains('FreeKick|Corner|ThrowIn'))]
    right = team_df[team_df['position'].isin(['DR', 'DMR'])]
    left = team_df[team_df['position'].isin(['DL', 'DML'])]
    
    avg_hr = right['x'].median()
    avg_hl = left['x'].median()
    avg_wr = right['y'].median()
    avg_wl = left['y'].median()
    avg_fb_h = (avg_hr+avg_hl)/2
    dist = avg_wl - avg_wr

    pitch = VerticalPitch(pitch_type='uefa', pitch_color=bg_color, linewidth=2, corner_arcs=True)
    pitch.draw(ax=ax)
    ax.set_xlim(68.5, -0.5)
    ax.set_ylim(-0.5, 105.5)
    
    # Plot lines and scatter points for positions
    pitch.lines(avg_hr, avg_wr, avg_hl, avg_wl, color='gray', lw=6, alpha=0.75, zorder=3, ax=ax)
    pitch.scatter(avg_hr, avg_wr, s=300, color=col1, edgecolor='gray', lw=3, zorder=3, ax=ax)
    pitch.scatter(avg_hl, avg_wl, s=300, color=col1, edgecolor='gray', lw=3, zorder=3, ax=ax)

    # Annotate the plot
    ax.text(avg_wr, avg_hr+7.5, 'RB', fontsize=16, fontweight='bold', color=col1, ha='center', va='center',
    fontproperties=custom_font
    )
    ax.text(avg_wl, avg_hl+7.5, 'LB', fontsize=16, fontweight='bold', color=col1, ha='center', va='center',
    fontproperties=custom_font
    )
    ax.hlines(avg_fb_h, xmin=0, xmax=68, color=col1, linestyle='--', linewidth=5, alpha=0.5, label='Avg. Position')
    ax.text(0, avg_fb_h, f'{avg_fb_h:.2f}m', fontsize=12, color=col1, ha='center', va='center', rotation=90,
            bbox=dict(facecolor=bg_color, edgecolor='None', boxstyle='round,pad=0.3'),
            fontproperties=custom_font_thin)
    
    # IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
    # image = Image.open(urlopen(IMAGE_URL))
    # ax_image = pitch.inset_image(52.5, 34, image, height=18, zorder=1, alpha=0.5, ax=ax)

    
    team_df = df[df['teamName'] == team_name]
    match_count = team_df['matchId'].unique()

    cb_counts_per_match = {}

    for match in match_count:
        no_cb = team_df[(team_df['matchId'] == match) & (team_df['position'] == 'DC')]
        no_cb = no_cb['playerName'].unique()
        cb_counts_per_match[match] = len(no_cb)

    # List of CB counts across matches
    cb_counts = list(cb_counts_per_match.values())
    most_common_cb_count = mode(cb_counts)

    if most_common_cb_count == 2:
        dfteam = df[df['teamName'] == team_name]
        cb_df = dfteam[(dfteam['position']=='DC') & (dfteam['type'].str.contains('Pass|TakeOn|BallTouch|BallRecovery|Interception|Error|Clearance|Aerial|Challenge|Foul|BlockedPass|Tackle|OffsideProvoked|Save'))]

        cb_avg = cb_df.groupby('playerName', as_index=False)[['x', 'y']].median()
        lcb = cb_avg[cb_avg['y']>34]
        rcb = cb_avg[cb_avg['y']<34]
        lcb_avg_y = lcb['y'].median()
        rcb_avg_y = rcb['y'].median()
        lcb_avg_x = lcb['x'].median()
        rcb_avg_x = rcb['x'].median()
        avg_x = cb_df['x'].median()
        avg_width = lcb_avg_y - rcb_avg_y
        
        ax.hlines(avg_x, xmin=0, xmax=68, color=col2, linestyle='--', linewidth=5, alpha=0.5, label='Avg. Position')
        ax.text(68, avg_x, f'{avg_x:.2f}m', fontsize=12, color=col2, ha='center', va='center', rotation=-90,
                bbox=dict(facecolor=bg_color, edgecolor='None', boxstyle='round,pad=0.3'),
                fontproperties=custom_font_thin)
        
        ax.scatter(lcb_avg_y, lcb_avg_x, color=col2, edgecolor='gray', zorder=3, linewidth=4, s=300)
        ax.scatter(rcb_avg_y, rcb_avg_x, color=col2, edgecolor='gray', zorder=3, linewidth=4, s=300)
        pitch.lines(lcb_avg_x, lcb_avg_y, rcb_avg_x, rcb_avg_y, color='gray', zorder=2, lw=6, alpha=0.75, ax=ax)
        ax.text(lcb_avg_y, lcb_avg_x-7.5, 'LCB', color=col2, fontsize=16, fontweight='bold', ha='center', va='center',
        fontproperties=custom_font
        )
        ax.text(rcb_avg_y, rcb_avg_x-7.5, 'RCB', color=col2, fontsize=16, fontweight='bold', ha='center', va='center',
        fontproperties=custom_font
        )
        
        pitch.lines(avg_hl, avg_wl, lcb_avg_x, lcb_avg_y, color='gray', zorder=2, lw=6, alpha=0.75, ax=ax)
        pitch.lines(avg_hr, avg_wr, rcb_avg_x, rcb_avg_y, color='gray', zorder=2, lw=6, alpha=0.75, ax=ax)
        
        # ax_text(34, 114, f'<FBs Heigt: {avg_fb_h:.1f}m> | <CBs Height: {avg_x:.1f}m>\nDifference: {(avg_fb_h-avg_x):.1f}m | <CB width: {avg_width:.1f}m>', fontsize=9, 
        #         ha='center', va='center', ax=ax, highlight_textprops=[{'color':col1}, {'color':col2}, {'color':col2}],
        #         #fontproperties=custom_font_thin
        #         )
        ax.text(34, 110, team_name, fontsize=20, fontweight='bold', ha='center', va='center',
        fontproperties=custom_font
        )
        
        # IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
        # image = Image.open(urlopen(IMAGE_URL))
        # ax_image = pitch.inset_image(52.5, 34, image, height=18, alpha=0.5, ax=ax)

    else:
        dfteam = df[df['teamName'] == team_name]
        cb_df = dfteam[(dfteam['position']=='DC') & (dfteam['type'].str.contains('Pass|TakeOn|BallTouch|BallRecovery|Interception|Error|Clearance|Aerial|Challenge|Foul|BlockedPass|Tackle|OffsideProvoked|Save'))]

        cb_avg = cb_df.groupby('playerName', as_index=False)[['x', 'y']].median()
        lcb = cb_avg[cb_avg['y']>43]
        mcb = cb_avg[(cb_avg['y']<43) & (cb_avg['y']>25)]
        rcb = cb_avg[cb_avg['y']<25]
        lcb_avg_y = lcb['y'].median()
        rcb_avg_y = rcb['y'].median()
        mcb_avg_y = mcb['y'].median()
        lcb_avg_x = lcb['x'].median()
        rcb_avg_x = rcb['x'].median()
        mcb_avg_x = mcb['x'].median()
        avg_x = cb_df['x'].median()
        avg_width = lcb_avg_y - rcb_avg_y
        
        ax.hlines(avg_x, xmin=0, xmax=68, color=col2, linestyle='--', linewidth=5, alpha=0.5, label='Avg. Position')
        ax.text(68, avg_x, f'{avg_x:.2f}m', fontsize=12, color=col2, ha='center', va='center', rotation=-90,
                bbox=dict(facecolor=bg_color, edgecolor='None', boxstyle='round,pad=0.3'),
                fontproperties=custom_font_thin)
        
        ax.scatter(lcb_avg_y, lcb_avg_x, color=col2, edgecolor='gray', zorder=3, linewidth=4, s=300)
        ax.scatter(rcb_avg_y, rcb_avg_x, color=col2, edgecolor='gray', zorder=3, linewidth=4, s=300)
        ax.scatter(mcb_avg_y, mcb_avg_x, color=col2, edgecolor='gray', zorder=3, linewidth=4, s=300)
        pitch.lines(lcb_avg_x, lcb_avg_y, mcb_avg_x, mcb_avg_y, color='gray', zorder=2, lw=6, alpha=0.75, ax=ax)
        pitch.lines(rcb_avg_x, rcb_avg_y, mcb_avg_x, mcb_avg_y, color='gray', zorder=2, lw=6, alpha=0.75, ax=ax)
        ax.text(lcb_avg_y, lcb_avg_x-7.5, 'LCB', color=col2, fontsize=16, fontweight='bold', ha='center', va='center',
        fontproperties=custom_font
        )
        ax.text(rcb_avg_y, rcb_avg_x-7.5, 'RCB', color=col2, fontsize=16, fontweight='bold', ha='center', va='center',
        fontproperties=custom_font
        )
        ax.text(mcb_avg_y, mcb_avg_x-7.5, 'CB', color=col2, fontsize=16, fontweight='bold', ha='center', va='center',
        fontproperties=custom_font
        )
        
        pitch.lines(avg_hl, avg_wl, lcb_avg_x, lcb_avg_y, color='gray', zorder=2, lw=6, alpha=0.75, ax=ax)
        pitch.lines(avg_hr, avg_wr, rcb_avg_x, rcb_avg_y, color='gray', zorder=2, lw=6, alpha=0.75, ax=ax)
        
        # ax_text(34, 114, f'<FBs Heigt: {avg_fb_h:.1f}m> | <CBs Height: {avg_x:.1f}m>\nDifference: {(avg_fb_h-avg_x):.1f}m | <CB width: {avg_width:.1f}m>', fontsize=9, 
        #         ha='center', va='center', ax=ax, highlight_textprops=[{'color':col1}, {'color':col2}, {'color':col2}],
        #         #fontproperties=custom_font_thin
        #         )
        ax.text(34, 110, team_name, fontsize=20, fontweight='bold', ha='center', va='center',
        fontproperties=custom_font
        )
        
        # IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
        # image = Image.open(urlopen(IMAGE_URL))
        # ax_image = pitch.inset_image(52.5, 34, image, height=18, alpha=0.5, zorder=1, ax=ax)

# %%
fig, ax = plt.subplots(figsize=(10, 10), facecolor=bg_color)
backline(ax, 'Southampton')

# %%
df.teamName.unique()
# Out:
# array(['Southampton', 'Sheff Wed', 'Rotherham', 'Stoke', 'Millwall',
#        'Middlesbrough', 'Blackburn', 'WBA', 'Watford', 'QPR',
#        'Birmingham', 'Swansea', 'Hull', 'Norwich', 'Bristol City',
#        'Preston', 'Plymouth', 'Huddersfield', 'Ipswich', 'Sunderland',
#        'Leicester', 'Coventry', 'Cardiff', 'Leeds'], dtype=object)

# %%
def generate_defense_line_analysis(league_name):
    # List of team names
    team_names = df.teamName.unique()

    # Create a DataFrame with team names and their diffe values
    team_diffe = pd.DataFrame({'teamName': team_names})
    team_diffe['diffe'] = team_diffe['teamName'].apply(calculate_diffe)

    # Sort the teams by diffe value
    team_avg_x_sorted = team_diffe.sort_values(by='diffe', ascending=False)

    # Create the figure and axes for a 4x5 grid
    fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(24, 30), facecolor=bg_color)

    # Flatten the axes array to easily loop through it
    axes = axes.ravel()

    # Loop through the sorted team names and corresponding axes
    for i, row in enumerate(team_avg_x_sorted.itertuples()):
        team_name = row.teamName
        diffe = row.diffe
        backline(axes[i], team_name)

    if league_name in ['Bundesliga', 'Ligue_1']:
        plot_blank(axes[18])
        plot_blank(axes[19])
    

    fig.text(0.21, 0.98, f"{league_name.replace('_', ' ')} Teams Defense Line Avg. Position", fontsize=32, fontweight='bold', ha='left', va='top',#
            fontproperties=custom_font
            )
    # fig_text(0.21, 0.955, "Teams are sorted by the difference of the avg. Height of <Fullbacks> & <Centerbacks>",
    #          fontsize=20, ha='left', va='top', highlight_textprops=[{'color':col1}, {'color':col2}])
    fig_text(0.21, 0.955, "Considering only Open-Play touches | Teams  sorted by <Centerbacks'> position",
            fontsize=20, ha='left', va='top', highlight_textprops=[{'color':col2}],
            fontproperties=custom_font_thin, color='#080808'
            )
    fig.text(0.21, 0.94, f"Data till GW38 of {league_name.replace('_', ' ')} 2024-25 | made by: @adnaaan433",
            fontsize=17, ha='left', va='top',
            fontproperties=custom_font_thin, color="#1A1A1A"
            )
    # fig.subplots_adjust(wspace=0.0005)

    image_url = f'file:///D:/FData/All_Top_5_League/league_logos/{league_name}_logo.html'
    image = urlopen(image_url)
    image = Image.open(image)
    ax_image = add_image(image, fig, left=0.14, bottom=0.93, width=0.05, height=0.05)

    plt.savefig(f"D:\FData\All_Top_5_League\Analysis\Defense_Line\Defense_Line_{league_name}.png", bbox_inches='tight', dpi=300)

league_names = ['La_Liga', 'Premier_League', 'Serie_A', 'Bundesliga', 'Ligue_1']
for league in league_names:
    df = pd.read_csv(rf"D:\FData\All_Top_5_League\event_data\{league}_2024_25_event_data.csv")
    generate_defense_line_analysis(league)

# %%
# List of team names
team_names = df.teamName.unique()

# Create a DataFrame with team names and their diffe values
team_diffe = pd.DataFrame({'teamName': team_names})
team_diffe['diffe'] = team_diffe['teamName'].apply(calculate_diffe)

# Sort the teams by diffe value
team_avg_x_sorted = team_diffe.sort_values(by='diffe', ascending=False)

# %%
# Create the figure and axes for a 4x5 grid
fig, axes = plt.subplots(nrows=4, ncols=5, figsize=(24, 30), facecolor=bg_color)

# Flatten the axes array to easily loop through it
axes = axes.ravel()

# Loop through the sorted team names and corresponding axes
for i, row in enumerate(team_avg_x_sorted.itertuples()):
    team_name = row.teamName
    diffe = row.diffe
    backline(axes[i], team_name)

# plot_blank(axes[18])
# plot_blank(axes[19])

fig.text(0.21, 0.98, 'La Liga Teams Defense Line Avg. Position', fontsize=32, fontweight='bold', ha='left', va='top',#
         fontproperties=custom_font
         )
# fig_text(0.21, 0.955, "Teams are sorted by the difference of the avg. Height of <Fullbacks> & <Centerbacks>",
#          fontsize=20, ha='left', va='top', highlight_textprops=[{'color':col1}, {'color':col2}])
fig_text(0.21, 0.955, "Considering only Open-Play touches | Teams  sorted by <Centerbacks'> position",
         fontsize=20, ha='left', va='top', highlight_textprops=[{'color':col2}],
         fontproperties=custom_font_thin, color='#080808'
         )
fig.text(0.21, 0.94, "Data till GW38 of La Liga 2024-25 | made by: @adnaaan433",
         fontsize=17, ha='left', va='top',
         fontproperties=custom_font_thin, color="#1A1A1A"
         )
# fig.subplots_adjust(wspace=0.0005)

image_url = 'file:///D:/FData/Leagues_logos/LaLiga%20.html'
image = urlopen(image_url)
image = Image.open(image)
ax_image = add_image(image, fig, left=0.14, bottom=0.93, width=0.05, height=0.05)

# %%
# List of team names
team_names = df.teamName.unique()

# Create a DataFrame with team names and their diffe values
team_diffe = pd.DataFrame({'teamName': team_names})
team_diffe['diffe'] = team_diffe['teamName'].apply(calculate_diffe)

# Sort the teams by diffe value
team_avg_x_sorted = team_diffe.sort_values(by='diffe', ascending=False)

# %%
# Create the figure and axes for a 4x5 grid
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(24, 35), facecolor=bg_color)

# Flatten the axes array to easily loop through it
axes = axes.ravel()

# Loop through the sorted team names and corresponding axes
for i, row in enumerate(team_avg_x_sorted.itertuples()):
    team_name = row.teamName
    diffe = row.diffe
    backline(axes[i], team_name)

plot_blank(axes[24])

fig.text(0.21, 0.98, 'Chmapionship Teams Defense Line Avg. Position', fontsize=34, fontweight='bold', ha='left', va='top',#
         fontproperties=custom_font
         )
# fig_text(0.21, 0.955, "Teams are sorted by the difference of the avg. Height of <Fullbacks> & <Centerbacks>",
#          fontsize=20, ha='left', va='top', highlight_textprops=[{'color':col1}, {'color':col2}])
fig_text(0.21, 0.955, "Considering only Open-Play touches  |  Teams  sorted by <Centerbacks'> position",
         fontsize=22, ha='left', va='top', highlight_textprops=[{'color':col2}],
         fontproperties=custom_font_thin, color='#080808'
         )
fig.text(0.21, 0.94, "Data: Opta  |  Chmapionship 2024-25  |  made by: @adnaaan433",
         fontsize=20, ha='left', va='top',
         fontproperties=custom_font_thin, color="#1A1A1A"
         )
# fig.subplots_adjust(wspace=0.0005)

image_url = 'file:///D:/FData/Leagues_logos/EFL_Championship_Logo.html'
image = urlopen(image_url)
image = Image.open(image)
ax_image = add_image(image, fig, left=0.14, bottom=0.93, width=0.05, height=0.05)

plt.tight_layout()

# %%
# List of team names
team_names = df.teamName.unique()

# Create a DataFrame with team names and their diffe values
team_diffe = pd.DataFrame({'teamName': team_names})
team_diffe['diffe'] = team_diffe['teamName'].apply(calculate_diffe)

# Sort the teams by diffe value
team_avg_x_sorted = team_diffe.sort_values(by='diffe', ascending=False)

# %%
# Create the figure and axes for a 4x5 grid
fig, axes = plt.subplots(nrows=5, ncols=5, figsize=(24, 35), facecolor=bg_color)

# Flatten the axes array to easily loop through it
axes = axes.ravel()

# Loop through the sorted team names and corresponding axes
for i, row in enumerate(team_avg_x_sorted.itertuples()):
    team_name = row.teamName
    diffe = row.diffe
    backline(axes[i], team_name)

plot_blank(axes[24])

fig.text(0.21, 0.98, 'Chmapionship Teams Defense Line Avg. Position', fontsize=34, fontweight='bold', ha='left', va='top',#
         fontproperties=custom_font
         )
# fig_text(0.21, 0.955, "Teams are sorted by the difference of the avg. Height of <Fullbacks> & <Centerbacks>",
#          fontsize=20, ha='left', va='top', highlight_textprops=[{'color':col1}, {'color':col2}])
fig_text(0.21, 0.955, "Considering only Open-Play touches  |  Teams  sorted by <Centerbacks'> position",
         fontsize=22, ha='left', va='top', highlight_textprops=[{'color':col2}],
         fontproperties=custom_font_thin, color='#080808'
         )
fig.text(0.21, 0.94, "Data: Opta  |  Chmapionship 2023-24  |  made by: @adnaaan433",
         fontsize=20, ha='left', va='top',
         fontproperties=custom_font_thin, color="#1A1A1A"
         )
# fig.subplots_adjust(wspace=0.0005)

image_url = 'file:///D:/FData/Leagues_logos/EFL_Championship_Logo.html'
image = urlopen(image_url)
image = Image.open(image)
ax_image = add_image(image, fig, left=0.14, bottom=0.93, width=0.05, height=0.05)

plt.tight_layout()

# %%
# Create the figure and axes for a 4x5 grid
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(13, 15), facecolor=bg_color)

# Flatten the axes array to easily loop through it
axes = axes.ravel()

team_list = ['Leeds', 'Burnley', 'Sunderland']
# Loop through the sorted team names and corresponding axes
for i, team_name in enumerate(team_list):
    backline(axes[i], team_name)

fig.text(0.21, 0.775, 'Championship 2024-25', fontsize=34, fontweight='bold', ha='left', va='top',#
         fontproperties=custom_font
         )
fig.text(0.21, 0.735, "Teams Defense Line Avg. Position",
         fontsize=20, ha='left', va='top',
         fontproperties=custom_font_thin, color="#1A1A1A"
         )
# fig.subplots_adjust(wspace=0.0005)

image_url = 'file:///D:/FData/Leagues_logos/EFL_Championship_Logo.html'
image = urlopen(image_url)
image = Image.open(image)
ax_image = add_image(image, fig, left=0.14, bottom=0.725, width=0.05, height=0.05)

# plt.tight_layout()

# %%
# Create the figure and axes for a 4x5 grid
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(13, 15), facecolor=bg_color)

# Flatten the axes array to easily loop through it
axes = axes.ravel()

team_list = ['Leicester', 'Ipswich', 'Southampton']
# Loop through the sorted team names and corresponding axes
for i, team_name in enumerate(team_list):
    plot_blank(axes[i])

fig.text(0.21, 0.775, 'Premier League 2025-26', fontsize=34, fontweight='bold', ha='left', va='top',#
         fontproperties=custom_font
         )
fig.text(0.21, 0.735, "Teams Defense Line Avg. Position",
         fontsize=20, ha='left', va='top',
         fontproperties=custom_font_thin, color="#1A1A1A"
         )
# fig.subplots_adjust(wspace=0.0005)

image_url = 'file:///D:/FData/All_Top_5_League/league_logos/Premier_League_logo.html'
image = urlopen(image_url)
image = Image.open(image)
ax_image = add_image(image, fig, left=0.14, bottom=0.725, width=0.05, height=0.05)

# plt.tight_layout()
