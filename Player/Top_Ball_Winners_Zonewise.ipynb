# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.markers import MarkerStyle
from mplsoccer.pitch import Pitch
from mplsoccer import Pitch, VerticalPitch
import matplotlib.patches as patches
from collections import Counter
import matplotlib.patheffects as path_effects

import matplotlib.cm as cm
import matplotlib.colors as mcolors

from highlight_text import ax_text, fig_text
from PIL import Image
from mplsoccer import add_image
import urllib
from urllib.request import urlopen

from matplotlib.font_manager import FontProperties

pd.set_option('display.max_columns', None)

# %%
col1 = '#f659fd'
col2 = '#33efff'
bg_color = '#060F38'
line_color = '#ffffff'
green = '#69f900'
red = '#ff4b44'

# %%
df = pd.read_csv(r"D:\FData\UCL\UCL_2024_25\till_mw5.csv")

# %%
df = pd.read_csv(r"D:\FData\LaLiga_2024_25\till_gw11.csv")

# %%
df = pd.read_csv(r"D:\FData\Serie_A_2024_25\till_gw12.csv")

# %%
df_pc = df[((df['type']=='BallRecovery') | (df['type']=='Interception'))]

# %%
df_pc = df[((df['type']=='Tackle') | (df['type']=='Interception')) & (df['outcomeType']=='Successful')]

# %%
df_pc = df[df['type']=='Tackle']

# %% [markdown]
# # Data Processing

# %%
df00 = df_pc[(df_pc['x']>((0*105)/6)) & (df_pc['x']<=((1*105)/6)) & (df_pc['y']>((0*68)/5)) & (df_pc['y']<=((1*68)/5))]
df01 = df_pc[(df_pc['x']>((0*105)/6)) & (df_pc['x']<=((1*105)/6)) & (df_pc['y']>((1*68)/5)) & (df_pc['y']<=((2*68)/5))]
df02 = df_pc[(df_pc['x']>((0*105)/6)) & (df_pc['x']<=((1*105)/6)) & (df_pc['y']>((2*68)/5)) & (df_pc['y']<=((3*68)/5))]
df03 = df_pc[(df_pc['x']>((0*105)/6)) & (df_pc['x']<=((1*105)/6)) & (df_pc['y']>((3*68)/5)) & (df_pc['y']<=((4*68)/5))]
df04 = df_pc[(df_pc['x']>((0*105)/6)) & (df_pc['x']<=((1*105)/6)) & (df_pc['y']>((4*68)/5)) & (df_pc['y']<=((5*68)/5))]

df10 = df_pc[(df_pc['x']>((1*105)/6)) & (df_pc['x']<=((2*105)/6)) & (df_pc['y']>((0*68)/5)) & (df_pc['y']<=((1*68)/5))]
df11 = df_pc[(df_pc['x']>((1*105)/6)) & (df_pc['x']<=((2*105)/6)) & (df_pc['y']>((1*68)/5)) & (df_pc['y']<=((2*68)/5))]
df12 = df_pc[(df_pc['x']>((1*105)/6)) & (df_pc['x']<=((2*105)/6)) & (df_pc['y']>((2*68)/5)) & (df_pc['y']<=((3*68)/5))]
df13 = df_pc[(df_pc['x']>((1*105)/6)) & (df_pc['x']<=((2*105)/6)) & (df_pc['y']>((3*68)/5)) & (df_pc['y']<=((4*68)/5))]
df14 = df_pc[(df_pc['x']>((1*105)/6)) & (df_pc['x']<=((2*105)/6)) & (df_pc['y']>((4*68)/5)) & (df_pc['y']<=((5*68)/5))]

df20 = df_pc[(df_pc['x']>((2*105)/6)) & (df_pc['x']<=((3*105)/6)) & (df_pc['y']>((0*68)/5)) & (df_pc['y']<=((3*68)/5))]
df21 = df_pc[(df_pc['x']>((2*105)/6)) & (df_pc['x']<=((3*105)/6)) & (df_pc['y']>((1*68)/5)) & (df_pc['y']<=((2*68)/5))]
df22 = df_pc[(df_pc['x']>((2*105)/6)) & (df_pc['x']<=((3*105)/6)) & (df_pc['y']>((2*68)/5)) & (df_pc['y']<=((3*68)/5))]
df23 = df_pc[(df_pc['x']>((2*105)/6)) & (df_pc['x']<=((3*105)/6)) & (df_pc['y']>((3*68)/5)) & (df_pc['y']<=((4*68)/5))]
df24 = df_pc[(df_pc['x']>((2*105)/6)) & (df_pc['x']<=((3*105)/6)) & (df_pc['y']>((4*68)/5)) & (df_pc['y']<=((5*68)/5))]

df30 = df_pc[(df_pc['x']>((3*105)/6)) & (df_pc['x']<=((4*105)/6)) & (df_pc['y']>((0*68)/5)) & (df_pc['y']<=((1*68)/5))]
df31 = df_pc[(df_pc['x']>((3*105)/6)) & (df_pc['x']<=((4*105)/6)) & (df_pc['y']>((1*68)/5)) & (df_pc['y']<=((2*68)/5))]
df32 = df_pc[(df_pc['x']>((3*105)/6)) & (df_pc['x']<=((4*105)/6)) & (df_pc['y']>((2*68)/5)) & (df_pc['y']<=((3*68)/5))]
df33 = df_pc[(df_pc['x']>((3*105)/6)) & (df_pc['x']<=((4*105)/6)) & (df_pc['y']>((3*68)/5)) & (df_pc['y']<=((4*68)/5))]
df34 = df_pc[(df_pc['x']>((3*105)/6)) & (df_pc['x']<=((4*105)/6)) & (df_pc['y']>((4*68)/5)) & (df_pc['y']<=((5*68)/5))]

df40 = df_pc[(df_pc['x']>((4*105)/6)) & (df_pc['x']<=((5*105)/6)) & (df_pc['y']>((0*68)/5)) & (df_pc['y']<=((1*68)/5))]
df41 = df_pc[(df_pc['x']>((4*105)/6)) & (df_pc['x']<=((5*105)/6)) & (df_pc['y']>((1*68)/5)) & (df_pc['y']<=((2*68)/5))]
df42 = df_pc[(df_pc['x']>((4*105)/6)) & (df_pc['x']<=((5*105)/6)) & (df_pc['y']>((2*68)/5)) & (df_pc['y']<=((3*68)/5))]
df43 = df_pc[(df_pc['x']>((4*105)/6)) & (df_pc['x']<=((5*105)/6)) & (df_pc['y']>((3*68)/5)) & (df_pc['y']<=((4*68)/5))]
df44 = df_pc[(df_pc['x']>((4*105)/6)) & (df_pc['x']<=((5*105)/6)) & (df_pc['y']>((4*68)/5)) & (df_pc['y']<=((5*68)/5))]

df50 = df_pc[(df_pc['x']>((5*105)/6)) & (df_pc['x']<=((6*105)/6)) & (df_pc['y']>((0*68)/5)) & (df_pc['y']<=((1*68)/5))]
df51 = df_pc[(df_pc['x']>((5*105)/6)) & (df_pc['x']<=((6*105)/6)) & (df_pc['y']>((1*68)/5)) & (df_pc['y']<=((2*68)/5))]
df52 = df_pc[(df_pc['x']>((5*105)/6)) & (df_pc['x']<=((6*105)/6)) & (df_pc['y']>((2*68)/5)) & (df_pc['y']<=((3*68)/5))]
df53 = df_pc[(df_pc['x']>((5*105)/6)) & (df_pc['x']<=((6*105)/6)) & (df_pc['y']>((3*68)/5)) & (df_pc['y']<=((4*68)/5))]
df54 = df_pc[(df_pc['x']>((5*105)/6)) & (df_pc['x']<=((6*105)/6)) & (df_pc['y']>((4*68)/5)) & (df_pc['y']<=((5*68)/5))]

# %%
df00_BW = df00.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df00_BW = df00_BW.reset_index(drop=False)
df00_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df00_BW = df00_BW.sort_values(by='Ball_Win', ascending=False)
df00_BW = df00_BW.head(3).reset_index(drop=True)
df00_BW
# Out:
#            name  Ball_Win     teamName   shortName
# 0    Adam Smith         1  Bournemouth    A. Smith
# 1  Ashley Young         1      Everton    A. Young
# 2   Ben Godfrey         1      Everton  B. Godfrey

# %%
df01_BW = df01.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df01_BW = df01_BW.reset_index(drop=False)
df01_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df01_BW = df01_BW.sort_values(by='Ball_Win', ascending=False)
df01_BW = df01_BW.head(3).reset_index(drop=True)
df01_BW
# Out:
#               name  Ball_Win        teamName  shortName
# 0  Vladimír Coufal         8        West Ham  V. Coufal
# 1        Joel Ward         7  Crystal Palace    J. Ward
# 2     Jayden Bogle         6       Sheff Utd   J. Bogle

# %%
df02_BW = df02.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df02_BW = df02_BW.reset_index(drop=False)
df02_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df02_BW = df02_BW.sort_values(by='Ball_Win', ascending=False)
df02_BW = df02_BW.head(3).reset_index(drop=True)
df02_BW
# Out:
#                 name  Ball_Win        teamName    shortName
# 0   Joachim Andersen        23  Crystal Palace  J. Andersen
# 1  Guglielmo Vicario        19       Tottenham   G. Vicario
# 2  Maximilian Kilman        19          Wolves    M. Kilman

# %%
df03_BW = df03.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df03_BW = df03_BW.reset_index(drop=False)
df03_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df03_BW = df03_BW.sort_values(by='Ball_Win', ascending=False)
df03_BW = df03_BW.head(3).reset_index(drop=True)
df03_BW
# Out:
#                 name  Ball_Win     teamName     shortName
# 0    Virgil van Dijk         5    Liverpool    V. v. Dijk
# 1  Gabriel Magalhães         5      Arsenal  G. Magalhães
# 2        Lucas Digne         4  Aston Villa      L. Digne

# %%
df04_BW = df04.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df04_BW = df04_BW.reset_index(drop=False)
df04_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df04_BW = df04_BW.sort_values(by='Ball_Win', ascending=False)
df04_BW = df04_BW.head(3).reset_index(drop=True)
df04_BW
# Out:
#                name  Ball_Win     teamName    shortName
# 0  Antonee Robinson         2       Fulham  A. Robinson
# 1    Dango Ouattara         2  Bournemouth  D. Ouattara
# 2     Marcos Senesi         1  Bournemouth    M. Senesi

# %%
df10_BW = df10.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df10_BW = df10_BW.reset_index(drop=False)
df10_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df10_BW = df10_BW.sort_values(by='Ball_Win', ascending=False)
df10_BW = df10_BW.head(3).reset_index(drop=True)
df10_BW
# Out:
#                name  Ball_Win        teamName    shortName
# 0  Timothy Castagne         8          Fulham  T. Castagne
# 1         Joel Ward         6  Crystal Palace      J. Ward
# 2   Vladimír Coufal         6        West Ham    V. Coufal

# %%
df11_BW = df11.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df11_BW = df11_BW.reset_index(drop=False)
df11_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df11_BW = df11_BW.sort_values(by='Ball_Win', ascending=False)
df11_BW = df11_BW.head(3).reset_index(drop=True)
df11_BW
# Out:
#               name  Ball_Win   teamName     shortName
# 0  James Tarkowski        12    Everton  J. Tarkowski
# 1  Cristian Romero        11  Tottenham     C. Romero
# 2  Ibrahima Konaté        11  Liverpool     I. Konaté

# %%
df12_BW = df12.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df12_BW = df12_BW.reset_index(drop=False)
df12_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df12_BW = df12_BW.sort_values(by='Ball_Win', ascending=False)
df12_BW = df12_BW.head(3).reset_index(drop=True)
df12_BW
# Out:
#                  name  Ball_Win        teamName       shortName
# 0    Joachim Andersen         7  Crystal Palace     J. Andersen
# 1  Jarrad Branthwaite         5         Everton  J. Branthwaite
# 2       Ethan Pinnock         5       Brentford      E. Pinnock

# %%
df13_BW = df13.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df13_BW = df13_BW.reset_index(drop=False)
df13_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df13_BW = df13_BW.sort_values(by='Ball_Win', ascending=False)
df13_BW = df13_BW.head(3).reset_index(drop=True)
df13_BW
# Out:
#                  name  Ball_Win   teamName       shortName
# 0     Virgil van Dijk        17  Liverpool      V. v. Dijk
# 1  Jarrad Branthwaite        15    Everton  J. Branthwaite
# 2   Gabriel Magalhães        14    Arsenal    G. Magalhães

# %%
df14_BW = df14.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df14_BW = df14_BW.reset_index(drop=False)
df14_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df14_BW = df14_BW.sort_values(by='Ball_Win', ascending=False)
df14_BW = df14_BW.head(3).reset_index(drop=True)
df14_BW
# Out:
#                  name  Ball_Win     teamName       shortName
# 0    Antonee Robinson        10       Fulham     A. Robinson
# 1  Jarrad Branthwaite         8      Everton  J. Branthwaite
# 2         Lucas Digne         8  Aston Villa        L. Digne

# %%
df20_BW = df20.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df20_BW = df20_BW.reset_index(drop=False)
df20_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df20_BW = df20_BW.sort_values(by='Ball_Win', ascending=False)
df20_BW = df20_BW.head(3).reset_index(drop=True)
df20_BW
# Out:
#                  name  Ball_Win   teamName        shortName
# 0     Ibrahima Konaté        36  Liverpool        I. Konaté
# 1         Dara O'Shea        26    Burnley        D. O'Shea
# 2  Jan Paul van Hecke        25   Brighton  J. P. van Hecke

# %%
df21_BW = df21.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df21_BW = df21_BW.reset_index(drop=False)
df21_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df21_BW = df21_BW.sort_values(by='Ball_Win', ascending=False)
df21_BW = df21_BW.head(3).reset_index(drop=True)
df21_BW
# Out:
#               name  Ball_Win   teamName  shortName
# 0  Ibrahima Konaté        20  Liverpool  I. Konaté
# 1  Cristian Romero        16  Tottenham  C. Romero
# 2      Dara O'Shea        15    Burnley  D. O'Shea

# %%
df22_BW = df22.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df22_BW = df22_BW.reset_index(drop=False)
df22_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df22_BW = df22_BW.sort_values(by='Ball_Win', ascending=False)
df22_BW = df22_BW.head(3).reset_index(drop=True)
df22_BW
# Out:
#                  name  Ball_Win        teamName       shortName
# 0  Jarrad Branthwaite         9         Everton  J. Branthwaite
# 1     Virgil van Dijk         8       Liverpool      V. v. Dijk
# 2    Joachim Andersen         8  Crystal Palace     J. Andersen

# %%
df23_BW = df23.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df23_BW = df23_BW.reset_index(drop=False)
df23_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df23_BW = df23_BW.sort_values(by='Ball_Win', ascending=False)
df23_BW = df23_BW.head(3).reset_index(drop=True)
df23_BW
# Out:
#                  name  Ball_Win   teamName       shortName
# 0     Virgil van Dijk        22  Liverpool      V. v. Dijk
# 1       Ethan Pinnock        16  Brentford      E. Pinnock
# 2  Jarrad Branthwaite        15    Everton  J. Branthwaite

# %%
df24_BW = df24.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df24_BW = df24_BW.reset_index(drop=False)
df24_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df24_BW = df24_BW.sort_values(by='Ball_Win', ascending=False)
df24_BW = df24_BW.head(3).reset_index(drop=True)
df24_BW
# Out:
#               name  Ball_Win   teamName   shortName
# 0    Lucas Paquetá        13   West Ham  L. Paquetá
# 1  Virgil van Dijk        11  Liverpool  V. v. Dijk
# 2         Dan Burn        11  Newcastle     D. Burn

# %%
df30_BW = df30.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df30_BW = df30_BW.reset_index(drop=False)
df30_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df30_BW = df30_BW.sort_values(by='Ball_Win', ascending=False)
df30_BW = df30_BW.head(3).reset_index(drop=True)
df30_BW
# Out:
#               name  Ball_Win           teamName    shortName
# 0  Antoine Semenyo        20        Bournemouth   A. Semenyo
# 1  Oliver McBurnie        15          Sheff Utd  O. McBurnie
# 2     Sèrge Aurier        14  Nottingham Forest    S. Aurier

# %%
df31_BW = df31.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df31_BW = df31_BW.reset_index(drop=False)
df31_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df31_BW = df31_BW.sort_values(by='Ball_Win', ascending=False)
df31_BW = df31_BW.head(3).reset_index(drop=True)
df31_BW
# Out:
#                     name  Ball_Win   teamName         shortName
# 0  Dominic Calvert-Lewin        14    Everton  D. Calvert-Lewin
# 1        Oliver McBurnie        13  Sheff Utd       O. McBurnie
# 2         Carlton Morris        13      Luton         C. Morris

# %%
df32_BW = df32.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df32_BW = df32_BW.reset_index(drop=False)
df32_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df32_BW = df32_BW.sort_values(by='Ball_Win', ascending=False)
df32_BW = df32_BW.head(3).reset_index(drop=True)
df32_BW
# Out:
#                     name  Ball_Win     teamName         shortName
# 0        Nicolas Jackson         7      Chelsea        N. Jackson
# 1  Dominic Calvert-Lewin         7      Everton  D. Calvert-Lewin
# 2          Ollie Watkins         5  Aston Villa        O. Watkins

# %%
df33_BW = df33.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df33_BW = df33_BW.reset_index(drop=False)
df33_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df33_BW = df33_BW.sort_values(by='Ball_Win', ascending=False)
df33_BW = df33_BW.head(3).reset_index(drop=True)
df33_BW
# Out:
#               name  Ball_Win   teamName    shortName
# 0  Oliver McBurnie        12  Sheff Utd  O. McBurnie
# 1       Ivan Toney         9  Brentford     I. Toney
# 2   Carlton Morris         9      Luton    C. Morris

# %%
df34_BW = df34.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df34_BW = df34_BW.reset_index(drop=False)
df34_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df34_BW = df34_BW.sort_values(by='Ball_Win', ascending=False)
df34_BW = df34_BW.head(3).reset_index(drop=True)
df34_BW
# Out:
#                     name  Ball_Win   teamName         shortName
# 0               Dan Burn        10  Newcastle           D. Burn
# 1             Ivan Toney         9  Brentford          I. Toney
# 2  Dominic Calvert-Lewin         8    Everton  D. Calvert-Lewin

# %%
df40_BW = df40.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df40_BW = df40_BW.reset_index(drop=False)
df40_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df40_BW = df40_BW.sort_values(by='Ball_Win', ascending=False)
df40_BW = df40_BW.head(3).reset_index(drop=True)
df40_BW
# Out:
#                     name  Ball_Win   teamName         shortName
# 0        Oliver McBurnie         9  Sheff Utd       O. McBurnie
# 1         Carlton Morris         7      Luton         C. Morris
# 2  Dominic Calvert-Lewin         6    Everton  D. Calvert-Lewin

# %%
df41_BW = df41.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df41_BW = df41_BW.reset_index(drop=False)
df41_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df41_BW = df41_BW.sort_values(by='Ball_Win', ascending=False)
df41_BW = df41_BW.head(3).reset_index(drop=True)
df41_BW
# Out:
#                     name  Ball_Win teamName         shortName
# 0  Dominic Calvert-Lewin        21  Everton  D. Calvert-Lewin
# 1         Carlton Morris        11    Luton         C. Morris
# 2        James Tarkowski         9  Everton      J. Tarkowski

# %%
df42_BW = df42.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df42_BW = df42_BW.reset_index(drop=False)
df42_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df42_BW = df42_BW.sort_values(by='Ball_Win', ascending=False)
df42_BW = df42_BW.head(3).reset_index(drop=True)
df42_BW
# Out:
#                     name  Ball_Win   teamName         shortName
# 0  Dominic Calvert-Lewin        11    Everton  D. Calvert-Lewin
# 1           Amadou Onana         5    Everton          A. Onana
# 2             Ivan Toney         4  Brentford          I. Toney

# %%
df43_BW = df43.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df43_BW = df43_BW.reset_index(drop=False)
df43_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df43_BW = df43_BW.sort_values(by='Ball_Win', ascending=False)
df43_BW = df43_BW.head(3).reset_index(drop=True)
df43_BW
# Out:
#                     name  Ball_Win teamName         shortName
# 0  Dominic Calvert-Lewin         9  Everton  D. Calvert-Lewin
# 1                   Beto         8  Everton              Beto
# 2            Kai Havertz         7  Arsenal        K. Havertz

# %%
df44_BW = df44.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df44_BW = df44_BW.reset_index(drop=False)
df44_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df44_BW = df44_BW.sort_values(by='Ball_Win', ascending=False)
df44_BW = df44_BW.head(3).reset_index(drop=True)
df44_BW
# Out:
#              name  Ball_Win           teamName  shortName
# 0      Chris Wood         7  Nottingham Forest    C. Wood
# 1  Carlton Morris         5              Luton  C. Morris
# 2     Lucas Digne         5        Aston Villa   L. Digne

# %%
df50_BW = df50.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df50_BW = df50_BW.reset_index(drop=False)
df50_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df50_BW = df50_BW.sort_values(by='Ball_Win', ascending=False)
df50_BW = df50_BW.head(3).reset_index(drop=True)
df50_BW
# Out:
#            name  Ball_Win           teamName  shortName
# 0   Issa Kaboré         2              Luton  I. Kaboré
# 1  Jarrod Bowen         2           West Ham   J. Bowen
# 2    Ryan Yates         2  Nottingham Forest   R. Yates

# %%
df51_BW = df51.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df51_BW = df51_BW.reset_index(drop=False)
df51_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df51_BW = df51_BW.sort_values(by='Ball_Win', ascending=False)
df51_BW = df51_BW.head(3).reset_index(drop=True)
df51_BW
# Out:
#                 name  Ball_Win           teamName     shortName
# 0    James Tarkowski        13            Everton  J. Tarkowski
# 1        Dara O'Shea        11            Burnley     D. O'Shea
# 2  Willy-Arnaud Boly         8  Nottingham Forest       W. Boly

# %%
df52_BW = df52.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df52_BW = df52_BW.reset_index(drop=False)
df52_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df52_BW = df52_BW.sort_values(by='Ball_Win', ascending=False)
df52_BW = df52_BW.head(3).reset_index(drop=True)
df52_BW
# Out:
#               name  Ball_Win   teamName   shortName
# 0  Virgil van Dijk        30  Liverpool  V. v. Dijk
# 1    Rodrigo Muniz        22     Fulham    R. Muniz
# 2   Carlton Morris        20      Luton   C. Morris

# %%
df53_BW = df53.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df53_BW = df53_BW.reset_index(drop=False)
df53_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df53_BW = df53_BW.sort_values(by='Ball_Win', ascending=False)
df53_BW = df53_BW.head(3).reset_index(drop=True)
df53_BW
# Out:
#               name  Ball_Win  teamName     shortName
# 0  James Tarkowski        13   Everton  J. Tarkowski
# 1   Carlton Morris         7     Luton     C. Morris
# 2       João Pedro         5  Brighton      J. Pedro

# %%
df54_BW = df54.groupby('name').agg({'type': ['count'], 'teamName': 'max', 'shortName': 'max'})
df54_BW = df54_BW.reset_index(drop=False)
df54_BW.columns = ['name','Ball_Win', 'teamName', 'shortName']
df54_BW = df54_BW.sort_values(by='Ball_Win', ascending=False)
df54_BW = df54_BW.head(3).reset_index(drop=True)
df54_BW
# Out:
#                    name  Ball_Win        teamName     shortName
# 0        Andy Robertson         1       Liverpool  A. Robertson
# 1  Jean-Philippe Mateta         1  Crystal Palace     J. Mateta
# 2       Rayan Aït-Nouri         1          Wolves  R. Aït-Nouri

# %% [markdown]
# # VIZ

# %%
def zone_wise_threat_crators(ax):
    pitch = Pitch(pitch_type='uefa', corner_arcs=True, pitch_color='#f5f5f5', line_color='k', linewidth=3)
    pitch.draw(ax=ax)
    ax.vlines(((1*105)/6), ymin=0, ymax=68, color='gray', zorder=50)
    ax.vlines(((2*105)/6), ymin=0, ymax=68, color='gray', zorder=50)
    ax.vlines(((3*105)/6), ymin=0, ymax=68, color='gray', zorder=50)
    ax.vlines(((4*105)/6), ymin=0, ymax=68, color='gray', zorder=50)
    ax.vlines(((5*105)/6), ymin=0, ymax=68, color='gray', zorder=50)

    ax.hlines(((1*68)/5), xmin=0, xmax=105, color='gray', zorder=50)
    ax.hlines(((2*68)/5), xmin=0, xmax=105, color='gray', zorder=50)
    ax.hlines(((3*68)/5), xmin=0, xmax=105, color='gray', zorder=50)
    ax.hlines(((4*68)/5), xmin=0, xmax=105, color='gray', zorder=50)

    bbox_props = dict(boxstyle="round,pad=0.3", edgecolor="None", facecolor='#f5f5f5', alpha=0.75)

    df00_name1 = df00_BW['shortName'][0]
    df00_BW_value1 = df00_BW['Ball_Win'][0].round(2)
    df00_name2 = df00_BW['shortName'][1]
    df00_BW_value2 = df00_BW['Ball_Win'][1].round(2)
    df00_name3 = df00_BW['shortName'][2]
    df00_BW_value3 = df00_BW['Ball_Win'][2].round(2)
    ax.text(8.75, 6.8, f'{df00_name1}: {df00_BW_value1}\n\n{df00_name2}: {df00_BW_value2}\n\n{df00_name3}: {df00_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df01_name1 = df01_BW['shortName'][0]
    df01_BW_value1 = df01_BW['Ball_Win'][0].round(2)
    df01_name2 = df01_BW['shortName'][1]
    df01_BW_value2 = df01_BW['Ball_Win'][1].round(2)
    df01_name3 = df01_BW['shortName'][2]
    df01_BW_value3 = df01_BW['Ball_Win'][2].round(2)
    ax.text(8.75, 20.4, f'{df01_name1}: {df01_BW_value1}\n\n{df01_name2}: {df01_BW_value2}\n\n{df01_name3}: {df01_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df02_name1 = df02_BW['shortName'][0]
    df02_BW_value1 = df02_BW['Ball_Win'][0].round(2)
    df02_name2 = df02_BW['shortName'][1]
    df02_BW_value2 = df02_BW['Ball_Win'][1].round(2)
    df02_name3 = df02_BW['shortName'][2]
    df02_BW_value3 = df02_BW['Ball_Win'][2].round(2)
    ax.text(8.75, 34, f'{df02_name1}: {df02_BW_value1}\n\n{df02_name2}: {df02_BW_value2}\n\n{df02_name3}: {df02_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df03_name1 = df03_BW['shortName'][0]
    df03_BW_value1 = df03_BW['Ball_Win'][0].round(2)
    df03_name2 = df03_BW['shortName'][1]
    df03_BW_value2 = df03_BW['Ball_Win'][1].round(2)
    df03_name3 = df03_BW['shortName'][2]
    df03_BW_value3 = df03_BW['Ball_Win'][2].round(2)
    ax.text(8.75, 47.6, f'{df03_name1}: {df03_BW_value1}\n\n{df03_name2}: {df03_BW_value2}\n\n{df03_name3}: {df03_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df04_name1 = df04_BW['shortName'][0]
    df04_BW_value1 = df04_BW['Ball_Win'][0].round(2)
    df04_name2 = df04_BW['shortName'][1]
    df04_BW_value2 = df04_BW['Ball_Win'][1].round(2)
    df04_name3 = df04_BW['shortName'][2]
    df04_BW_value3 = df04_BW['Ball_Win'][2].round(2)
    ax.text(8.75, 61.2, f'{df04_name1}: {df04_BW_value1}\n\n{df04_name2}: {df04_BW_value2}\n\n{df04_name3}: {df04_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)






    df10_name1 = df10_BW['shortName'][0]
    df10_BW_value1 = df10_BW['Ball_Win'][0].round(2)
    df10_name2 = df10_BW['shortName'][1]
    df10_BW_value2 = df10_BW['Ball_Win'][1].round(2)
    df10_name3 = df10_BW['shortName'][2]
    df10_BW_value3 = df10_BW['Ball_Win'][2].round(2)
    ax.text(26.25, 6.8, f'{df10_name1}: {df10_BW_value1}\n\n{df10_name2}: {df10_BW_value2}\n\n{df10_name3}: {df10_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df11_name1 = df11_BW['shortName'][0]
    df11_BW_value1 = df11_BW['Ball_Win'][0].round(2)
    df11_name2 = df11_BW['shortName'][1]
    df11_BW_value2 = df11_BW['Ball_Win'][1].round(2)
    df11_name3 = df11_BW['shortName'][2]
    df11_BW_value3 = df11_BW['Ball_Win'][2].round(2)
    ax.text(26.25, 20.4, f'{df11_name1}: {df11_BW_value1}\n\n{df11_name2}: {df11_BW_value2}\n\n{df11_name3}: {df11_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df12_name1 = df12_BW['shortName'][0]
    df12_BW_value1 = df12_BW['Ball_Win'][0].round(2)
    df12_name2 = df12_BW['shortName'][1]
    df12_BW_value2 = df12_BW['Ball_Win'][1].round(2)
    df12_name3 = df12_BW['shortName'][2]
    df12_BW_value3 = df12_BW['Ball_Win'][2].round(2)
    ax.text(26.25, 34, f'{df12_name1}: {df12_BW_value1}\n\n{df12_name2}: {df12_BW_value2}\n\n{df12_name3}: {df12_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df13_name1 = df13_BW['shortName'][0]
    df13_BW_value1 = df13_BW['Ball_Win'][0].round(2)
    df13_name2 = df13_BW['shortName'][1]
    df13_BW_value2 = df13_BW['Ball_Win'][1].round(2)
    df13_name3 = df13_BW['shortName'][2]
    df13_BW_value3 = df13_BW['Ball_Win'][2].round(2)
    ax.text(26.25, 47.6, f'{df13_name1}: {df13_BW_value1}\n\n{df13_name2}: {df13_BW_value2}\n\n{df13_name3}: {df13_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df14_name1 = df14_BW['shortName'][0]
    df14_BW_value1 = df14_BW['Ball_Win'][0].round(2)
    df14_name2 = df14_BW['shortName'][1]
    df14_BW_value2 = df14_BW['Ball_Win'][1].round(2)
    df14_name3 = df14_BW['shortName'][2]
    df14_BW_value3 = df14_BW['Ball_Win'][2].round(2)
    ax.text(26.25, 61.2, f'{df14_name1}: {df14_BW_value1}\n\n{df14_name2}: {df14_BW_value2}\n\n{df14_name3}: {df14_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)








    df20_name1 = df20_BW['shortName'][0]
    df20_BW_value1 = df20_BW['Ball_Win'][0].round(2)
    df20_name2 = df20_BW['shortName'][1]
    df20_BW_value2 = df20_BW['Ball_Win'][1].round(2)
    df20_name3 = df20_BW['shortName'][2]
    df20_BW_value3 = df20_BW['Ball_Win'][2].round(2)
    ax.text(43.75, 6.8, f'{df20_name1}: {df20_BW_value1}\n\n{df20_name2}: {df20_BW_value2}\n\n{df20_name3}: {df20_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df21_name1 = df21_BW['shortName'][0]
    df21_BW_value1 = df21_BW['Ball_Win'][0].round(2)
    df21_name2 = df21_BW['shortName'][1]
    df21_BW_value2 = df21_BW['Ball_Win'][1].round(2)
    df21_name3 = df21_BW['shortName'][2]
    df21_BW_value3 = df21_BW['Ball_Win'][2].round(2)
    ax.text(43.75, 20.4, f'{df21_name1}: {df21_BW_value1}\n\n{df21_name2}: {df21_BW_value2}\n\n{df21_name3}: {df21_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df22_name1 = df22_BW['shortName'][0]
    df22_BW_value1 = df22_BW['Ball_Win'][0].round(2)
    df22_name2 = df22_BW['shortName'][1]
    df22_BW_value2 = df22_BW['Ball_Win'][1].round(2)
    df22_name3 = df22_BW['shortName'][2]
    df22_BW_value3 = df22_BW['Ball_Win'][2].round(2)
    ax.text(43.75, 34, f'{df22_name1}: {df22_BW_value1}\n\n{df22_name2}: {df22_BW_value2}\n\n{df22_name3}: {df22_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df23_name1 = df23_BW['shortName'][0]
    df23_BW_value1 = df23_BW['Ball_Win'][0].round(2)
    df23_name2 = df23_BW['shortName'][1]
    df23_BW_value2 = df23_BW['Ball_Win'][1].round(2)
    df23_name3 = df23_BW['shortName'][2]
    df23_BW_value3 = df23_BW['Ball_Win'][2].round(2)
    ax.text(43.75, 47.6, f'{df23_name1}: {df23_BW_value1}\n\n{df23_name2}: {df23_BW_value2}\n\n{df23_name3}: {df23_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df24_name1 = df24_BW['shortName'][0]
    df24_BW_value1 = df24_BW['Ball_Win'][0].round(2)
    df24_name2 = df24_BW['shortName'][1]
    df24_BW_value2 = df24_BW['Ball_Win'][1].round(2)
    df24_name3 = df24_BW['shortName'][2]
    df24_BW_value3 = df24_BW['Ball_Win'][2].round(2)
    ax.text(43.75, 61.2, f'{df24_name1}: {df24_BW_value1}\n\n{df24_name2}: {df24_BW_value2}\n\n{df24_name3}: {df24_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)







    df30_name1 = df30_BW['shortName'][0]
    df30_BW_value1 = df30_BW['Ball_Win'][0].round(2)
    df30_name2 = df30_BW['shortName'][1]
    df30_BW_value2 = df30_BW['Ball_Win'][1].round(2)
    df30_name3 = df30_BW['shortName'][2]
    df30_BW_value3 = df30_BW['Ball_Win'][2].round(2)
    ax.text(61.25, 6.8, f'{df30_name1}: {df30_BW_value1}\n\n{df30_name2}: {df30_BW_value2}\n\n{df30_name3}: {df30_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df31_name1 = df31_BW['shortName'][0]
    df31_BW_value1 = df31_BW['Ball_Win'][0].round(2)
    df31_name2 = df31_BW['shortName'][1]
    df31_BW_value2 = df31_BW['Ball_Win'][1].round(2)
    df31_name3 = df31_BW['shortName'][2]
    df31_BW_value3 = df31_BW['Ball_Win'][2].round(2)
    ax.text(61.25, 20.4, f'{df31_name1}: {df31_BW_value1}\n\n{df31_name2}: {df31_BW_value2}\n\n{df31_name3}: {df31_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df32_name1 = df32_BW['shortName'][0]
    df32_BW_value1 = df32_BW['Ball_Win'][0].round(2)
    df32_name2 = df32_BW['shortName'][1]
    df32_BW_value2 = df32_BW['Ball_Win'][1].round(2)
    df32_name3 = df32_BW['shortName'][2]
    df32_BW_value3 = df32_BW['Ball_Win'][2].round(2)
    ax.text(61.25, 34, f'{df32_name1}: {df32_BW_value1}\n\n{df32_name2}: {df32_BW_value2}\n\n{df32_name3}: {df32_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df33_name1 = df33_BW['shortName'][0]
    df33_BW_value1 = df33_BW['Ball_Win'][0].round(2)
    df33_name2 = df33_BW['shortName'][1]
    df33_BW_value2 = df33_BW['Ball_Win'][1].round(2)
    df33_name3 = df33_BW['shortName'][2]
    df33_BW_value3 = df33_BW['Ball_Win'][2].round(2)
    ax.text(61.25, 47.6, f'{df33_name1}: {df33_BW_value1}\n\n{df33_name2}: {df33_BW_value2}\n\n{df33_name3}: {df33_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df34_name1 = df34_BW['shortName'][0]
    df34_BW_value1 = df34_BW['Ball_Win'][0].round(2)
    df34_name2 = df34_BW['shortName'][1]
    df34_BW_value2 = df34_BW['Ball_Win'][1].round(2)
    df34_name3 = df34_BW['shortName'][2]
    df34_BW_value3 = df34_BW['Ball_Win'][2].round(2)
    ax.text(61.25, 61.2, f'{df34_name1}: {df34_BW_value1}\n\n{df34_name2}: {df34_BW_value2}\n\n{df34_name3}: {df34_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)









    df40_name1 = df40_BW['shortName'][0]
    df40_BW_value1 = df40_BW['Ball_Win'][0].round(2)
    df40_name2 = df40_BW['shortName'][1]
    df40_BW_value2 = df40_BW['Ball_Win'][1].round(2)
    df40_name3 = df40_BW['shortName'][2]
    df40_BW_value3 = df40_BW['Ball_Win'][2].round(2)
    ax.text(78.75, 6.8, f'{df40_name1}: {df40_BW_value1}\n\n{df40_name2}: {df40_BW_value2}\n\n{df40_name3}: {df40_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df41_name1 = df41_BW['shortName'][0]
    df41_BW_value1 = df41_BW['Ball_Win'][0].round(2)
    df41_name2 = df41_BW['shortName'][1]
    df41_BW_value2 = df41_BW['Ball_Win'][1].round(2)
    df41_name3 = df41_BW['shortName'][2]
    df41_BW_value3 = df41_BW['Ball_Win'][2].round(2)
    ax.text(78.75, 20.4, f'{df41_name1}: {df41_BW_value1}\n\n{df41_name2}: {df41_BW_value2}\n\n{df41_name3}: {df41_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df42_name1 = df42_BW['shortName'][0]
    df42_BW_value1 = df42_BW['Ball_Win'][0].round(2)
    df42_name2 = df42_BW['shortName'][1]
    df42_BW_value2 = df42_BW['Ball_Win'][1].round(2)
    df42_name3 = df42_BW['shortName'][2]
    df42_BW_value3 = df42_BW['Ball_Win'][2].round(2)
    ax.text(78.75, 34, f'{df42_name1}: {df42_BW_value1}\n\n{df42_name2}: {df42_BW_value2}\n\n{df42_name3}: {df42_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df43_name1 = df43_BW['shortName'][0]
    df43_BW_value1 = df43_BW['Ball_Win'][0].round(2)
    df43_name2 = df43_BW['shortName'][1]
    df43_BW_value2 = df43_BW['Ball_Win'][1].round(2)
    df43_name3 = df43_BW['shortName'][2]
    df43_BW_value3 = df43_BW['Ball_Win'][2].round(2)
    ax.text(78.75, 47.6, f'{df43_name1}: {df43_BW_value1}\n\n{df43_name2}: {df43_BW_value2}\n\n{df43_name3}: {df43_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df44_name1 = df44_BW['shortName'][0]
    df44_BW_value1 = df44_BW['Ball_Win'][0].round(2)
    df44_name2 = df44_BW['shortName'][1]
    df44_BW_value2 = df44_BW['Ball_Win'][1].round(2)
    df44_name3 = df44_BW['shortName'][2]
    df44_BW_value3 = df44_BW['Ball_Win'][2].round(2)
    ax.text(78.75, 61.2, f'{df44_name1}: {df44_BW_value1}\n\n{df44_name2}: {df44_BW_value2}\n\n{df44_name3}: {df44_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)









    df50_name1 = df50_BW['shortName'][0]
    df50_BW_value1 = df50_BW['Ball_Win'][0].round(2)
    df50_name2 = df50_BW['shortName'][1]
    df50_BW_value2 = df50_BW['Ball_Win'][1].round(2)
    df50_name3 = df50_BW['shortName'][2]
    df50_BW_value3 = df50_BW['Ball_Win'][2].round(2)
    ax.text(96.25, 6.8, f'{df50_name1}: {df50_BW_value1}\n\n{df50_name2}: {df50_BW_value2}\n\n{df50_name3}: {df50_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df51_name1 = df51_BW['shortName'][0]
    df51_BW_value1 = df51_BW['Ball_Win'][0].round(2)
    df51_name2 = df51_BW['shortName'][1]
    df51_BW_value2 = df51_BW['Ball_Win'][1].round(2)
    df51_name3 = df51_BW['shortName'][2]
    df51_BW_value3 = df51_BW['Ball_Win'][2].round(2)
    ax.text(96.25, 20.4, f'{df51_name1}: {df51_BW_value1}\n\n{df51_name2}: {df51_BW_value2}\n\n{df51_name3}: {df51_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df52_name1 = df52_BW['shortName'][0]
    df52_BW_value1 = df52_BW['Ball_Win'][0].round(2)
    df52_name2 = df52_BW['shortName'][1]
    df52_BW_value2 = df52_BW['Ball_Win'][1].round(2)
    df52_name3 = df52_BW['shortName'][2]
    df52_BW_value3 = df52_BW['Ball_Win'][2].round(2)
    ax.text(96.25, 34, f'{df52_name1}: {df52_BW_value1}\n\n{df52_name2}: {df52_BW_value2}\n\n{df52_name3}: {df52_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df53_name1 = df53_BW['shortName'][0]
    df53_BW_value1 = df53_BW['Ball_Win'][0].round(2)
    df53_name2 = df53_BW['shortName'][1]
    df53_BW_value2 = df53_BW['Ball_Win'][1].round(2)
    df53_name3 = df53_BW['shortName'][2]
    df53_BW_value3 = df53_BW['Ball_Win'][2].round(2)
    ax.text(96.25, 47.6, f'{df53_name1}: {df53_BW_value1}\n\n{df53_name2}: {df53_BW_value2}\n\n{df53_name3}: {df53_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)

    df54_name1 = df54_BW['shortName'][0]
    df54_BW_value1 = df54_BW['Ball_Win'][0].round(2)
    df54_name2 = df54_BW['shortName'][1]
    df54_BW_value2 = df54_BW['Ball_Win'][1].round(2)
    df54_name3 = df54_BW['shortName'][2]
    df54_BW_value3 = df54_BW['Ball_Win'][2].round(2)
    ax.text(96.25, 61.2, f'{df54_name1}: {df54_BW_value1}\n\n{df54_name2}: {df54_BW_value2}\n\n{df54_name3}: {df54_BW_value3}',
            fontsize=10, color='k', ha='center', va='center', bbox=bbox_props)
    
    ax.set_title('Zone-wise Top Aerial Winners of EPL 2023-24', fontsize=23, fontweight='bold')
    ax.text(52.5, 70.5, 'Every Successful Aerial Duel is considered', fontsize=15, ha='center', va='center', bbox=bbox_props)
    ax.text(0, -3, 'Attacking Direction ------>', ha='left', va='center')
    ax.text(52.5, -3, 'Data From: Opta', ha='center', va='center')
    ax.text(105, -3, 'Made by: @adnaaan433', ha='right', va='center')
    return

fig,ax=plt.subplots(figsize=(15,10), facecolor='#f5f5f5')
zone_wise_threat_crators(ax)

himage = urlopen(f"file:///D:/FData/Leagues_logos/LaLiga%20.html")
himage = Image.open(himage)
ax_himage = add_image(himage, fig, left=0.135, bottom=0.85, width=0.075, height=0.075)

# %% [markdown]
# # Short Code

# %%
# Define the pitch dimensions
pitch_length = 105
pitch_width = 68

# Create an empty list to store the resulting dataframes
binned_data = []

# Loop through each bin and filter the data accordingly
for i in range(6):
    for j in range(5):
        df_bin = df_pc[(df_pc['x'] > (i * pitch_length / 6)) & (df_pc['x'] <= ((i + 1) * pitch_length / 6)) & 
                       (df_pc['y'] > (j * pitch_width / 5)) & (df_pc['y'] <= ((j + 1) * pitch_width / 5))]
        
        # Group and process the data within the bin
        df_xT = df_bin.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
        df_xT.columns = ['name', 'ball_win', 'teamName', 'shortName']
        df_xT = df_xT.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)
        
        # Append the processed data to the list
        binned_data.append(df_xT)

# Combine all the binned dataframes into a single dataframe if needed
result_df = pd.concat(binned_data, keys=[f'df{i}{j}_xT' for i in range(6) for j in range(5)])


f_third = df_pc[df_pc['x']>=70]
m_third = df_pc[(df_pc['x']<70) & (df_pc['x']>35)]
d_third = df_pc[df_pc['x']<=35]

f_third = f_third.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
f_third.columns = ['name', 'ball_win', 'teamName', 'shortName']
m_third = m_third.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
m_third.columns = ['name', 'ball_win', 'teamName', 'shortName']
d_third = d_third.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
d_third.columns = ['name', 'ball_win', 'teamName', 'shortName']

f_third = f_third.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)
m_third = m_third.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)
d_third = d_third.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)

# VIZ
def zone_wise_threat_creators(ax):
    pitch = Pitch(pitch_type='uefa', corner_arcs=True, pitch_color='#f5f5f5', line_color='k', linewidth=3)
    pitch.draw(ax=ax)
    bbox_props = dict(boxstyle="round,pad=0.3", edgecolor="None", facecolor='#f5f5f5', alpha=0.75)

    # Draw vertical lines
    for i in range(1, 6):
        ax.vlines((i * pitch_length) / 6, ymin=0, ymax=pitch_width, color='gray', zorder=50)

    # Draw horizontal lines
    for i in range(1, 5):
        ax.hlines((i * pitch_width) / 5, xmin=0, xmax=pitch_length, color='gray', zorder=50)
    
    bin_width = pitch_length / 6
    bin_height = pitch_width / 5

    for i, df_xT in enumerate(binned_data):
        x_bin = ((i // 5) * bin_width + bin_width / 2) - 5
        y_bin = ((i % 5) * bin_height + bin_height / 2) + 2
        
        for idx, row in df_xT.iterrows():
            ax.text(x_bin, y_bin - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color='k', bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(x_bin-2, y_bin - (idx * 2.5), image, height=2, ax=ax)

    ax.text(13, 80, 'Zone-wise Top Ball Winners', fontsize=30, fontweight='bold', ha='left', va='center')
    ax.text(13, 75, 'Every Ball Recoveries & Interceptions are Considered | Till GW11, LaLiga 2024-25', fontsize=15, ha='left', va='center', bbox=bbox_props)
    ax.text(0, 71, 'Attacking Direction ------>', ha='left', va='center')
    ax.text(52.5, 71, 'Data From: Opta', ha='center', va='center')
    ax.text(105, 71, 'Made by: @adnaaan433', ha='right', va='center')
    # f_third
    ax.text(87.5, -4, 'Top Ball Winners in Final Third', fontsize=10, fontweight='bold', ha='center', va='center')
    for idx, row in f_third.iterrows():
            ax.text(80, - 8 - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color='k', bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(80-2, - 8 - (idx * 2.5), image, height=2, ax=ax)
    # m_third
    ax.text(52.5, -4, 'Top Ball Winners in Mid Third', fontsize=10, fontweight='bold', ha='center', va='center')
    for idx, row in m_third.iterrows():
            ax.text(45, - 8 - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color='k', bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(45-2, - 8 - (idx * 2.5), image, height=2, ax=ax)
    # d_third
    ax.text(17.5, -4, 'Top Ball Winners in Defensive Third', fontsize=10, fontweight='bold', ha='center', va='center')
    for idx, row in d_third.iterrows():
            ax.text(10, - 8 - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color='k', bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(10-2, - 8 - (idx * 2.5), image, height=2, ax=ax)

    return

fig, ax = plt.subplots(figsize=(15, 10), facecolor='#f5f5f5')
zone_wise_threat_creators(ax)

himage = urlopen(f"file:///D:/FData/Leagues_logos/LaLiga%20.html")
himage = Image.open(himage)
ax_himage = add_image(himage, fig, left=0.135, bottom=0.89, width=0.099, height=0.099)

# %%
# Define the pitch dimensions
pitch_length = 105
pitch_width = 68

# Create an empty list to store the resulting dataframes
binned_data = []

# Loop through each bin and filter the data accordingly
for i in range(6):
    for j in range(5):
        df_bin = df_pc[(df_pc['x'] > (i * pitch_length / 6)) & (df_pc['x'] <= ((i + 1) * pitch_length / 6)) & 
                       (df_pc['y'] > (j * pitch_width / 5)) & (df_pc['y'] <= ((j + 1) * pitch_width / 5))]
        
        # Group and process the data within the bin
        df_xT = df_bin.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
        df_xT.columns = ['name', 'ball_win', 'teamName', 'shortName']
        df_xT = df_xT.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)
        
        # Append the processed data to the list
        binned_data.append(df_xT)

# Combine all the binned dataframes into a single dataframe if needed
result_df = pd.concat(binned_data, keys=[f'df{i}{j}_xT' for i in range(6) for j in range(5)])


f_third = df_pc[df_pc['x']>=70]
m_third = df_pc[(df_pc['x']<70) & (df_pc['x']>35)]
d_third = df_pc[df_pc['x']<=35]

f_third = f_third.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
f_third.columns = ['name', 'ball_win', 'teamName', 'shortName']
m_third = m_third.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
m_third.columns = ['name', 'ball_win', 'teamName', 'shortName']
d_third = d_third.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
d_third.columns = ['name', 'ball_win', 'teamName', 'shortName']

f_third = f_third.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)
m_third = m_third.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)
d_third = d_third.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)

# VIZ
def zone_wise_threat_creators(ax):
    pitch = Pitch(pitch_type='uefa', corner_arcs=True, pitch_color='#f5f5f5', line_color='k', linewidth=3)
    pitch.draw(ax=ax)
    bbox_props = dict(boxstyle="round,pad=0.3", edgecolor="None", facecolor='#f5f5f5', alpha=0.75)

    # Draw vertical lines
    for i in range(1, 6):
        ax.vlines((i * pitch_length) / 6, ymin=0, ymax=pitch_width, color='gray', zorder=50)

    # Draw horizontal lines
    for i in range(1, 5):
        ax.hlines((i * pitch_width) / 5, xmin=0, xmax=pitch_length, color='gray', zorder=50)
    
    bin_width = pitch_length / 6
    bin_height = pitch_width / 5

    for i, df_xT in enumerate(binned_data):
        x_bin = ((i // 5) * bin_width + bin_width / 2) - 5
        y_bin = ((i % 5) * bin_height + bin_height / 2) + 2
        
        for idx, row in df_xT.iterrows():
            ax.text(x_bin, y_bin - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color='k', bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(x_bin-2, y_bin - (idx * 2.5), image, height=2, ax=ax)

    ax.text(13, 80, 'Zone-wise Top Ball Winners', fontsize=30, fontweight='bold', ha='left', va='center')
    ax.text(13, 75, 'Every Ball Recoveries & Interceptions are Considered | Till GW10, EPL 2024-25', fontsize=15, ha='left', va='center', bbox=bbox_props)
    ax.text(0, 71, 'Attacking Direction ------>', ha='left', va='center')
    ax.text(52.5, 71, 'Data From: Opta', ha='center', va='center')
    ax.text(105, 71, 'Made by: @adnaaan433', ha='right', va='center')
    # f_third
    ax.text(87.5, -4, 'Top Ball Winners in Final Third', fontsize=10, fontweight='bold', ha='center', va='center')
    for idx, row in f_third.iterrows():
            ax.text(80, - 8 - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color='k', bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(80-2, - 8 - (idx * 2.5), image, height=2, ax=ax)
    # m_third
    ax.text(52.5, -4, 'Top Ball Winners in Mid Third', fontsize=10, fontweight='bold', ha='center', va='center')
    for idx, row in m_third.iterrows():
            ax.text(45, - 8 - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color='k', bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(45-2, - 8 - (idx * 2.5), image, height=2, ax=ax)
    # d_third
    ax.text(17.5, -4, 'Top Ball Winners in Defensive Third', fontsize=10, fontweight='bold', ha='center', va='center')
    for idx, row in d_third.iterrows():
            ax.text(10, - 8 - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color='k', bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(10-2, - 8 - (idx * 2.5), image, height=2, ax=ax)

    return

fig, ax = plt.subplots(figsize=(15, 10), facecolor='#f5f5f5')
zone_wise_threat_creators(ax)

himage = urlopen("file:///D:/FData/Leagues_logos/EPL_Logo.html")
himage = Image.open(himage)
ax_himage = add_image(himage, fig, left=0.135, bottom=0.89, width=0.099, height=0.099)

# %%
# Define the pitch dimensions
pitch_length = 105
pitch_width = 68

# Create an empty list to store the resulting dataframes
binned_data = []

# Loop through each bin and filter the data accordingly
for i in range(6):
    for j in range(5):
        df_bin = df_pc[(df_pc['x'] > (i * pitch_length / 6)) & (df_pc['x'] <= ((i + 1) * pitch_length / 6)) & 
                       (df_pc['y'] > (j * pitch_width / 5)) & (df_pc['y'] <= ((j + 1) * pitch_width / 5))]
        
        # Group and process the data within the bin
        df_xT = df_bin.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
        df_xT.columns = ['name', 'ball_win', 'teamName', 'shortName']
        df_xT = df_xT.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)
        
        # Append the processed data to the list
        binned_data.append(df_xT)

# Combine all the binned dataframes into a single dataframe if needed
result_df = pd.concat(binned_data, keys=[f'df{i}{j}_xT' for i in range(6) for j in range(5)])


f_third = df_pc[df_pc['x']>=70]
m_third = df_pc[(df_pc['x']<70) & (df_pc['x']>35)]
d_third = df_pc[df_pc['x']<=35]

f_third = f_third.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
f_third.columns = ['name', 'ball_win', 'teamName', 'shortName']
m_third = m_third.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
m_third.columns = ['name', 'ball_win', 'teamName', 'shortName']
d_third = d_third.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
d_third.columns = ['name', 'ball_win', 'teamName', 'shortName']

f_third = f_third.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)
m_third = m_third.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)
d_third = d_third.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)

# VIZ
def zone_wise_threat_creators(ax):
    pitch = Pitch(pitch_type='uefa', corner_arcs=True, pitch_color='#f5f5f5', line_color='k', linewidth=3)
    pitch.draw(ax=ax)
    bbox_props = dict(boxstyle="round,pad=0.3", edgecolor="None", facecolor='#f5f5f5', alpha=0.75)

    # Draw vertical lines
    for i in range(1, 6):
        ax.vlines((i * pitch_length) / 6, ymin=0, ymax=pitch_width, color='gray', zorder=50)

    # Draw horizontal lines
    for i in range(1, 5):
        ax.hlines((i * pitch_width) / 5, xmin=0, xmax=pitch_length, color='gray', zorder=50)
    
    bin_width = pitch_length / 6
    bin_height = pitch_width / 5

    for i, df_xT in enumerate(binned_data):
        x_bin = ((i // 5) * bin_width + bin_width / 2) - 5
        y_bin = ((i % 5) * bin_height + bin_height / 2) + 2
        
        for idx, row in df_xT.iterrows():
            ax.text(x_bin, y_bin - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color='k', bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(x_bin-2, y_bin - (idx * 2.5), image, height=2, ax=ax)

    ax.text(13, 80, 'Zone-wise Top Ball Winners', fontsize=30, fontweight='bold', ha='left', va='center')
    ax.text(13, 75, 'Every Ball Recoveries & Interceptions are Considered | Till GW12, Serie A 2024-25', fontsize=15, ha='left', va='center', bbox=bbox_props)
    ax.text(0, 71, 'Attacking Direction ------>', ha='left', va='center')
    ax.text(52.5, 71, 'Data From: Opta', ha='center', va='center')
    ax.text(105, 71, 'Made by: @adnaaan433', ha='right', va='center')
    # f_third
    ax.text(87.5, -4, 'Top Ball Winners in Final Third', fontsize=10, fontweight='bold', ha='center', va='center')
    for idx, row in f_third.iterrows():
            ax.text(80, - 8 - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color='k', bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(80-2, - 8 - (idx * 2.5), image, height=2, ax=ax)
    # m_third
    ax.text(52.5, -4, 'Top Ball Winners in Mid Third', fontsize=10, fontweight='bold', ha='center', va='center')
    for idx, row in m_third.iterrows():
            ax.text(45, - 8 - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color='k', bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(45-2, - 8 - (idx * 2.5), image, height=2, ax=ax)
    # d_third
    ax.text(17.5, -4, 'Top Ball Winners in Defensive Third', fontsize=10, fontweight='bold', ha='center', va='center')
    for idx, row in d_third.iterrows():
            ax.text(10, - 8 - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color='k', bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(10-2, - 8 - (idx * 2.5), image, height=2, ax=ax)

    return

fig, ax = plt.subplots(figsize=(15, 10), facecolor='#f5f5f5')
zone_wise_threat_creators(ax)

himage = urlopen("file:///D:/FData/Leagues_logos/Serie_A_logo.html")
himage = Image.open(himage)
ax_himage = add_image(himage, fig, left=0.135, bottom=0.89, width=0.099, height=0.099)

# %% [markdown]
# # UCL

# %%
# Define the pitch dimensions
pitch_length = 105
pitch_width = 68

# Create an empty list to store the resulting dataframes
binned_data = []

# Loop through each bin and filter the data accordingly
for i in range(6):
    for j in range(5):
        df_bin = df_pc[(df_pc['x'] > (i * pitch_length / 6)) & (df_pc['x'] <= ((i + 1) * pitch_length / 6)) & 
                       (df_pc['y'] > (j * pitch_width / 5)) & (df_pc['y'] <= ((j + 1) * pitch_width / 5))]
        
        # Group and process the data within the bin
        df_xT = df_bin.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
        df_xT.columns = ['name', 'ball_win', 'teamName', 'shortName']
        df_xT = df_xT.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)
        
        # Append the processed data to the list
        binned_data.append(df_xT)

# Combine all the binned dataframes into a single dataframe if needed
result_df = pd.concat(binned_data, keys=[f'df{i}{j}_xT' for i in range(6) for j in range(5)])


f_third = df_pc[df_pc['x']>=70]
m_third = df_pc[(df_pc['x']<70) & (df_pc['x']>35)]
d_third = df_pc[df_pc['x']<=35]

f_third = f_third.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
f_third.columns = ['name', 'ball_win', 'teamName', 'shortName']
m_third = m_third.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
m_third.columns = ['name', 'ball_win', 'teamName', 'shortName']
d_third = d_third.groupby('name').agg({'type': 'count', 'teamName': 'max', 'shortName': 'max'}).reset_index()
d_third.columns = ['name', 'ball_win', 'teamName', 'shortName']

f_third = f_third.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)
m_third = m_third.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)
d_third = d_third.sort_values(by=['ball_win', 'teamName'], ascending=[False, True]).head(3).reset_index(drop=True)

# VIZ
def zone_wise_threat_creators(ax):
    pitch = Pitch(pitch_type='uefa', corner_arcs=True, pitch_color=bg_color, line_color=line_color, linewidth=3)
    pitch.draw(ax=ax)
    bbox_props = dict(boxstyle="round,pad=0.3", edgecolor="None", facecolor=bg_color, alpha=0.75)

    # Draw vertical lines
    for i in range(1, 6):
        ax.vlines((i * pitch_length) / 6, ymin=0, ymax=pitch_width, color='gray', zorder=50)

    # Draw horizontal lines
    for i in range(1, 5):
        ax.hlines((i * pitch_width) / 5, xmin=0, xmax=pitch_length, color='gray', zorder=50)
    
    bin_width = pitch_length / 6
    bin_height = pitch_width / 5

    for i, df_xT in enumerate(binned_data):
        x_bin = ((i // 5) * bin_width + bin_width / 2) - 5
        y_bin = ((i % 5) * bin_height + bin_height / 2) + 2
        
        for idx, row in df_xT.iterrows():
            ax.text(x_bin, y_bin - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color=line_color, bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(x_bin-2, y_bin - (idx * 2.5), image, height=2, ax=ax)

    font_path = r"C:\Fonts\UEFAbold.otf"
    custom_font = FontProperties(fname=font_path)
    ax.text(13, 82, 'Zone wise Top Ball Winners', color=line_color, fontsize=50, fontweight='bold', ha='left', va='center', fontproperties=custom_font)
    ax.text(13, 77, 'Successful Tackles & Interceptions are Considered | Till MW5, UCL 2024-25', color=line_color, fontsize=15, ha='left', va='center', bbox=bbox_props)
    ax.text(0, 71, 'Attacking Direction ------>', color=line_color, ha='left', va='center')
    ax.text(52.5, 71, 'Data From: Opta', color=line_color, ha='center', va='center')
    ax.text(105, 71, 'Made by: @adnaaan433', color=line_color, ha='right', va='center')
    # f_third
    ax.text(87.5, -4, 'Top Ball Winners in Final Third', color=line_color, fontsize=10, fontweight='bold', ha='center', va='center')
    for idx, row in f_third.iterrows():
            ax.text(80, - 8 - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color=line_color, bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(80-2, - 8 - (idx * 2.5), image, height=2, ax=ax)
    # m_third
    ax.text(52.5, -4, 'Top Ball Winners in Mid Third', color=line_color, fontsize=10, fontweight='bold', ha='center', va='center')
    for idx, row in m_third.iterrows():
            ax.text(45, - 8 - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color=line_color, bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(45-2, - 8 - (idx * 2.5), image, height=2, ax=ax)
    # d_third
    ax.text(17.5, -4, 'Top Ball Winners in Defensive Third', color=line_color, fontsize=10, fontweight='bold', ha='center', va='center')
    for idx, row in d_third.iterrows():
            ax.text(10, - 8 - (idx * 2.5), f'{row["shortName"]}: {row["ball_win"]}', ha='left', va='center', 
                    fontsize=12, color=line_color, bbox=bbox_props)
            team_name = row['teamName']
            IMAGE_URL = f'file:///D:/FData/club_teams_logo/all_league%20-%20Copy/{team_name}.html'
            image = Image.open(urlopen(IMAGE_URL))
            ax_image = pitch.inset_image(10-2, - 8 - (idx * 2.5), image, height=2, ax=ax)

    return

fig, ax = plt.subplots(figsize=(15, 10), facecolor=bg_color)
zone_wise_threat_creators(ax)

himage = urlopen("file:///D:/FData/Leagues_logos/UEFA_Champions_League_White.html")
himage = Image.open(himage)
ax_himage = add_image(himage, fig, left=0.135, bottom=0.92, width=0.099, height=0.099)
