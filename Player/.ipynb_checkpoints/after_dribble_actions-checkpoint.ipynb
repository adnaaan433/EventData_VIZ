# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.image as mpimg
import matplotlib.patches as patches
import matplotlib as mpl
from mplsoccer import Pitch, VerticalPitch, FontManager, Sbopen, add_image
from matplotlib.font_manager import FontProperties
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.patheffects as path_effects
from highlight_text import ax_text, fig_text
from PIL import Image
from mplsoccer import add_image
from urllib.request import urlopen
import os


# Print the modified DataFrame
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

green = '#69f900'
red = '#ff4b44'
blue = '#00a0de'
violet = '#a369ff'
bg_color= '#f5f5f5'
line_color= '#000000'
col1 = '#ff4b44'
col2 = '#00a0de'

# %%
df = pd.read_csv(r"D:\FData\EPL_2024_25\epl_till_gw29.csv")

# %%
df = pd.read_csv(r"D:\FData\LaLiga_2024_25\laliga_till_gw38.csv")

# %%
df = df[df['type']!='Carry'].reset_index(drop=True)

# %%
df_teamNameId = pd.read_csv(r"D:\FData\club_teams_logo\teams_name_and_id.csv")

# %% [markdown]
# # After TakeOn Actions

# %%
def positive_action(ax, pname):
    dfp = df[df['name']==pname]
    pteam = dfp.teamName.unique()[0]
    # dfteam = df[(df['teamName']==pteam) | (df['oppositionTeamName']==pteam)].reset_index(drop=True)
    dfteam = df[df['teamName']==pteam].reset_index(drop=True)

    pitch = VerticalPitch(pitch_type='uefa', pitch_color=bg_color,  linewidth=2, corner_arcs=True)
    pitch.draw(ax=ax)

    # Successful Pass
    sp = 0
    for index, row in dfteam.iterrows():
        if (
            row['name'] == pname and 
            row['type'] == 'TakeOn' and 
            row['outcomeType'] == 'Successful' and 
            index + 1 < len(dfteam) and  
            dfteam.loc[index + 1, 'name'] == pname and
            dfteam.loc[index + 1, 'type'] == 'Pass' and
            dfteam.loc[index + 1, 'outcomeType'] == 'Successful' 
        ):
            pitch.scatter(row['x'], row['y'], s=100, color='None', edgecolor=col2, ax=ax)
            pitch.lines(row['x'], row['y'], dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], color=col2, lw=0.75, ls='--', ax=ax)
            arrow = patches.FancyArrowPatch((dfteam.loc[index + 1, 'y'], dfteam.loc[index + 1, 'x']), (dfteam.loc[index + 1, 'endY'], 
                                             dfteam.loc[index + 1, 'endX']), arrowstyle='->', color=col2, zorder=6, mutation_scale=15, alpha=0.75, linewidth=2)
            ax.add_patch(arrow)
            sp += 1

    # Key Pass
    kp = 0
    for index, row in dfteam.iterrows():
        if (
            row['name'] == pname and 
            row['type'] == 'TakeOn' and 
            row['outcomeType'] == 'Successful' and 
            index + 1 < len(dfteam) and  
            dfteam.loc[index + 1, 'name'] == pname and
            dfteam.loc[index + 1, 'type'] == 'Pass' and
            'KeyPass' in dfteam.loc[index + 1, 'qualifiers']
        ):
            pitch.scatter(row['x'], row['y'], s=100, color='None', edgecolor=violet, ax=ax)
            pitch.lines(row['x'], row['y'], dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], color=violet, lw=0.75, ls='--', ax=ax)
            arrow = patches.FancyArrowPatch((dfteam.loc[index + 1, 'y'], dfteam.loc[index + 1, 'x']), (dfteam.loc[index + 1, 'endY'], 
                                             dfteam.loc[index + 1, 'endX']), arrowstyle='->', color=violet, zorder=6, mutation_scale=15, alpha=0.75, linewidth=2)
            ax.add_patch(arrow)
            kp += 1

    # Assist
    ass = 0
    for index, row in dfteam.iterrows():
        if (
            row['name'] == pname and 
            row['type'] == 'TakeOn' and 
            row['outcomeType'] == 'Successful' and 
            index + 1 < len(dfteam) and  
            dfteam.loc[index + 1, 'name'] == pname and
            dfteam.loc[index + 1, 'type'] == 'Pass' and
            'GoalAssist' in dfteam.loc[index + 1, 'qualifiers']
        ):
            pitch.scatter(row['x'], row['y'], s=100, color='None', edgecolor='green', ax=ax)
            pitch.lines(row['x'], row['y'], dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], color='green', lw=0.75, ls='--', ax=ax)
            arrow = patches.FancyArrowPatch((dfteam.loc[index + 1, 'y'], dfteam.loc[index + 1, 'x']), (dfteam.loc[index + 1, 'endY'], 
                                             dfteam.loc[index + 1, 'endX']), arrowstyle='->', color='green', zorder=6, mutation_scale=15, alpha=0.75, linewidth=2)
            ax.add_patch(arrow)
            ass += 1

    # Shots
    sht = 0
    for index, row in dfteam.iterrows():
        if (
            row['name'] == pname and 
            row['type'] == 'TakeOn' and 
            row['outcomeType'] == 'Successful' and 
            index + 1 < len(dfteam) and  
            dfteam.loc[index + 1, 'name'] == pname and
            dfteam.loc[index + 1, 'type'] in ['MissedShots', 'SavedShot', 'ShotOnPost']
        ):
            pitch.scatter(row['x'], row['y'], s=100, color='None', edgecolor='orange', ax=ax)
            pitch.lines(row['x'], row['y'], dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], color='orange', lw=0.75, ls='--', ax=ax)
            pitch.scatter(dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], s=100, color='orange', marker='^', ax=ax)
            sht += 1

    # Goals
    gl = 0
    for index, row in dfteam.iterrows():
        if (
            row['name'] == pname and 
            row['type'] == 'TakeOn' and 
            row['outcomeType'] == 'Successful' and 
            index + 1 < len(dfteam) and  
            dfteam.loc[index + 1, 'name'] == pname and
            dfteam.loc[index + 1, 'type'] == 'Goal'
        ):
            pitch.scatter(row['x'], row['y'], s=100, color='None', edgecolor='green', ax=ax)
            pitch.lines(row['x'], row['y'], dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], color='green', lw=0.75, ls='--', ax=ax)
            pitch.scatter(dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], s=100, color='green', marker='^', ax=ax)
            gl += 1

    
            

    ax.set_title('After TakeOn Positive Impact', fontweight='bold')
    ax_text(34, -4, f'<Successful Pass: {sp}> | <Key Pass: {kp}> | <Assist: {ass}>', ha='center', va='center', 
            highlight_textprops=[{'color': col2}, {'color': violet}, {'color': 'green'}], ax=ax)
    ax_text(34, -8, f'<Shots: {sht}> | <Goals: {gl}>', ha='center', va='center', 
            highlight_textprops=[{'color': 'orange'}, {'color': 'green'}], ax=ax)
    
    return

def negative_action(ax, pname):
    dfp = df[df['name']==pname]
    pteam = dfp.teamName.unique()[0]
    # dfteam = df[(df['teamName']==pteam) | (df['oppositionTeamName']==pteam)].reset_index(drop=True)
    dfteam = df[df['teamName']==pteam].reset_index(drop=True)

    pitch = VerticalPitch(pitch_type='uefa', pitch_color=bg_color,  linewidth=2, corner_arcs=True)
    pitch.draw(ax=ax)

    # Unsuccessful Pass
    up = 0
    for index, row in dfteam.iterrows():
        if (
            row['name'] == pname and 
            row['type'] == 'TakeOn' and 
            row['outcomeType'] == 'Successful' and 
            index + 1 < len(dfteam) and  
            dfteam.loc[index + 1, 'name'] == pname and
            dfteam.loc[index + 1, 'type'] == 'Pass' and
            dfteam.loc[index + 1, 'outcomeType'] == 'Unsuccessful' 
        ):
            pitch.scatter(row['x'], row['y'], s=100, color='None', edgecolor=col2, ax=ax)
            pitch.lines(row['x'], row['y'], dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], color=col2, lw=0.75, ls='--', ax=ax)
            arrow = patches.FancyArrowPatch((dfteam.loc[index + 1, 'y'], dfteam.loc[index + 1, 'x']), (dfteam.loc[index + 1, 'endY'], 
                                             dfteam.loc[index + 1, 'endX']), arrowstyle='->', color=col1, zorder=6, mutation_scale=15, alpha=0.75, linewidth=2)
            ax.add_patch(arrow)
            up += 1

    # Possession Lost
    pl = 0
    for index, row in dfteam.iterrows():
        if (
            row['name'] == pname and 
            row['type'] == 'TakeOn' and 
            row['outcomeType'] == 'Successful' and 
            index + 1 < len(dfteam) and  
            dfteam.loc[index + 1, 'name'] == pname and
            (
                dfteam.loc[index + 1, 'type'] == 'Dispossessed' or 
                dfteam.loc[index + 1, 'type'] == 'BallTouch'
            )
        ):
            pitch.scatter(row['x'], row['y'], s=100, color='None', edgecolor=col2, ax=ax)
            pitch.lines(row['x'], row['y'], dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], color=col2, lw=0.75, ls='--', ax=ax)
            pitch.scatter(dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], s=100, color='orange', marker='x', ax=ax)
            pl += 1

    ax.set_title('After TakeOn Negative Impact', fontweight='bold')
    ax_text(34, -4, f'<Unsuccessful Pass: {up}> | <Possession Lost: {pl}>', ha='center', va='center', 
            highlight_textprops=[{'color': col1}, {'color': 'orange'}], ax=ax)
    ftmb_tid = df_teamNameId[df_teamNameId['teamName']==pteam].teamId.to_list()[0]
    return ftmb_tid

# %%
sorted_names = sorted(df.name.dropna().unique())
sorted_names
# Out:
# ['Abde Ezzalzouli',
#  'Abde Rebbach',
#  'Abdel Abqar',
#  'Abdon Prats',
#  'Abdoulaye Keita',
#  'Abdul Mumin',
#  'Abel Bretones',
#  'Abel Ruiz',
#  'Aboubacar Bassinga',
#  'Adam Aznou',
#  'Adama Boiro',
#  'Adnan Januzaj',
#  'Adri Embarba',
#  'Adria Alti',
#  'Adria Pedrosa',
#  'Adrian',
#  'Adrian Arnu',
#  'Adrian Nino',
#  'Adrian Pica',
#  'Adrian Rodriguez',
#  'Adu Ares',
#  'Aihen Munoz',
#  'Aimar Oroz',
#  'Aingeru Olabarrieta',
#  'Aitor Fernandez',
#  'Aitor Paredes',
#  'Aitor Ruibal',
#  'Akor Adams',
#  'Albert Sambi Lokonga',
#  'Alberto Mari',
#  'Alberto Moleiro',
#  'Alberto Risco',
#  'Alejandro Balde',
#  'Alejandro Catena',
#  'Alejandro Frances',
#  'Alejandro Padilla',
#  'Alejo Veliz',
#  'Aleksandar Sedlar',
#  'Alex Baena',
#  'Alex Berenguer',
#  'Alex Kral',
#  'Alex Munoz',
#  'Alex Padilla',
#  'Alex Remiro',
#  'Alex Sola',
#  'Alex Suarez',
#  'Alexander Sorloth',
#  'Alfon Gonzalez',
#  'Alfonso Espino',
#  'Alfonso Pedraza',
#  'Allan Nyom',
#  'Alvaro Aguado',
#  'Alvaro Djalo',
#  'Alvaro Fernandez',
#  'Alvaro Garcia',
#  'Alvaro Odriozola',
#  'Alvaro Pascual',
#  'Alvaro Rodriguez',
#  'Alvaro Tejero',
#  'Amath Ndiaye',
#  'Ander Barrenetxea',
#  'Ander Guevara',
#  'Ander Herrera',
#  'Andoni Gorosabel',
#  'Andre Almeida',
#  'Andre Ferreira',
#  'Andreas Christensen',
#  'Andrei Ratiu',
#  'Andrii Lunin',
#  'Andy Pelmard',
#  'Angel Correa',
#  'Angel Ortiz',
#  'Ansu Fati',
#  'Ante Budimir',
#  'Antoine Griezmann',
#  'Antonio Blanco',
#  'Antonio Candela',
#  'Antonio Raillo',
#  'Antonio Rudiger',
#  'Antonio Sanchez',
#  'Antonio Sivera',
#  'Antoniu Roca',
#  'Antony',
#  'Anuar Tuhami',
#  'Arda Guler',
#  'Aridane Hernandez',
#  'Aritz Arambarri',
#  'Aritz Elustondo',
#  'Arkaitz Mariezkurrena',
#  'Arnau Martinez',
#  'Arnau Rafus',
#  'Arnau Sola',
#  'Arnaut Danjuma',
#  'Arsen Zakharyan',
#  'Arthur',
#  'Arturo Rodriguez',
#  'Asier Villalibre',
#  'Assane Diao',
#  'Augusto Batalla',
#  'Aurelien Tchouameni',
#  'Axel Witsel',
#  'Ayoze Perez',
#  'Benat Prados',
#  'Benat Turrientes',
#  'Benito Ramirez',
#  'Bertug Yildirim',
#  'Bojan Miovski',
#  'Borja Iglesias',
#  'Borja Mayoral',
#  'Borna Barisic',
#  'Brahim Diaz',
#  'Brais Mendez',
#  'Brian Olivan',
#  'Bryan Gil',
#  'Bryan Zaragoza',
#  'Carl Starfelt',
#  'Carles Alena',
#  'Carles Perez',
#  'Carlos Benavidez',
#  'Carlos Dominguez',
#  'Carlos Guirao',
#  'Carlos Martin',
#  'Carlos Romero',
#  'Carlos Vicente',
#  'Cedric Bakambu',
#  'Cenk Ozkacar',
#  'Cesar Azpilicueta',
#  'Cesar Tarrega',
#  'Chema Andres',
#  'Chidera Ejuke',
#  'Chimy Avila',
#  'Chiquinho',
#  'Christantus Uche',
#  'Chuki',
#  'Clement Lenglet',
#  'Coba da Costa',
#  'Conor Gallagher',
#  'Copete',
#  'Cristhian Mosquera',
#  'Cristhian Stuani',
#  'Cucho Hernandez',
#  'Cyle Larin',
#  'Daley Blind',
#  'Daley Sinkgraven',
#  'Damian Rodriguez',
#  'Dani Cardenas',
#  'Dani Carvajal',
#  'Dani Ceballos',
#  'Dani Gomez',
#  'Dani Olmo',
#  'Dani Parejo',
#  'Dani Raba',
#  'Dani Requena',
#  'Dani Rodriguez',
#  'Dani Vivian',
#  'Daniel Diaz',
#  'Daniel Luna',
#  'Daniel Yanez',
#  'Dario Benavides',
#  'Dario Essugo',
#  'Darko Brasanac',
#  'Darwin Machis',
#  'David Alaba',
#  'David Arguelles',
#  'David Lopez',
#  'David Otorbi',
#  'David Soria',
#  'David Torres',
#  'Denis Suarez',
#  'Diego Conde',
#  'Diego Garcia',
#  'Diego Hormigo',
#  'Diego Llorente',
#  'Diego Lopez',
#  'Diego Martin',
#  'Diego Rico',
#  'Dimitri Foulquier',
#  'Dinko Horkas',
#  'Djene Dakonam',
#  'Djibril Sow',
#  'Dodi Lukebakio',
#  'Domingos Duarte',
#  'Dominik Greif',
#  'Donny van de Beek',
#  'Duk',
#  'Eder Militao',
#  'Edu Exposito',
#  'Eduardo Camavinga',
#  'Endika Bujan',
#  'Endrick',
#  'Enric Franquesa',
#  'Enzo Barrenechea',
#  'Enzo Boyomo',
#  'Enzo Loiodice',
#  'Eray Comert',
#  'Eric Bailly',
#  'Eric Garcia',
#  "Etienne Eto'o Pineda",
#  'Etta Eyong',
#  'Fabio Gonzalez',
#  'Fabio Silva',
#  'Facundo Garces',
#  'Federico Valverde',
#  'Ferland Mendy',
#  'Fermin Lopez',
#  'Fernando Calero',
#  'Fernando Lopez',
#  'Ferran Ruiz',
#  'Ferran Torres',
#  'Florian Grillitsch',
#  'Florian Lejeune',
#  'Fran Beltran',
#  'Fran Garcia',
#  'Fran Gonzalez',
#  'Fran Perez',
#  'Fran Vieites',
#  'Franco Cervi',
#  'Frenkie de Jong',
#  'Gabriel Misehouy',
#  'Garcia Pascual',
#  'Gavi',
#  'Gerard Gumbau',
#  'Gerard Martin',
#  'Gerard Moreno',
#  'German Valera',
#  'Giorgi Mamardashvili',
#  'Giovani Lo Celso',
#  'Giuliano Simeone',
#  'Gonzalo Garcia',
#  'Gonzalo Montiel',
#  'Gorka Guruzeta',
#  'Gorka Rivera',
#  'Hamari Traore',
#  'Hector Bellerin',
#  'Hector Fort',
#  'Henrique',
#  'Hugo Alvarez',
#  'Hugo Duro',
#  'Hugo Guillamon',
#  'Hugo Novoa',
#  'Hugo Sotelo',
#  'Iago Aspas',
#  'Iago Parente',
#  'Ibrahim Alani',
#  'Igor Zubeldia',
#  'Iker Almena',
#  'Iker Benito',
#  'Iker Cordoba',
#  'Iker Losada',
#  'Iker Munoz',
#  'Ilaix Moriba',
#  'Ilias Akhomach',
#  'Inaki Pena',
#  'Inaki Williams',
#  'Inaki Williams Arthuer',
#  'Inigo Lekue',
#  'Inigo Martinez',
#  'Inigo Ruiz de Galarreta',
#  'Irvin Cardona',
#  'Isaac Romero',
#  'Isco',
#  'Isi Palazon',
#  'Ismael Bekhoucha',
#  'Israel Dominguez',
#  'Ivan Balliu',
#  'Ivan Jaime',
#  'Ivan Martin',
#  'Ivan Sanchez',
#  'Ivan Villar',
#  'Jacobo Ramon',
#  'Jailson',
#  'Jaime Mata',
#  'James Rodriguez',
#  'Jan Oblak',
#  'Jan Salas',
#  'Jasper Cillessen',
#  'Javi Galan',
#  'Javi Guerra',
#  'Javi Hernandez',
#  'Javi Llabres',
#  'Javi Lopez',
#  'Javi Martinez',
#  'Javi Munoz',
#  'Javi Puado',
#  'Javi Rodriguez',
#  'Javi Sanchez',
#  'Javier Manquillo',
#  'Javier Marton',
#  'Javier Rodriguez',
#  'Jesus Areso',
#  'Jesus Navas',
#  'Jesus Owono',
#  'Jesus Rodriguez',
#  'Jesus Vallejo',
#  'Jesus Vazquez',
#  'Jhon Solis',
#  'Joan Garcia',
#  'Joan Jordan',
#  'Jofre Carreras',
#  'Johan Mojica',
#  'John Patrick',
#  'Johnny Cardoso',
#  'Jon Aramburu',
#  'Jon Guridi',
#  'Jon Magunazelaia',
#  'Jon Martin',
#  'Jon Moncayola',
#  'Jon Olasagasti',
#  'Jon Pacheco',
#  'Jonathan Bamba',
#  'Jorge Herrando',
#  'Jorge Saenz',
#  'Jorge de Frutos',
#  'Jose Angel Carmona',
#  'Jose Arnaiz',
#  'Jose Campana',
#  'Jose Carlos Gonzalez',
#  'Jose Gaya',
#  'Jose Gimenez',
#  'Jose Gragera',
#  'Jose Maria Gimenez',
#  'Joseph Aidoo',
#  'Juan Bernat',
#  'Juan Berrocal',
#  'Juan Carlos',
#  'Juan Cruz',
#  'Juan Foyth',
#  'Juan Herzog',
#  'Juan Iglesias',
#  'Juan Musso',
#  'Juan Soriano',
#  'Juanlu Sanchez',
#  'Juanmi',
#  'Juanmi Latasa',
#  'Juanpe',
#  'Jude Bellingham',
#  'Julen Agirrezabala',
#  'Jules Kounde',
#  'Julian Alvarez',
#  'Julian Chicco',
#  'Juma Bah',
#  'Justin Smith',
#  'Karl Hein',
#  'Kelechi Iheanacho',
#  'Kenedy',
#  'Kike Barja',
#  'Kike Garcia',
#  'Kike Perez',
#  'Kike Salas',
#  'Kiko Femenia',
#  'Kim Min-Su',
#  'Kirian Rodriguez',
#  'Koke',
#  'Kylian Mbappe',
#  'Ladislav Krejci',
#  'Lamine Yamal',
#  'Leandro Antonetti',
#  'Leandro Cabrera',
#  'Leo Roman',
#  'Logan Costa',
#  'Loic Bade',
#  'Lorenzo Aguado',
#  'Luca de la Torre',
#  'Lucas Ocampos',
#  'Lucas Rosa',
#  'Lucas Torro',
#  'Lucas Vazquez',
#  'Lucien Agoume',
#  'Luis Milla',
#  'Luis Perez',
#  'Luis Rioja',
#  'Luiz Junior',
#  'Luka Modric',
#  'Luka Romero',
#  'Luka Sucic',
#  'Luken Beitia',
#  'Mamadou Sylla',
#  'Manu Bueno',
#  'Manu Fuster',
#  'Manu Morlanes',
#  'Manu Sanchez',
#  'Marash Kumbulla',
#  'Marc Bartra',
#  'Marc Bernal',
#  'Marc Cardona',
#  'Marc Casado',
#  'Marc Domenech',
#  'Marc Roca',
#  'Marc-Andre ter Stegen',
#  'Marcao',
#  'Marcos Alonso',
#  'Marcos Andre',
#  'Marcos Llorente',
#  'Mario Maroto',
#  'Mario Martin',
#  'Marko Dmitrovic',
#  'Maroan Sannadi',
#  'Martin Tejon',
#  'Martin Valjent',
#  'Martin Zubimendi',
#  'Marvin Park',
#  'Mateo Flores',
#  'Mateo Mejia',
#  'Mateu Morey',
#  'Matija Nastasic',
#  'Mauro Arambarri',
#  'Max Aarons',
#  'Maximiliano Caufriez',
#  'Miguel Gutierrez',
#  'Miguel de la Fuente',
#  'Mihailo Ristic',
#  'Mika Marmol',
#  'Mikel Jauregizar',
#  'Mikel Oyarzabal',
#  'Mikel Vesga',
#  'Moi Gomez',
#  'Mouctar Diakhaby',
#  'Moussa Diarra',
#  'Munir El Haddadi',
#  'Nabil Aberdin',
#  'Nabil Fekir',
#  'Nacho Vidal',
#  'Naci Unuvar',
#  'Nahuel Molina',
#  'Nahuel Tenaglia',
#  'Natan',
#  'Nayef Aguerd',
#  'Nemanja Gudelj',
#  'Nico Serrano',
#  'Nico Williams',
#  'Nicolas Pepe',
#  'Nobel Mendy',
#  'Oihan Sancet',
#  'Oliver McBurnie',
#  'Omar Alderete',
#  'Omar El Hilali',
#  'Omar Mascarell',
#  'Oriol Romeu',
#  'Orjan Nyland',
#  'Orri Oskarsson',
#  'Oscar De Marcos',
#  'Oscar Mingueza',
#  'Oscar Rodriguez',
#  'Oscar Trejo',
#  'Oscar Valentin',
#  'Pablo Barrios',
#  'Pablo Duran',
#  'Pablo Fornals',
#  'Pablo Garcia',
#  'Pablo Ibanez',
#  'Pablo Maffeo',
#  'Pablo Marin',
#  'Pablo Torre',
#  'Papa Dame Ba',
#  'Pape Gueye',
#  'Pathe Ciss',
#  'Pau Cabanes',
#  'Pau Cabanes De La Torre',
#  'Pau Cubarsi',
#  'Pau Lopez',
#  'Pau Navarro',
#  'Pau Victor',
#  'Paulo Gazzaniga',
#  'Pedri',
#  'Pedro Diaz',
#  'Peio Canales',
#  'Pejino',
#  'Pelayo Fernandez',
#  'Pep Chavarria',
#  'Pepelu',
#  'Peque',
#  'Peque Fernandez',
#  'Pere Milla',
#  'Peter Federico',
#  'Pol Lozano',
#  'Portu',
#  'Rafa Mir',
#  'Rafael Bauza',
#  'Ramon Martinez',
#  'Ramon Terrats',
#  'Randy Nteka',
#  'Raphinha',
#  'Raul',
#  'Raul Albiol',
#  'Raul Asencio',
#  'Raul Chasco',
#  'Raul Garcia',
#  'Raul Moro',
#  'Raul de Tomas',
#  'Reinildo',
#  'Renato Tapia',
#  'Ricardo Rodriguez',
#  'Robert Lewandowski',
#  'Robert Navarro',
#  'Roberto Fernandez',
#  'Roberto Lopez',
#  'Robin Le Normand',
#  'Rodri',
#  'Rodrigo Abajas',
#  'Rodrigo De Paul',
#  'Rodrigo Riquelme',
#  'Rodrygo',
#  'Roger Hinojo',
#  'Romain Perraud',
#  'Ronald Araujo',
#  'Ruben Garcia',
#  'Ruben Pena',
#  'Ruben Vargas',
#  'Rui Silva',
#  'Samu Costa',
#  'Samuel Lino',
#  'Sandro Ramirez',
#  'Santi Comesana',
#  'Santiago Mourino',
#  'Saul Niguez',
#  'Scott McKenna',
#  'Sebastien Haller',
#  'Selim Amallah',
#  'Sergi Altimira',
#  'Sergi Canos',
#  'Sergi Cardona',
#  'Sergi Darder',
#  'Sergi Dominguez',
#  'Sergi Gomez',
#  'Sergi Guardiola',
#  'Sergio Arribas',
#  'Sergio Camello',
#  'Sergio Carreira',
#  'Sergio Gomez',
#  'Sergio Gonzalez',
#  'Sergio Herrera',
#  'Sergio Viera',
#  'Seydouba Cisse',
#  'Sheraldo Becker',
#  'Siebe Van der Heyden',
#  'Silvi Clua',
#  'Stanis Idumbo',
#  'Stanis Idumbo Muzambo',
#  'Stanko Juric',
#  'Stefan Bajcetic',
#  'Stoichkov',
#  'Stole Dimitrievski',
#  'Suso',
#  'Tadeo Allende',
#  'Tajon Buchanan',
#  'Takefusa Kubo',
#  'Takuma Asano',
#  'Tamas Nikitscher',
#  'Tanguy Nianzou',
#  'Tasos Douvikas',
#  'Thiago Ojeda',
#  'Thibaut Courtois',
#  'Thierno Barry',
#  'Thierry Correia',
#  'Thomas Lemar',
#  'Tomas Conechny',
#  'Toni Lato',
#  'Toni Martinez',
#  'Umar Sadiq',
#  'Unai Garcia',
#  'Unai Gomez',
#  'Unai Lopez',
#  'Unai Marrero',
#  'Unai Nunez',
#  'Unai Simon',
#  'Urko Gonzalez',
#  'Valentin Barco',
#  'Valentin Pezzolesi',
#  'Valentin Rosier',
#  'Valery Fernandez',
#  'Vedat Muriqi',
#  'Vicente Guaita',
#  'Victor Meseguer',
#  'Victor Munoz',
#  'Viktor Tsygankov',
#  'Viktor Tsyhankov',
#  'Vinicius Junior',
#  'Viti Rozada',
#  'Vitor Roque',
#  'Vladyslav Krapyvtsov',
#  'Walid Cheddira',
#  'William Carvalho',
#  'Williot Swedberg',
#  'Willy Kambwala',
#  'Wojciech Szczesny',
#  'Xavi Moreno',
#  'Yan Diomande',
#  'Yangel Herrera',
#  'Yarek Gasiorowski',
#  'Yaser Asprilla',
#  'Yellu Santiago',
#  'Yeray Alvarez',
#  'Yeremy Pino',
#  'Yoel Lago',
#  'Youssouf Sabaly',
#  'Yuri Berchiche',
#  'Yvan Neyou']

# %%
fig,axs = plt.subplots(1,2, figsize=(15,10), facecolor=bg_color)
positive_action(axs[0], 'Jeremy Doku')
ftmb_tid = negative_action(axs[1], 'Jeremy Doku')
fig.subplots_adjust(wspace=0.001)

fig.text(0.25, 1.05, 'Jeremy Doku', fontsize=30, fontweight='bold', va='center')
fig.text(0.25, 1.00, 'in English Premier League 2024-25 season, till GW 29', fontsize=13, va='center')
fig.text(0.25, 0.97, 'Data from: Opta | made by: @adnaaan433', fontsize=13, va='center')

fig.text(0.5, -0.01, '*Circle = Successful TakeOns, Dotted Lines = Ball Carry after TakeOn', fontstyle='italic', ha='center', va='center')

himage = urlopen(f"https://images.fotmob.com/image_resources/logo/teamlogo/{ftmb_tid}.png")
himage = Image.open(himage)
ax_himage = add_image(himage, fig, left=0.13, bottom=0.97, width=0.1, height=0.1)

# %%
fig,axs = plt.subplots(1,2, figsize=(15,10), facecolor=bg_color)
positive_action(axs[0], 'Raphinha')
ftmb_tid = negative_action(axs[1], 'Raphinha')
fig.subplots_adjust(wspace=0.001)

fig.text(0.25, 1.02, 'Raphinha', fontsize=30, fontweight='bold', va='center')
fig.text(0.25, 0.97, 'in LaLiga 2024-25 season  |  Data from: Opta  |  made by: @adnaaan433', fontsize=13, va='center')
# fig.text(0.25, 0.97, 'Data from: Opta | made by: @adnaaan433', fontsize=13, va='center')

fig.text(0.5, -0.01, '*Circle = Successful TakeOns, Dotted Lines = Ball Carry after TakeOn', fontstyle='italic', ha='center', va='center')

himage = urlopen(f"https://images.fotmob.com/image_resources/logo/teamlogo/{ftmb_tid}.png")
himage = Image.open(himage)
ax_himage = add_image(himage, fig, left=0.13, bottom=0.95, width=0.1, height=0.1)

# %% [markdown]
# # After Carry Actions

# %%
def positive_action(ax, pname):
    dfp = df[df['name']==pname]
    pteam = dfp.teamName.unique()[0]
    # dfteam = df[(df['teamName']==pteam) | (df['oppositionTeamName']==pteam)].reset_index(drop=True)
    dfteam = df[df['teamName']==pteam].reset_index(drop=True)

    pitch = VerticalPitch(pitch_type='uefa', pitch_color=bg_color,  linewidth=2, corner_arcs=True)
    pitch.draw(ax=ax)

    # Successful Pass
    sp = 0
    for index, row in dfteam.iterrows():
        if (
            row['name'] == pname and 
            row['type'] == 'Carry' and 
            row['outcomeType'] == 'Successful' and 
            index + 1 < len(dfteam) and  
            dfteam.loc[index + 1, 'name'] == pname and
            dfteam.loc[index + 1, 'type'] == 'Pass' and
            dfteam.loc[index + 1, 'outcomeType'] == 'Successful' 
        ):
            pitch.scatter(row['x'], row['y'], s=25, color=col2, ax=ax)
            pitch.lines(row['x'], row['y'], dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], color=col2, lw=0.75, ls='--', ax=ax)
            arrow = patches.FancyArrowPatch((dfteam.loc[index + 1, 'y'], dfteam.loc[index + 1, 'x']), (dfteam.loc[index + 1, 'endY'], 
                                             dfteam.loc[index + 1, 'endX']), arrowstyle='->', color=col2, zorder=6, mutation_scale=10, alpha=0.75, linewidth=1)
            ax.add_patch(arrow)
            sp += 1

    # Key Pass
    kp = 0
    for index, row in dfteam.iterrows():
        if (
            row['name'] == pname and 
            row['type'] == 'Carry' and 
            row['outcomeType'] == 'Successful' and 
            index + 1 < len(dfteam) and  
            dfteam.loc[index + 1, 'name'] == pname and
            dfteam.loc[index + 1, 'type'] == 'Pass' and
            'KeyPass' in dfteam.loc[index + 1, 'qualifiers']
        ):
            pitch.scatter(row['x'], row['y'], s=25, color=violet, ax=ax)
            pitch.lines(row['x'], row['y'], dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], color=violet, lw=0.75, ls='--', ax=ax)
            arrow = patches.FancyArrowPatch((dfteam.loc[index + 1, 'y'], dfteam.loc[index + 1, 'x']), (dfteam.loc[index + 1, 'endY'], 
                                             dfteam.loc[index + 1, 'endX']), arrowstyle='->', color=violet, zorder=6, mutation_scale=10, alpha=0.75, linewidth=1)
            ax.add_patch(arrow)
            kp += 1

    # Assist
    ass = 0
    for index, row in dfteam.iterrows():
        if (
            row['name'] == pname and 
            row['type'] == 'Carry' and 
            row['outcomeType'] == 'Successful' and 
            index + 1 < len(dfteam) and  
            dfteam.loc[index + 1, 'name'] == pname and
            dfteam.loc[index + 1, 'type'] == 'Pass' and
            'GoalAssist' in dfteam.loc[index + 1, 'qualifiers']
        ):
            pitch.scatter(row['x'], row['y'], s=25, color='green', ax=ax)
            pitch.lines(row['x'], row['y'], dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], color='green', lw=0.75, ls='--', ax=ax)
            arrow = patches.FancyArrowPatch((dfteam.loc[index + 1, 'y'], dfteam.loc[index + 1, 'x']), (dfteam.loc[index + 1, 'endY'], 
                                             dfteam.loc[index + 1, 'endX']), arrowstyle='->', color='green', zorder=6, mutation_scale=10, alpha=0.75, linewidth=1)
            ax.add_patch(arrow)
            ass += 1

    # Shots
    sht = 0
    for index, row in dfteam.iterrows():
        if (
            row['name'] == pname and 
            row['type'] == 'Carry' and 
            row['outcomeType'] == 'Successful' and 
            index + 1 < len(dfteam) and  
            dfteam.loc[index + 1, 'name'] == pname and
            dfteam.loc[index + 1, 'type'] in ['MissedShots', 'SavedShot', 'ShotOnPost']
        ):
            pitch.scatter(row['x'], row['y'], s=25, color='orange', ax=ax)
            pitch.lines(row['x'], row['y'], dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], color='orange', lw=0.75, ls='--', ax=ax)
            pitch.scatter(dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], s=100, color='orange', marker='^', ax=ax)
            sht += 1

    # Goals
    gl = 0
    for index, row in dfteam.iterrows():
        if (
            row['name'] == pname and 
            row['type'] == 'Carry' and 
            row['outcomeType'] == 'Successful' and 
            index + 1 < len(dfteam) and  
            dfteam.loc[index + 1, 'name'] == pname and
            dfteam.loc[index + 1, 'type'] == 'Goal'
        ):
            pitch.scatter(row['x'], row['y'], s=25, color='green', ax=ax)
            pitch.lines(row['x'], row['y'], dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], color='green', lw=0.75, ls='--', ax=ax)
            pitch.scatter(dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], s=100, color='green', marker='^', ax=ax)
            gl += 1

    
            

    ax.set_title('After Carry Positive Impact', fontweight='bold')
    ax_text(34, -4, f'<Successful Pass: {sp}> | <Key Pass: {kp}> | <Assist: {ass}>', ha='center', va='center', 
            highlight_textprops=[{'color': col2}, {'color': violet}, {'color': 'green'}], ax=ax)
    ax_text(34, -8, f'<Shots: {sht}> | <Goals: {gl}>', ha='center', va='center', 
            highlight_textprops=[{'color': 'orange'}, {'color': 'green'}], ax=ax)
    
    return

def negative_action(ax, pname):
    dfp = df[df['name']==pname]
    pteam = dfp.teamName.unique()[0]
    # dfteam = df[(df['teamName']==pteam) | (df['oppositionTeamName']==pteam)].reset_index(drop=True)
    dfteam = df[df['teamName']==pteam].reset_index(drop=True)

    pitch = VerticalPitch(pitch_type='uefa', pitch_color=bg_color,  linewidth=2, corner_arcs=True)
    pitch.draw(ax=ax)

    # Unsuccessful Pass
    up = 0
    for index, row in dfteam.iterrows():
        if (
            row['name'] == pname and 
            row['type'] == 'Carry' and 
            row['outcomeType'] == 'Successful' and 
            index + 1 < len(dfteam) and  
            dfteam.loc[index + 1, 'name'] == pname and
            dfteam.loc[index + 1, 'type'] == 'Pass' and
            dfteam.loc[index + 1, 'outcomeType'] == 'Unsuccessful' 
        ):
            pitch.scatter(row['x'], row['y'], s=25, color=col2, ax=ax)
            pitch.lines(row['x'], row['y'], dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], color=col2, lw=0.75, ls='--', ax=ax)
            arrow = patches.FancyArrowPatch((dfteam.loc[index + 1, 'y'], dfteam.loc[index + 1, 'x']), (dfteam.loc[index + 1, 'endY'], 
                                             dfteam.loc[index + 1, 'endX']), arrowstyle='->', color=col1, zorder=6, mutation_scale=10, alpha=0.75, linewidth=1)
            ax.add_patch(arrow)
            up += 1

    # Possession Lost
    pl = 0
    for index, row in dfteam.iterrows():
        if (
            row['name'] == pname and 
            row['type'] == 'Carry' and 
            row['outcomeType'] == 'Successful' and 
            index + 1 < len(dfteam) and  
            dfteam.loc[index + 1, 'name'] == pname and
            (
                dfteam.loc[index + 1, 'type'] == 'Dispossessed' or 
                dfteam.loc[index + 1, 'type'] == 'BallTouch'
            )
        ):
            pitch.scatter(row['x'], row['y'], s=25, color=col2, ax=ax)
            pitch.lines(row['x'], row['y'], dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], color=col2, lw=0.75, ls='--', ax=ax)
            pitch.scatter(dfteam.loc[index + 1, 'x'], dfteam.loc[index + 1, 'y'], s=100, color='orange', marker='x', ax=ax)
            pl += 1

    ax.set_title('After Carry Negative Impact', fontweight='bold')
    ax_text(34, -4, f'<Unsuccessful Pass: {up}> | <Possession Lost: {pl}>', ha='center', va='center', 
            highlight_textprops=[{'color': col1}, {'color': 'orange'}], ax=ax)
    ftmb_tid = df_teamNameId[df_teamNameId['teamName']==pteam].teamId.to_list()[0]
    return ftmb_tid

# %%
fig,axs = plt.subplots(1,2, figsize=(15,10), facecolor=bg_color)
positive_action(axs[0], 'Nico Williams')
ftmb_tid = negative_action(axs[1], 'Nico Williams')
fig.subplots_adjust(wspace=0.001)

fig.text(0.25, 1.02, 'Nico Williams', fontsize=30, fontweight='bold', va='center')
fig.text(0.25, 0.97, 'in LaLiga 2024-25 season  |  Data from: Opta  |  made by: @adnaaan433', fontsize=13, va='center')
# fig.text(0.25, 0.97, 'Data from: Opta | made by: @adnaaan433', fontsize=13, va='center')

fig.text(0.5, -0.01, '*Circle = Pass Received, Dotted Lines = Ball Carry after Receive', fontstyle='italic', ha='center', va='center')

himage = urlopen(f"https://images.fotmob.com/image_resources/logo/teamlogo/{ftmb_tid}.png")
himage = Image.open(himage)
ax_himage = add_image(himage, fig, left=0.13, bottom=0.95, width=0.1, height=0.1)
