# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.markers import MarkerStyle
from mplsoccer.pitch import Pitch
from mplsoccer import Pitch, VerticalPitch
import matplotlib.patches as patches
from collections import Counter
import matplotlib.patheffects as path_effects

import matplotlib.cm as cm
import matplotlib.colors as mcolors

from highlight_text import ax_text, fig_text
from PIL import Image
from mplsoccer import add_image
import urllib
from urllib.request import urlopen

# Print the modified DataFrame
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

green = '#69f900'
red = '#ff4b44'
blue = '#00a0de'
violet = '#a369ff'
bg_color= '#f5f5f5'
line_color= '#000000'
col1 = '#ff4b44'
col2 = '#00a0de'

# %%
df = pd.read_csv(r"D:\FData\LaLiga_2024_25\laliga_till_gw28.csv")

# %%
df_teamNameId = pd.read_csv(r"D:\FData\club_teams_logo\teams_name_and_id.csv")

# %% [markdown]
# # Prog_Pass

# %%
sorted_names = (sorted(df.name.dropna().unique()))
sorted_names
# Out:
# ['Abde Ezzalzouli',
#  'Abde Rebbach',
#  'Abdel Abqar',
#  'Abdon Prats',
#  'Abdoulaye Keita',
#  'Abdul Mumin',
#  'Abel Bretones',
#  'Abel Ruiz',
#  'Aboubacar Bassinga',
#  'Adam Aznou',
#  'Adama Boiro',
#  'Adnan Januzaj',
#  'Adri Embarba',
#  'Adria Alti',
#  'Adria Pedrosa',
#  'Adrian',
#  'Adrian Arnu',
#  'Adrian Nino',
#  'Adrian Pica',
#  'Adrian Rodriguez',
#  'Adu Ares',
#  'Aihen Munoz',
#  'Aimar Oroz',
#  'Aitor Paredes',
#  'Aitor Ruibal',
#  'Akor Adams',
#  'Albert Sambi Lokonga',
#  'Alberto Mari',
#  'Alberto Moleiro',
#  'Alberto Risco',
#  'Alejandro Balde',
#  'Alejandro Catena',
#  'Alejandro Frances',
#  'Alejandro Padilla',
#  'Alejo Veliz',
#  'Aleksandar Sedlar',
#  'Alex Baena',
#  'Alex Berenguer',
#  'Alex Kral',
#  'Alex Munoz',
#  'Alex Padilla',
#  'Alex Remiro',
#  'Alex Sola',
#  'Alex Suarez',
#  'Alexander Sorloth',
#  'Alfon Gonzalez',
#  'Alfonso Espino',
#  'Alfonso Pedraza',
#  'Allan Nyom',
#  'Alvaro Aguado',
#  'Alvaro Djalo',
#  'Alvaro Fernandez',
#  'Alvaro Garcia',
#  'Alvaro Odriozola',
#  'Alvaro Pascual',
#  'Alvaro Rodriguez',
#  'Alvaro Tejero',
#  'Amath Ndiaye',
#  'Ander Barrenetxea',
#  'Ander Guevara',
#  'Ander Herrera',
#  'Andoni Gorosabel',
#  'Andre Almeida',
#  'Andreas Christensen',
#  'Andrei Ratiu',
#  'Andrii Lunin',
#  'Andy Pelmard',
#  'Angel Correa',
#  'Angel Ortiz',
#  'Ansu Fati',
#  'Ante Budimir',
#  'Antoine Griezmann',
#  'Antonio Blanco',
#  'Antonio Candela',
#  'Antonio Raillo',
#  'Antonio Rudiger',
#  'Antonio Sanchez',
#  'Antonio Sivera',
#  'Antoniu Roca',
#  'Antony',
#  'Anuar Tuhami',
#  'Arda Guler',
#  'Aridane Hernandez',
#  'Aritz Arambarri',
#  'Aritz Elustondo',
#  'Arkaitz Mariezkurrena',
#  'Arnau Martinez',
#  'Arnaut Danjuma',
#  'Arsen Zakharyan',
#  'Arthur',
#  'Asier Villalibre',
#  'Assane Diao',
#  'Augusto Batalla',
#  'Aurelien Tchouameni',
#  'Axel Witsel',
#  'Ayoze Perez',
#  'Benat Prados',
#  'Benat Turrientes',
#  'Benito Ramirez',
#  'Bertug Yildirim',
#  'Bojan Miovski',
#  'Borja Iglesias',
#  'Borja Mayoral',
#  'Borna Barisic',
#  'Brahim Diaz',
#  'Brais Mendez',
#  'Brian Olivan',
#  'Bryan Gil',
#  'Bryan Zaragoza',
#  'Carl Starfelt',
#  'Carles Alena',
#  'Carles Perez',
#  'Carlos Benavidez',
#  'Carlos Dominguez',
#  'Carlos Guirao',
#  'Carlos Martin',
#  'Carlos Romero',
#  'Carlos Vicente',
#  'Cedric Bakambu',
#  'Cenk Ozkacar',
#  'Cesar Azpilicueta',
#  'Cesar Tarrega',
#  'Chema Andres',
#  'Chidera Ejuke',
#  'Chimy Avila',
#  'Chiquinho',
#  'Christantus Uche',
#  'Chuki',
#  'Clement Lenglet',
#  'Coba da Costa',
#  'Conor Gallagher',
#  'Copete',
#  'Cristhian Mosquera',
#  'Cristhian Stuani',
#  'Cucho Hernandez',
#  'Cyle Larin',
#  'Daley Blind',
#  'Daley Sinkgraven',
#  'Damian Rodriguez',
#  'Dani Cardenas',
#  'Dani Carvajal',
#  'Dani Ceballos',
#  'Dani Gomez',
#  'Dani Olmo',
#  'Dani Parejo',
#  'Dani Raba',
#  'Dani Rodriguez',
#  'Dani Vivian',
#  'Daniel Luna',
#  'Daniel Yanez',
#  'Dario Benavides',
#  'Dario Essugo',
#  'Darko Brasanac',
#  'Darwin Machis',
#  'David Alaba',
#  'David Arguelles',
#  'David Lopez',
#  'David Otorbi',
#  'David Soria',
#  'David Torres',
#  'Denis Suarez',
#  'Diego Conde',
#  'Diego Garcia',
#  'Diego Llorente',
#  'Diego Lopez',
#  'Diego Rico',
#  'Dimitri Foulquier',
#  'Dinko Horkas',
#  'Djene Dakonam',
#  'Djibril Sow',
#  'Dodi Lukebakio',
#  'Domingos Duarte',
#  'Dominik Greif',
#  'Donny van de Beek',
#  'Duk',
#  'Eder Militao',
#  'Edu Exposito',
#  'Eduardo Camavinga',
#  'Endika Bujan',
#  'Endrick',
#  'Enric Franquesa',
#  'Enzo Barrenechea',
#  'Enzo Boyomo',
#  'Enzo Loiodice',
#  'Eray Comert',
#  'Eric Bailly',
#  'Eric Garcia',
#  "Etienne Eto'o Pineda",
#  'Fabio Gonzalez',
#  'Fabio Silva',
#  'Facundo Garces',
#  'Federico Valverde',
#  'Ferland Mendy',
#  'Fermin Lopez',
#  'Fernando Calero',
#  'Fernando Lopez',
#  'Ferran Ruiz',
#  'Ferran Torres',
#  'Florian Grillitsch',
#  'Florian Lejeune',
#  'Fran Beltran',
#  'Fran Garcia',
#  'Fran Perez',
#  'Fran Vieites',
#  'Franco Cervi',
#  'Frenkie de Jong',
#  'Gabriel Misehouy',
#  'Garcia Pascual',
#  'Gavi',
#  'Gerard Gumbau',
#  'Gerard Martin',
#  'Gerard Moreno',
#  'German Valera',
#  'Giorgi Mamardashvili',
#  'Giovani Lo Celso',
#  'Giuliano Simeone',
#  'Gonzalo Montiel',
#  'Gorka Guruzeta',
#  'Gorka Rivera',
#  'Hamari Traore',
#  'Hector Bellerin',
#  'Hector Fort',
#  'Hugo Alvarez',
#  'Hugo Duro',
#  'Hugo Guillamon',
#  'Hugo Novoa',
#  'Hugo Sotelo',
#  'Iago Aspas',
#  'Igor Zubeldia',
#  'Iker Almena',
#  'Iker Benito',
#  'Iker Cordoba',
#  'Iker Losada',
#  'Iker Munoz',
#  'Ilaix Moriba',
#  'Ilias Akhomach',
#  'Inaki Pena',
#  'Inaki Williams',
#  'Inaki Williams Arthuer',
#  'Inigo Lekue',
#  'Inigo Martinez',
#  'Inigo Ruiz de Galarreta',
#  'Irvin Cardona',
#  'Isaac Romero',
#  'Isco',
#  'Isi Palazon',
#  'Ismael Bekhoucha',
#  'Israel Dominguez',
#  'Ivan Balliu',
#  'Ivan Jaime',
#  'Ivan Martin',
#  'Ivan Sanchez',
#  'Ivan Villar',
#  'Jailson',
#  'Jaime Mata',
#  'James Rodriguez',
#  'Jan Oblak',
#  'Jan Salas',
#  'Jasper Cillessen',
#  'Javi Galan',
#  'Javi Guerra',
#  'Javi Hernandez',
#  'Javi Llabres',
#  'Javi Lopez',
#  'Javi Martinez',
#  'Javi Munoz',
#  'Javi Puado',
#  'Javi Rodriguez',
#  'Javi Sanchez',
#  'Javier Manquillo',
#  'Javier Marton',
#  'Javier Rodriguez',
#  'Jesus Areso',
#  'Jesus Navas',
#  'Jesus Owono',
#  'Jesus Rodriguez',
#  'Jesus Vallejo',
#  'Jesus Vazquez',
#  'Jhon Solis',
#  'Joan Garcia',
#  'Joan Jordan',
#  'Jofre Carreras',
#  'Johan Mojica',
#  'John Patrick',
#  'Johnny Cardoso',
#  'Jon Aramburu',
#  'Jon Guridi',
#  'Jon Magunazelaia',
#  'Jon Martin',
#  'Jon Moncayola',
#  'Jon Olasagasti',
#  'Jon Pacheco',
#  'Jonathan Bamba',
#  'Jorge Herrando',
#  'Jorge Saenz',
#  'Jorge de Frutos',
#  'Jose Angel Carmona',
#  'Jose Arnaiz',
#  'Jose Campana',
#  'Jose Gaya',
#  'Jose Gimenez',
#  'Jose Gragera',
#  'Jose Maria Gimenez',
#  'Joseph Aidoo',
#  'Juan Bernat',
#  'Juan Berrocal',
#  'Juan Carlos',
#  'Juan Cruz',
#  'Juan Foyth',
#  'Juan Herzog',
#  'Juan Iglesias',
#  'Juan Musso',
#  'Juan Soriano',
#  'Juanlu Sanchez',
#  'Juanmi',
#  'Juanmi Latasa',
#  'Juanpe',
#  'Jude Bellingham',
#  'Julen Agirrezabala',
#  'Jules Kounde',
#  'Julian Alvarez',
#  'Julian Chicco',
#  'Juma Bah',
#  'Justin Smith',
#  'Karl Hein',
#  'Kelechi Iheanacho',
#  'Kenedy',
#  'Kike Barja',
#  'Kike Garcia',
#  'Kike Perez',
#  'Kike Salas',
#  'Kiko Femenia',
#  'Kim Min-Su',
#  'Kirian Rodriguez',
#  'Koke',
#  'Kylian Mbappe',
#  'Ladislav Krejci',
#  'Lamine Yamal',
#  'Leandro Antonetti',
#  'Leandro Cabrera',
#  'Leo Roman',
#  'Logan Costa',
#  'Loic Bade',
#  'Lorenzo Aguado',
#  'Luca de la Torre',
#  'Lucas Ocampos',
#  'Lucas Rosa',
#  'Lucas Torro',
#  'Lucas Vazquez',
#  'Lucien Agoume',
#  'Luis Milla',
#  'Luis Perez',
#  'Luis Rioja',
#  'Luiz Junior',
#  'Luka Modric',
#  'Luka Romero',
#  'Luka Sucic',
#  'Luken Beitia',
#  'Mamadou Sylla',
#  'Manu Bueno',
#  'Manu Fuster',
#  'Manu Morlanes',
#  'Manu Sanchez',
#  'Marash Kumbulla',
#  'Marc Bartra',
#  'Marc Bernal',
#  'Marc Cardona',
#  'Marc Casado',
#  'Marc Domenech',
#  'Marc Roca',
#  'Marc-Andre ter Stegen',
#  'Marcao',
#  'Marcos Alonso',
#  'Marcos Andre',
#  'Marcos Llorente',
#  'Mario Maroto',
#  'Mario Martin',
#  'Marko Dmitrovic',
#  'Maroan Sannadi',
#  'Martin Tejon',
#  'Martin Valjent',
#  'Martin Zubimendi',
#  'Marvin Park',
#  'Mateo Flores',
#  'Mateo Mejia',
#  'Mateu Morey',
#  'Matija Nastasic',
#  'Mauro Arambarri',
#  'Max Aarons',
#  'Maximiliano Caufriez',
#  'Miguel Gutierrez',
#  'Miguel de la Fuente',
#  'Mihailo Ristic',
#  'Mika Marmol',
#  'Mikel Jauregizar',
#  'Mikel Oyarzabal',
#  'Mikel Vesga',
#  'Moi Gomez',
#  'Mouctar Diakhaby',
#  'Moussa Diarra',
#  'Munir El Haddadi',
#  'Nabil Aberdin',
#  'Nabil Fekir',
#  'Nacho Vidal',
#  'Naci Unuvar',
#  'Nahuel Molina',
#  'Nahuel Tenaglia',
#  'Natan',
#  'Nayef Aguerd',
#  'Nemanja Gudelj',
#  'Nico Serrano',
#  'Nico Williams',
#  'Nicolas Pepe',
#  'Oihan Sancet',
#  'Oliver McBurnie',
#  'Omar Alderete',
#  'Omar El Hilali',
#  'Omar Mascarell',
#  'Oriol Romeu',
#  'Orjan Nyland',
#  'Orri Oskarsson',
#  'Oscar De Marcos',
#  'Oscar Mingueza',
#  'Oscar Rodriguez',
#  'Oscar Trejo',
#  'Oscar Valentin',
#  'Pablo Barrios',
#  'Pablo Duran',
#  'Pablo Fornals',
#  'Pablo Garcia',
#  'Pablo Ibanez',
#  'Pablo Maffeo',
#  'Pablo Marin',
#  'Pablo Torre',
#  'Papa Dame Ba',
#  'Pape Gueye',
#  'Pathe Ciss',
#  'Pau Cabanes',
#  'Pau Cabanes De La Torre',
#  'Pau Cubarsi',
#  'Pau Lopez',
#  'Pau Navarro',
#  'Pau Victor',
#  'Paulo Gazzaniga',
#  'Pedri',
#  'Pedro Diaz',
#  'Peio Canales',
#  'Pejino',
#  'Pep Chavarria',
#  'Pepelu',
#  'Peque',
#  'Peque Fernandez',
#  'Pere Milla',
#  'Peter Federico',
#  'Pol Lozano',
#  'Portu',
#  'Rafa Mir',
#  'Rafael Bauza',
#  'Ramon Martinez',
#  'Ramon Terrats',
#  'Randy Nteka',
#  'Raphinha',
#  'Raul',
#  'Raul Albiol',
#  'Raul Asencio',
#  'Raul Chasco',
#  'Raul Garcia',
#  'Raul Moro',
#  'Reinildo',
#  'Renato Tapia',
#  'Ricardo Rodriguez',
#  'Robert Lewandowski',
#  'Robert Navarro',
#  'Roberto Fernandez',
#  'Roberto Lopez',
#  'Robin Le Normand',
#  'Rodri',
#  'Rodrigo Abajas',
#  'Rodrigo De Paul',
#  'Rodrigo Riquelme',
#  'Rodrygo',
#  'Romain Perraud',
#  'Ronald Araujo',
#  'Ruben Garcia',
#  'Ruben Pena',
#  'Ruben Vargas',
#  'Rui Silva',
#  'Samu Costa',
#  'Samuel Lino',
#  'Sandro Ramirez',
#  'Santi Comesana',
#  'Santiago Mourino',
#  'Saul Niguez',
#  'Scott McKenna',
#  'Sebastien Haller',
#  'Selim Amallah',
#  'Sergi Altimira',
#  'Sergi Canos',
#  'Sergi Cardona',
#  'Sergi Darder',
#  'Sergi Dominguez',
#  'Sergi Gomez',
#  'Sergi Guardiola',
#  'Sergio Arribas',
#  'Sergio Camello',
#  'Sergio Carreira',
#  'Sergio Gomez',
#  'Sergio Gonzalez',
#  'Sergio Herrera',
#  'Seydouba Cisse',
#  'Sheraldo Becker',
#  'Siebe Van der Heyden',
#  'Silvi Clua',
#  'Stanis Idumbo',
#  'Stanis Idumbo Muzambo',
#  'Stanko Juric',
#  'Stefan Bajcetic',
#  'Stoichkov',
#  'Stole Dimitrievski',
#  'Suso',
#  'Tadeo Allende',
#  'Tajon Buchanan',
#  'Takefusa Kubo',
#  'Takuma Asano',
#  'Tamas Nikitscher',
#  'Tanguy Nianzou',
#  'Tasos Douvikas',
#  'Thiago Ojeda',
#  'Thibaut Courtois',
#  'Thierno Barry',
#  'Thierry Correia',
#  'Thomas Lemar',
#  'Tomas Conechny',
#  'Toni Lato',
#  'Toni Martinez',
#  'Umar Sadiq',
#  'Unai Gomez',
#  'Unai Lopez',
#  'Unai Marrero',
#  'Unai Nunez',
#  'Unai Simon',
#  'Urko Gonzalez',
#  'Valentin Barco',
#  'Valentin Pezzolesi',
#  'Valentin Rosier',
#  'Valery Fernandez',
#  'Vedat Muriqi',
#  'Vicente Guaita',
#  'Victor Meseguer',
#  'Viktor Tsygankov',
#  'Viktor Tsyhankov',
#  'Vinicius Junior',
#  'Viti Rozada',
#  'Vitor Roque',
#  'Walid Cheddira',
#  'William Carvalho',
#  'Williot Swedberg',
#  'Willy Kambwala',
#  'Wojciech Szczesny',
#  'Yangel Herrera',
#  'Yarek Gasiorowski',
#  'Yaser Asprilla',
#  'Yellu Santiago',
#  'Yeray Alvarez',
#  'Yeremy Pino',
#  'Yoel Lago',
#  'Youssouf Sabaly',
#  'Yuri Berchiche',
#  'Yvan Neyou']

# %%
ftmb_tid = df_teamNameId[df_teamNameId['teamName']=='AC Milan']['teamId'].values[0]
ftmb_tid
# Out:
# 8564

# %%
def plot_prog_pass(ax, pname):
    dfp = df[(df['name'] == pname) & (df['prog_pass'] >= 9.11) & (~df['qualifiers'].str.contains('Corner|Freekick|ThrowIn')) & (df['x'] >= 35)]
    suc = dfp[dfp['outcomeType'] == 'Successful']
    # uns = dfp[dfp['outcomeType'] == 'Unsuccessful']
    team_name = dfp.teamName.unique()[0]
    ftmb_tid = df_teamNameId[df_teamNameId['teamName']==team_name]['teamId'].values[0]

    pitch = VerticalPitch(pitch_type='uefa', pitch_color='#f5f5f5', line_color='k', linewidth=2, corner_arcs=True)
    pitch.draw(ax=ax)
    ax.set_xlim(68.5, -0.5)
    ax.set_ylim(-0.5, 105.5)

    pitch.lines(suc.x, suc.y, suc.endX, suc.endY, color=col2, lw=2.5, comet=True, transparent=True, zorder=4, ax=ax)
    pitch.scatter(suc.endX, suc.endY, color=bg_color, edgecolor=col2, zorder=5, ax=ax)

    # pitch.lines(uns.x, uns.y, uns.endX, uns.endY, color=col1, lw=2, comet=True, transparent=True, alpha=0.75, zorder=2, ax=ax)
    # pitch.scatter(uns.endX, uns.endY, color=bg_color, edgecolor=col1, zorder=3, ax=ax)

    ax.text(57, 118, f'{pname}', fontsize=20, fontweight='bold', ha='left', va='center')
    ax.text(57, 113, f'Open-Play Successful Progressive Passes', fontsize=12, ha='left', va='center')
    ax.text(57, 109, f'in {team_name}, LaLiga 2024-25 season', fontsize=12, ha='left', va='center')

    # ax_text(34, 109, f'<Successful: {len(suc)}>   |   <Unsuccessful: {len(uns)}>', fontsize=12, ha='center', va='center', ax=ax,
    #         highlight_textprops=[{'color': col2}, {'color': col1}])

    IMAGE_URL = f"https://images.fotmob.com/image_resources/logo/teamlogo/{ftmb_tid}.png"
    image = Image.open(urlopen(IMAGE_URL))
    ax_image = pitch.inset_image(113, 65, image, height=10, ax=ax)

fig,ax = plt.subplots(figsize=(10,10))
plot_prog_pass(ax, 'Johnny Cardoso')

# %%
def tackles_int(ax, pname):
    dfp = df[(df['name'] == pname) & (df['type'].isin(['Tackle', 'Interception']))]
    stk = dfp[(dfp['type']=='Tackle') & (dfp['outcomeType']=='Successful')]
    utk = dfp[(dfp['type']=='Tackle') & (dfp['outcomeType']=='Unsuccessful')]
    intc = dfp[dfp['type']=='Interception']
    team_name = dfp.teamName.unique()[0]
    ftmb_tid = df_teamNameId[df_teamNameId['teamName']==team_name]['teamId'].values[0]

    pitch = VerticalPitch(pitch_type='uefa', pitch_color='#f5f5f5', line_color='k', linewidth=2, corner_arcs=True)
    pitch.draw(ax=ax)
    ax.set_xlim(68.5, -0.5)
    ax.set_ylim(-0.5, 105.5)

    pitch.scatter(stk.x, stk.y, marker='x', s=200, lw=3, c='g', zorder=5, ax=ax)
    pitch.scatter(utk.x, utk.y, marker='x', s=200, lw=3, c=col1, zorder=3, ax=ax)
    pitch.scatter(intc.x, intc.y, marker='o', s=200, c='None', ec=col2, lw=2, zorder=4, ax=ax)

    ax.text(57, 125, f'{pname}', fontsize=20, fontweight='bold', ha='left', va='center')
    ax.text(57, 120, f'Tackles and Interceptions', fontsize=12, ha='left', va='center')
    ax.text(57, 116, f'in {team_name}, LaLiga 2024-25 season', fontsize=12, ha='left', va='center')

    ax_text(34, 109, f'<Successful Tackles: {len(stk)}> | <Unsuccessful Tackles: {len(utk)}> | <Interceptions: {len(intc)}>', 
            fontsize=10, ha='center', va='center', ax=ax, 
            highlight_textprops=[{'color': 'g'}, {'color': col1}, {'color': col2}])

    IMAGE_URL = f"https://images.fotmob.com/image_resources/logo/teamlogo/{ftmb_tid}.png"
    image = Image.open(urlopen(IMAGE_URL))
    ax_image = pitch.inset_image(120, 65, image, height=10, ax=ax)

fig,ax = plt.subplots(figsize=(10,10))
tackles_int(ax, 'Martin Zubimendi')

# %%
def plot_player_prog_pass(ax, pname):
    dfp = df[(df['name'] == pname) & (df['prog_pass'] >= 9.11) & (df['outcomeType'] == 'Successful') &
             (~df['qualifiers'].str.contains('Corner|Freekick|ThrowIn')) & (df['x'] >= 35)]
    dfpen = df[(df['name']==pname) & (df['endX']>=87.5) & (df['endY']>=13.6) & (df['endY']<=54.4) & (df['outcomeType']=='Successful') &
            (~df['qualifiers'].str.contains('Corner|Freekick|ThrowIn')) & (df['prog_pass']<9.11) & (df['type']=='Pass')]
    dfp = pd.concat([dfp,dfpen])
    
    pitch = Pitch(pitch_type='uefa', pitch_color='#f5f5f5', line_color='k', linewidth=2, corner_arcs=True)
    pitch.draw(ax=ax)
    ax.set_xlim(-0.75, 105.25)
    ax.set_ylim(-0.75, 68.25)

    df1 = dfp[dfp['xT']<=0.005]
    df2 = dfp[(dfp['xT']>0.005) & (dfp['xT']<=0.02)]
    df3 = dfp[(dfp['xT']>0.02) & (dfp['xT']<=0.03)]
    df4 = dfp[(dfp['xT']>0.03) & (dfp['xT']<=0.04)]
    df5 = dfp[(dfp['xT']>0.04)]

    pitch.lines(df1.x, df1.y, df1.endX, df1.endY, color='#ffc6a2', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df2.x, df2.y, df2.endX, df2.endY, color='#19a28e', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df3.x, df3.y, df3.endX, df3.endY, color='#30d7bf', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df4.x, df4.y, df4.endX, df4.endY, color='#674586', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df5.x, df5.y, df5.endX, df5.endY, color='#a043ae', lw=2.5, comet=True, transparent=True, ax=ax)

    # ax.scatter(dfp.endX, dfp.endY, s=20, color='#f5f5f5', edgecolor='#ff4b44', zorder=2)
    xT = dfp['xT'].sum().round(2)
    show_name = dfp['shortName'].unique()[0]
    
    ax.set_title(f'{show_name}: {len(dfp)}', color='k', fontsize=25, fontweight='bold', y=1.07)
    ax.text(52.5, 71, f'xT by Prog. Pass: {xT}', color='k', fontsize=16, ha='center', va='center')
    # ax.scatter(4, 4, s=1000, marker='h', color='#808080')
    # ax.scatter(4+6, 4, s=1000, marker='h', color='#1f928b')
    # ax.scatter(4+12, 4, s=1000, marker='h', color='#38b977')
    # ax.scatter(4+18, 4, s=1000, marker='h', color='#91da3b')
    # ax.scatter(4+24, 4, s=1000, marker='h', color='#fce724')
    # path_eff = [path_effects.Stroke(linewidth=1, foreground='k'), path_effects.Normal()]
    # ax.text(4, 4, '<0.005', color='k', ha='center', va='center', fontsize=8, path_effects=path_eff)
    # ax.text(4+6, 4, '<0.02', color='k', ha='center', va='center', fontsize=8, path_effects=path_eff)
    # ax.text(4+12, 4, '<0.03', color='k', ha='center', va='center', fontsize=8, path_effects=path_eff)
    # ax.text(4+18, 4, '<0.04', color='k', ha='center', va='center', fontsize=8, path_effects=path_eff)
    # ax.text(4+24, 4, '<0.05', color='k', ha='center', va='center', fontsize=8, path_effects=path_eff)

    team_name = dfp['teamName'].unique()
    team_name = team_name[0]
    # Take data coordinates and transform them to normalized figure coordinates
    DC_to_FC = ax.transData.transform
    FC_to_NFC = fig.transFigure.inverted().transform
    DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))
    ax_coords = DC_to_NFC((0,66))
    ax_size = 0.02
    image_ax = fig.add_axes([ax_coords[0], ax_coords[1], ax_size, ax_size], fc='None', anchor='C')
    fotmob_url = f'https://raw.githubusercontent.com/adnaaan433/club_teams_logos/main/{team_name}.png'
    fotmob_url = fotmob_url.replace(' ', '%20')
    club_icon = Image.open(urllib.request.urlopen(fotmob_url))
    image_ax.imshow(club_icon)
    image_ax.axis('off')
    
    return

fig, ax = plt.subplots(figsize=(10,10), facecolor='#f5f5f5')
plot_player_prog_pass(ax, "Antonio Rüdiger")

# %%
def plot_player_prog_pass(ax, pname):
    dfp = df[(df['name'] == pname) & (df['prog_pass'] >= 9.11) & (df['outcomeType'] == 'Successful') &
             (~df['qualifiers'].str.contains('Corner|Freekick|ThrowIn')) & (df['x'] >= 35)]
    dfpen = df[(df['name']==pname) & (df['endX']>=87.5) & (df['endY']>=13.6) & (df['endY']<=54.4) & (df['outcomeType']=='Successful') &
            (~df['qualifiers'].str.contains('Corner|Freekick|ThrowIn')) & (df['prog_pass']<9.11) & (df['type']=='Pass')]
    dfp = pd.concat([dfp,dfpen])
    
    pitch = Pitch(pitch_type='uefa', pitch_color='#262626', line_color='w', linewidth=2, corner_arcs=True)
    pitch.draw(ax=ax)
    ax.set_xlim(-0.75, 105.25)
    ax.set_ylim(-0.75, 68.25)

    df1 = dfp[dfp['xT']<=0.005]
    df2 = dfp[(dfp['xT']>0.005) & (dfp['xT']<=0.02)]
    df3 = dfp[(dfp['xT']>0.02) & (dfp['xT']<=0.03)]
    df4 = dfp[(dfp['xT']>0.03) & (dfp['xT']<=0.04)]
    df5 = dfp[(dfp['xT']>0.04)]

    pitch.lines(df1.x, df1.y, df1.endX, df1.endY, color='#808080', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df2.x, df2.y, df2.endX, df2.endY, color='#1f928b', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df3.x, df3.y, df3.endX, df3.endY, color='#38b977', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df4.x, df4.y, df4.endX, df4.endY, color='#91da3b', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df5.x, df5.y, df5.endX, df5.endY, color='#fce724', lw=2.5, comet=True, transparent=True, ax=ax)

    # ax.scatter(dfp.endX, dfp.endY, s=20, color='#f5f5f5', edgecolor='#ff4b44', zorder=2)
    xT = dfp['xT'].sum().round(2)
    show_name = dfp['shortName'].unique()[0]
    
    ax.set_title(f'{show_name}: {len(dfp)}', color='w', fontsize=25, fontweight='bold', y=1.07)
    ax.text(52.5, 71, f'xT by Prog. Pass: {xT}', color='w', fontsize=16, ha='center', va='center')
    # ax.scatter(4, 4, s=1000, marker='h', color='#808080')
    # ax.scatter(4+6, 4, s=1000, marker='h', color='#1f928b')
    # ax.scatter(4+12, 4, s=1000, marker='h', color='#38b977')
    # ax.scatter(4+18, 4, s=1000, marker='h', color='#91da3b')
    # ax.scatter(4+24, 4, s=1000, marker='h', color='#fce724')
    # path_eff = [path_effects.Stroke(linewidth=1, foreground='k'), path_effects.Normal()]
    # ax.text(4, 4, '<0.005', color='w', ha='center', va='center', fontsize=8, path_effects=path_eff)
    # ax.text(4+6, 4, '<0.02', color='w', ha='center', va='center', fontsize=8, path_effects=path_eff)
    # ax.text(4+12, 4, '<0.03', color='w', ha='center', va='center', fontsize=8, path_effects=path_eff)
    # ax.text(4+18, 4, '<0.04', color='w', ha='center', va='center', fontsize=8, path_effects=path_eff)
    # ax.text(4+24, 4, '<0.05', color='w', ha='center', va='center', fontsize=8, path_effects=path_eff)

    team_name = dfp['teamName'].unique()
    team_name = team_name[0]
    # Take data coordinates and transform them to normalized figure coordinates
    DC_to_FC = ax.transData.transform
    FC_to_NFC = fig.transFigure.inverted().transform
    DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))
    ax_coords = DC_to_NFC((0,66))
    ax_size = 0.02
    image_ax = fig.add_axes([ax_coords[0], ax_coords[1], ax_size, ax_size], fc='None', anchor='C')
    fotmob_url = f'https://raw.githubusercontent.com/adnaaan433/club_teams_logos/main/{team_name}.png'
    fotmob_url = fotmob_url.replace(' ', '%20')
    club_icon = Image.open(urllib.request.urlopen(fotmob_url))
    image_ax.imshow(club_icon)
    image_ax.axis('off')
    
    return

fig, ax = plt.subplots(figsize=(10,10), facecolor='#313332')
plot_player_prog_pass(ax, "Antonio Rüdiger")

# %%
dfp = df[(df['prog_pass'] >= 9.11) & (df['outcomeType'] == 'Successful') &
             (~df['qualifiers'].str.contains('Corner|Freekick|ThrowIn')) & (df['x'] >= 35)]
dfpen = df[(df['endX']>=87.5) & (df['endY']>=13.6) & (df['endY']<=54.4) & (df['outcomeType']=='Successful') & (df['prog_pass']<9.11) &
            (~df['qualifiers'].str.contains('Corner|Freekick|ThrowIn')) & (df['type']=='Pass')]
dfp = pd.concat([dfp,dfpen])

dfpp = dfp.groupby(['name']).count()
dfpp = dfpp.sort_values(by='xT', ascending=False)
top10 = dfpp['xT'].head(12)
top10 = top10.reset_index()
top10 = top10['name'].unique()

top10
# Out:
# array(['Toni Kroos', 'Antonio Rüdiger', 'Giovanni Di Lorenzo',
#        'Joshua Kimmich', 'Kieran Trippier', 'Denis Vavro', 'Jules Koundé',
#        'Théo Hernández', 'Milan Skriniar', 'Jannik Vestergaard',
#        'Dayot Upamecano', 'Virgil van Dijk'], dtype=object)

# %%
players = top10

fig, axs = plt.subplots(4, 3, figsize=(30, 30), facecolor='#262626')

for i, player in enumerate(players):
    row = i // 3
    col = i % 3
    plot_player_prog_pass(axs[row, col], player)

fig.text(0.2, 0.95, 'Top Progressive Passers, EURO 2024', color='w', fontsize=45, fontweight='bold')
fig_text(0.2, 0.94, 'Open play Progressive passes, in Group stage | <Low xT>, <medium xT> and <high xT> Passes | made by: @adnaan433', 
         color='w', fontsize=22, highlight_textprops=[{'color':'#808080'}, {'color':'#38b977'}, {'color':'#fce724'}])

image_url = 'https://raw.githubusercontent.com/adnaaan433/league_logos/main/EURO2024.png'
image = urlopen(image_url)
image = Image.open(image)
ax_image = add_image(image, fig, left=0.13, bottom=0.92, width=0.05, height=0.05)

# %% [markdown]
# # Prog_Carry

# %%
def plot_player_prog_carry(ax, pname):
    dfp = df[(df['name'] == pname) & (df['prog_carry'] >= 9.11) & (df['outcomeType'] == 'Successful') & (df['x'] >= 35)]
    dfpen = df[(df['name']==pname) & (df['endX']>=87.5) & (df['endY']>=13.6) & (df['endY']<=54.4) & (df['prog_carry']<9.11) & (df['type']=='Carry')]
    dfp = pd.concat([dfp,dfpen])
    
    pitch = Pitch(pitch_type='uefa', pitch_color='#262626', line_color='w', linewidth=2, corner_arcs=True)
    pitch.draw(ax=ax)
    ax.set_xlim(-0.75, 105.25)
    ax.set_ylim(-0.75, 68.25)

    df1 = dfp[dfp['xT']<=0.005]
    df2 = dfp[(dfp['xT']>0.005) & (dfp['xT']<=0.02)]
    df3 = dfp[(dfp['xT']>0.02) & (dfp['xT']<=0.03)]
    df4 = dfp[(dfp['xT']>0.03) & (dfp['xT']<=0.04)]
    df5 = dfp[(dfp['xT']>0.04)]

    pitch.lines(df1.x, df1.y, df1.endX, df1.endY, color='#808080', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df2.x, df2.y, df2.endX, df2.endY, color='#1f928b', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df3.x, df3.y, df3.endX, df3.endY, color='#38b977', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df4.x, df4.y, df4.endX, df4.endY, color='#91da3b', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df5.x, df5.y, df5.endX, df5.endY, color='#fce724', lw=2.5, comet=True, transparent=True, ax=ax)

    # ax.scatter(dfp.endX, dfp.endY, s=20, color='#f5f5f5', edgecolor='#ff4b44', zorder=2)
    xT = dfp['xT'].sum().round(2)
    show_name = dfp['shortName'].unique()[0]
    
    ax.set_title(f'{show_name}: {len(dfp)}', color='w', fontsize=25, fontweight='bold', y=1.07)
    ax.text(52.5, 71, f'xT by Prog. Pass: {xT}', color='w', fontsize=16, ha='center', va='center')
    # ax.scatter(4, 4, s=1000, marker='h', color='#808080')
    # ax.scatter(4+6, 4, s=1000, marker='h', color='#1f928b')
    # ax.scatter(4+12, 4, s=1000, marker='h', color='#38b977')
    # ax.scatter(4+18, 4, s=1000, marker='h', color='#91da3b')
    # ax.scatter(4+24, 4, s=1000, marker='h', color='#fce724')
    # path_eff = [path_effects.Stroke(linewidth=1, foreground='k'), path_effects.Normal()]
    # ax.text(4, 4, '<0.005', color='w', ha='center', va='center', fontsize=8, path_effects=path_eff)
    # ax.text(4+6, 4, '<0.02', color='w', ha='center', va='center', fontsize=8, path_effects=path_eff)
    # ax.text(4+12, 4, '<0.03', color='w', ha='center', va='center', fontsize=8, path_effects=path_eff)
    # ax.text(4+18, 4, '<0.04', color='w', ha='center', va='center', fontsize=8, path_effects=path_eff)
    # ax.text(4+24, 4, '<0.05', color='w', ha='center', va='center', fontsize=8, path_effects=path_eff)

    team_name = dfp['teamName'].unique()
    team_name = team_name[0]
    # Take data coordinates and transform them to normalized figure coordinates
    DC_to_FC = ax.transData.transform
    FC_to_NFC = fig.transFigure.inverted().transform
    DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))
    ax_coords = DC_to_NFC((0,68))
    ax_size = 0.02
    image_ax = fig.add_axes([ax_coords[0], ax_coords[1], ax_size, ax_size], fc='None', anchor='C')
    fotmob_url = f'https://raw.githubusercontent.com/adnaaan433/club_teams_logos/main/{team_name}.png'
    fotmob_url = fotmob_url.replace(' ', '%20')
    club_icon = Image.open(urllib.request.urlopen(fotmob_url))
    image_ax.imshow(club_icon)
    image_ax.axis('off')
    
    return

fig, ax = plt.subplots(figsize=(10,10), facecolor='#313332')
plot_player_prog_carry(ax, "Rafael Leão")

# %%
# dfp = df[(df['prog_carry']>=9.11) & (df['outcomeType']=='Successful') & 
#              (~df['qualifiers'].str.contains('CornerTaken|Cross|Freekick|ThrowIn')) & (df['x']>=35)]
# dfp_xT = dfp.groupby(['name']).sum().round(2)
# dfp_xt = dfp_xT.sort_values(by='xT', ascending=False)
# top10 = dfp_xt['xT'].head(20)
# top10 = top10.reset_index()
# top10 = top10['name'].unique()
# print(top10)

# %%
dfp = df[(df['prog_carry']>=9.11) & (df['outcomeType']=='Successful') & (df['x']>=35)]
dfpen = df[(df['endX']>=87.5) & (df['endY']>=13.6) & (df['endY']<=54.4) & (df['outcomeType']=='Successful') & (df['prog_carry']<9.11)
            & (df['type']=='Carry')]
dfp = pd.concat([dfp,dfpen])
dfp_xT = dfp.groupby(['name']).count().round(2)
dfp_xt = dfp_xT.sort_values(by='xT', ascending=False)
top10 = dfp_xt['xT'].head(12)
top10 = top10.reset_index()
top10 = top10['name'].unique()
print(top10)
# Out:
# ['Jérémy Doku' 'Jamal Musiala' 'Ousmane Dembélé' 'Mateo Kovacic'
#  'Ferdi Kadioglu' 'Khvicha Kvaratskhelia' 'Kylian Mbappé' 'Cody Gakpo'
#  'Bernardo Silva' 'Baris Alper Yilmaz' 'Piotr Zielinski' 'Florian Wirtz']

# %%
players = top10

fig, axs = plt.subplots(4, 3, figsize=(30, 30), facecolor='#262626')

for i, player in enumerate(players):
    row = i // 3
    col = i % 3
    plot_player_prog_carry(axs[row, col], player)

fig.text(0.2, 0.95, 'Top Progressive ball Carriers, EURO 2024', color='w', fontsize=45, fontweight='bold')
fig_text(0.2, 0.94, 'Progressive carries, in Group stage | <Low xT>, <medium xT> and <high xT> Passes | made by: @adnaan433', 
         color='w', fontsize=22, highlight_textprops=[{'color':'#808080'}, {'color':'#38b977'}, {'color':'#fce724'}])

image_url = 'https://raw.githubusercontent.com/adnaaan433/league_logos/main/EURO2024.png'
image = urlopen(image_url)
image = Image.open(image)
ax_image = add_image(image, fig, left=0.13, bottom=0.92, width=0.05, height=0.05)

# %% [markdown]
# # Threat

# %% [markdown]
# Pass

# %%
def plot_top_xTP(ax, pname):
    dfp = df[(df['name']==pname) & (df['type']=='Pass') & (df['outcomeType']=='Successful') & 
             (~df['qualifiers'].str.contains('Corner|Freekick|ThrowIn'))]
    dfkp = dfp[dfp['qualifiers'].str.contains('KeyPass')]
    dfas = dfp[dfp['qualifiers'].str.contains('IntentionalGoalAssist')]

    pitch = Pitch(pitch_type='uefa', pitch_color='#262626', line_color='w', linewidth=2, corner_arcs=True)
    pitch.draw(ax=ax)
    ax.set_xlim(-0.75, 105.25)
    ax.set_ylim(-0.75, 68.25)

    df1 = dfp[dfp['xT']<=0.005]
    df2 = dfp[(dfp['xT']>0.005) & (dfp['xT']<=0.02)]
    df3 = dfp[(dfp['xT']>0.02) & (dfp['xT']<=0.03)]
    df4 = dfp[(dfp['xT']>0.03) & (dfp['xT']<=0.04)]
    df5 = dfp[(dfp['xT']>0.04)]

    pitch.lines(df1.x, df1.y, df1.endX, df1.endY, color='#808080', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df2.x, df2.y, df2.endX, df2.endY, color='#1f928b', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df3.x, df3.y, df3.endX, df3.endY, color='#38b977', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df4.x, df4.y, df4.endX, df4.endY, color='#91da3b', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df5.x, df5.y, df5.endX, df5.endY, color='#fce724', lw=2.5, comet=True, transparent=True, ax=ax)

    ax.scatter(dfkp.endX, dfkp.endY, s=40, color='#262626', edgecolor='#ff4b44', zorder=2)
    ax.scatter(dfas.endX, dfas.endY, s=40, color='#ff4b44', edgecolor='w', zorder=3)
    xT = dfp['xT'].sum().round(2)
    show_name = dfp['shortName'].unique()[0]
    
    ax.set_title(f'{show_name}: {xT} xT', color='w', fontsize=25, fontweight='bold', y=1.07)
    # ax.text(52.5, 71, f'xT by Prog. Pass: {xT}', color='w', fontsize=16, ha='center', va='center')

    team_name = dfp['teamName'].unique()
    team_name = team_name[0]
    # Take data coordinates and transform them to normalized figure coordinates
    DC_to_FC = ax.transData.transform
    FC_to_NFC = fig.transFigure.inverted().transform
    DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))
    ax_coords = DC_to_NFC((0,66))
    ax_size = 0.02
    image_ax = fig.add_axes([ax_coords[0], ax_coords[1], ax_size, ax_size], fc='None', anchor='C')
    fotmob_url = f'https://raw.githubusercontent.com/adnaaan433/club_teams_logos/main/{team_name}.png'
    fotmob_url = fotmob_url.replace(' ', '%20')
    club_icon = Image.open(urllib.request.urlopen(fotmob_url))
    image_ax.imshow(club_icon)
    image_ax.axis('off')
    
    return

fig, ax = plt.subplots(figsize=(10,10), facecolor='#313332')
plot_top_xTP(ax, "Antonio Rüdiger")

# %%
dfp = df[(df['type']=='Pass') & (df['outcomeType']=='Successful') & 
             (~df['qualifiers'].str.contains('Corner|Freekick|ThrowIn'))]
dfp_xT = dfp.groupby(['name']).sum().round(2)
dfp_xt = dfp_xT.sort_values(by='xT', ascending=False)
top10df = dfp_xt['xT'].head(12)
top10 = top10df.reset_index()
top10 = top10['name'].unique()
top10df
# Out:
# name
# Toni Kroos               1.18
# Andrija Zivkovic         1.12
# Ivan Perisic             0.91
# Cody Gakpo               0.89
# Joshua Kimmich           0.87
# Jérémy Doku              0.87
# Dusan Tadic              0.68
# Antonio Rüdiger          0.68
# Khvicha Kvaratskhelia    0.68
# Baris Alper Yilmaz       0.61
# Federico Chiesa          0.60
# Denzel Dumfries          0.56
# Name: xT, dtype: float64

# %%
players = top10

fig, axs = plt.subplots(4, 3, figsize=(30, 30), facecolor='#262626')

for i, player in enumerate(players):
    row = i // 3
    col = i % 3
    plot_top_xTP(axs[row, col], player)

fig.text(0.2, 0.95, 'Top Threatening Passers, EURO 2024', color='w', fontsize=45, fontweight='bold')
fig_text(0.2, 0.94, 'Open play passes, in Group stage | <Low xT>, <medium xT> and <high xT> Passes | made by: @adnaan433', 
         color='w', fontsize=22, highlight_textprops=[{'color':'#808080'}, {'color':'#38b977'}, {'color':'#fce724'}])

image_url = 'https://raw.githubusercontent.com/adnaaan433/league_logos/main/EURO2024.png'
image = urlopen(image_url)
image = Image.open(image)
ax_image = add_image(image, fig, left=0.13, bottom=0.92, width=0.05, height=0.05)

# %% [markdown]
# Carry

# %%
def plot_top_xTC(ax, pname):
    dfp = df[(df['name']==pname) & (df['type']=='Carry')]
    # dfkp = df[(df['name']==pname) & (df['type']=='Carry') & (df['qualifiers'].shift(-1).str.contains('KeyPass'))]
    # dfas = dfp[dfp['qualifiers'].str.contains('IntentionalGoalAssist')]

    pitch = Pitch(pitch_type='uefa', pitch_color='#262626', line_color='w', linewidth=2, corner_arcs=True)
    pitch.draw(ax=ax)
    ax.set_xlim(-0.75, 105.25)
    ax.set_ylim(-0.75, 68.25)

    df1 = dfp[dfp['xT']<=0.005]
    df2 = dfp[(dfp['xT']>0.005) & (dfp['xT']<=0.02)]
    df3 = dfp[(dfp['xT']>0.02) & (dfp['xT']<=0.03)]
    df4 = dfp[(dfp['xT']>0.03) & (dfp['xT']<=0.04)]
    df5 = dfp[(dfp['xT']>0.04)]

    pitch.lines(df1.x, df1.y, df1.endX, df1.endY, color='#808080', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df2.x, df2.y, df2.endX, df2.endY, color='#1f928b', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df3.x, df3.y, df3.endX, df3.endY, color='#38b977', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df4.x, df4.y, df4.endX, df4.endY, color='#91da3b', lw=2.5, comet=True, transparent=True, ax=ax)
    pitch.lines(df5.x, df5.y, df5.endX, df5.endY, color='#fce724', lw=2.5, comet=True, transparent=True, ax=ax)

    # ax.scatter(dfkp.endX, dfkp.endY, s=40, color='#262626', edgecolor='#ff4b44', zorder=2)
    # ax.scatter(dfas.endX, dfas.endY, s=40, color='#ff4b44', edgecolor='w', zorder=3)
    xT = dfp['xT'].sum().round(2)
    show_name = dfp['shortName'].unique()[0]
    
    ax.set_title(f'{show_name}: {xT} xT', color='w', fontsize=25, fontweight='bold', y=1.07)
    # ax.text(52.5, 71, f'xT by Prog. Pass: {xT}', color='w', fontsize=16, ha='center', va='center')

    team_name = dfp['teamName'].unique()
    team_name = team_name[0]
    # Take data coordinates and transform them to normalized figure coordinates
    DC_to_FC = ax.transData.transform
    FC_to_NFC = fig.transFigure.inverted().transform
    DC_to_NFC = lambda x: FC_to_NFC(DC_to_FC(x))
    ax_coords = DC_to_NFC((0,66))
    ax_size = 0.02
    image_ax = fig.add_axes([ax_coords[0], ax_coords[1], ax_size, ax_size], fc='None', anchor='C')
    fotmob_url = f'https://raw.githubusercontent.com/adnaaan433/club_teams_logos/main/{team_name}.png'
    fotmob_url = fotmob_url.replace(' ', '%20')
    club_icon = Image.open(urllib.request.urlopen(fotmob_url))
    image_ax.imshow(club_icon)
    image_ax.axis('off')
    
    return

fig, ax = plt.subplots(figsize=(10,10), facecolor='#313332')
plot_top_xTC(ax, "Dan Ndoye")

# %%
dfp = df[(df['type']=='Carry')]
dfp_xT = dfp.groupby(['name']).sum().round(2)
dfp_xt = dfp_xT.sort_values(by='xT', ascending=False)
top10df = dfp_xt['xT'].head(12)
top10 = top10df.reset_index()
top10 = top10['name'].unique()
top10df
# Out:
# name
# Dan Ndoye             0.53
# Jamal Musiala         0.45
# Kenan Yildiz          0.42
# Rafael Leão           0.42
# Jérémy Doku           0.42
# Ferdi Kadioglu        0.28
# Mateo Kovacic         0.27
# Ousmane Dembélé       0.27
# Milan Skriniar        0.25
# Lamine Yamal          0.24
# Roman Yaremchuk       0.24
# Baris Alper Yilmaz    0.23
# Name: xT, dtype: float64

# %%
players = top10

fig, axs = plt.subplots(4, 3, figsize=(30, 30), facecolor='#262626')

for i, player in enumerate(players):
    row = i // 3
    col = i % 3
    plot_top_xTC(axs[row, col], player)

fig.text(0.2, 0.95, 'Top Threatening Ball Carriers, EURO 2024', color='w', fontsize=45, fontweight='bold')
fig_text(0.2, 0.94, 'Ball Carries, in Group stage | <Low xT>, <medium xT> and <high xT> Passes | made by: @adnaan433', 
         color='w', fontsize=22, highlight_textprops=[{'color':'#808080'}, {'color':'#38b977'}, {'color':'#fce724'}])

image_url = 'https://raw.githubusercontent.com/adnaaan433/league_logos/main/EURO2024.png'
image = urlopen(image_url)
image = Image.open(image)
ax_image = add_image(image, fig, left=0.13, bottom=0.92, width=0.05, height=0.05)
